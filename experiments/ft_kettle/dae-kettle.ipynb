# %%
# Constants
MAX_NO_ROWS = 1000000
LOAD_MODEL=False
SKIP_TRAINING=False
FEATURE = 'ft_kettle'
SEQ_PER_BATCH = 1024
SEQ_LEN = 32
N_STRIDES = 1
NORM_TYPE = 'mean'
LEARNING_RATE = 1e-3
CLIP_VALUE = 10.
EPOCHS = 1000
CHECKPOINT_PATH = f"dae_training_{FEATURE}/cp.ckpt"

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Dissertation
# Out:
# /content/drive/My Drive/Colab Notebooks/Dissertation

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.22.4)

# %%
from lib.chunk_reader import read_labels, get_merged_chunks, get_dates
from lib.plotting import plot_ft_days, plot_model_history, plot_prediction_windows
from lib.analysis import print_heads_tails

# %%
labels = read_labels(1)
for house in range(1,2):
    print('House {}: '.format(house), labels[house], '\n')
# Out:
# House 1:  ['mains_active', 'mains_apparent', 'mains_rms', 'aggregate_apparent', 'ft_boiler', 'ft_solar_thermal_pump', 'ft_washing_machine', 'ft_dishwasher', 'ft_tv', 'ft_kitchen_lights', 'ft_htpc', 'ft_kettle', 'ft_toaster', 'ft_fridge', 'ft_microwave', 'ft_amp_livingroom', 'ft_adsl_router', 'ft_livingroom_s_lamp', 'ft_lighting_circuit', 'ft_subwoofer_livingroom', 'ft_livingroom_lamp_tv', 'ft_kitchen_phone&stereo', 'ft_coffee_machine', 'ft_gas_oven', 'ft_data_logger_pc', 'ft_office_lamp2', 'aggregate_active', 'unix_time']

# %%
ref_chunk_df = get_merged_chunks(1, 1)
print('Original DF shape', ref_chunk_df.shape)
print('---')
ref_chunk_df = ref_chunk_df[0:MAX_NO_ROWS]
# Out:
# reading house 1; chunk 1
# reading file data/ukdale-parsed-chunks/house_1/chunk_1.dat; for house 1 and chunk 1
# read house 1; chunk 1; df.shape is (4500000, 29)
# Original DF shape (4500000, 29)
# ---

# %%
dates = {}
# for house in range(1,2):
dates[1] = get_dates(ref_chunk_df, 1)
# Out:
# House 1 data contain 71 days from 2013-04-11 to 2013-06-20.
# ['2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05-13', '2013-05-14', '2013-05-15', '2013-05-16', '2013-05-17', '2013-05-18', '2013-05-19', '2013-05-20', '2013-05-21', '2013-05-22', '2013-05-23', '2013-05-24', '2013-05-25', '2013-05-26', '2013-05-27', '2013-05-28', '2013-05-29', '2013-05-30', '2013-05-31', '2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04', '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08', '2013-06-09', '2013-06-10', '2013-06-11', '2013-06-12', '2013-06-13', '2013-06-14', '2013-06-15', '2013-06-16', '2013-06-17', '2013-06-18', '2013-06-19', '2013-06-20']

# %%
# Constants 2
rows_per_day = ref_chunk_df.loc[:dates[1][2]].shape[0]

# %%
from algos.processing import split_df_by_dates
from algos.dae import create_model, train, predict
from algos.norm import get_ref_norm, normalize, denormalize

# %%
# Separate house 1 data into train, validation and test data
df_train, df_val, df_test  =  split_df_by_dates(ref_chunk_df, dates=dates, house=1)
# Out:
# df_train.shape:  (521300, 29)
# df_val.shape:  (316800, 29)
# df_test.shape:  (190700, 29)

# %%
ref_norm = get_ref_norm(df_train, NORM_TYPE)
# Out:
# ref_mean: 325.09124755859375; ref_max: 6002.919921875; ref_std: 434.2580871582031
# norm_type: mean; ref_norm 325.09124755859375

# %%
model = create_model(seq_len=SEQ_LEN, learning_rate=LEARNING_RATE, clipvalue=CLIP_VALUE)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 32, 8)             40
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  reshape (Reshape)           (None, 32, 8)             0
#
#  conv1d_1 (Conv1D)           (None, 32, 1)             33
#
# =================================================================
# Total params: 131,785
# Trainable params: 131,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !!!!!!!Counter!!!!!!! 
# Manually update for every new loaded training
# Run Counter = 0

# Load and or Train
if LOAD_MODEL:
  model.load_weights(CHECKPOINT_PATH)
if SKIP_TRAINING:
  pass
else:
  model, history, time_spent = train(model, feature=FEATURE, df_train=df_train, df_val=df_val, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH, epochs=EPOCHS, checkpoint_path=CHECKPOINT_PATH)
# Out:
# (521300, 1) (521300, 1) (316800, 1) (316800, 1)
# sequence_len 32
# epochs 1000
# Input initial shape (16291, 32, 1); input final shape (16291, 32, 1)
# Output initial shape (16291, 32, 1); Output final shape (16291, 32, 1)
# Epoch 1/1000
# 16/16 - 13s - loss: 0.3326 - root_mean_squared_error: 0.5767 - mean_absolute_error: 0.1393 - val_loss: 0.1892 - val_root_mean_squared_error: 0.4349 - val_mean_absolute_error: 0.0475 - 13s/epoch - 842ms/step
# Epoch 2/1000
# 16/16 - 0s - loss: 0.2670 - root_mean_squared_error: 0.5168 - mean_absolute_error: 0.1063 - val_loss: 0.1619 - val_root_mean_squared_error: 0.4024 - val_mean_absolute_error: 0.0538 - 118ms/epoch - 7ms/step
# Epoch 3/1000
# 16/16 - 0s - loss: 0.2415 - root_mean_squared_error: 0.4914 - mean_absolute_error: 0.0930 - val_loss: 0.1452 - val_root_mean_squared_error: 0.3811 - val_mean_absolute_error: 0.0554 - 125ms/epoch - 8ms/step
# Epoch 4/1000
# 16/16 - 0s - loss: 0.2205 - root_mean_squared_error: 0.4696 - mean_absolute_error: 0.0860 - val_loss: 0.1324 - val_root_mean_squared_error: 0.3639 - val_mean_absolute_error: 0.0572 - 128ms/epoch - 8ms/step
# Epoch 5/1000
# 16/16 - 0s - loss: 0.2073 - root_mean_squared_error: 0.4553 - mean_absolute_error: 0.0809 - val_loss: 0.1367 - val_root_mean_squared_error: 0.3697 - val_mean_absolute_error: 0.0539 - 117ms/epoch - 7ms/step
# Epoch 6/1000
# 16/16 - 0s - loss: 0.2029 - root_mean_squared_error: 0.4505 - mean_absolute_error: 0.0791 - val_loss: 0.1282 - val_root_mean_squared_error: 0.3580 - val_mean_absolute_error: 0.0522 - 135ms/epoch - 8ms/step
# Epoch 7/1000
# 16/16 - 0s - loss: 0.1983 - root_mean_squared_error: 0.4453 - mean_absolute_error: 0.0766 - val_loss: 0.1304 - val_root_mean_squared_error: 0.3612 - val_mean_absolute_error: 0.0485 - 120ms/epoch - 7ms/step
# Epoch 8/1000
# 16/16 - 0s - loss: 0.1948 - root_mean_squared_error: 0.4413 - mean_absolute_error: 0.0691 - val_loss: 0.1273 - val_root_mean_squared_error: 0.3568 - val_mean_absolute_error: 0.0494 - 152ms/epoch - 9ms/step
# Epoch 9/1000
# 16/16 - 0s - loss: 0.1975 - root_mean_squared_error: 0.4444 - mean_absolute_error: 0.0697 - val_loss: 0.1267 - val_root_mean_squared_error: 0.3560 - val_mean_absolute_error: 0.0428 - 153ms/epoch - 10ms/step
# Epoch 10/1000
# 16/16 - 0s - loss: 0.1910 - root_mean_squared_error: 0.4370 - mean_absolute_error: 0.0705 - val_loss: 0.1338 - val_root_mean_squared_error: 0.3658 - val_mean_absolute_error: 0.0429 - 123ms/epoch - 8ms/step
# Epoch 11/1000
# 16/16 - 0s - loss: 0.1885 - root_mean_squared_error: 0.4342 - mean_absolute_error: 0.0669 - val_loss: 0.1256 - val_root_mean_squared_error: 0.3543 - val_mean_absolute_error: 0.0415 - 124ms/epoch - 8ms/step
# Epoch 12/1000
# 16/16 - 0s - loss: 0.1819 - root_mean_squared_error: 0.4265 - mean_absolute_error: 0.0638 - val_loss: 0.1246 - val_root_mean_squared_error: 0.3529 - val_mean_absolute_error: 0.0399 - 158ms/epoch - 10ms/step
# Epoch 13/1000
# 16/16 - 0s - loss: 0.1814 - root_mean_squared_error: 0.4259 - mean_absolute_error: 0.0616 - val_loss: 0.1245 - val_root_mean_squared_error: 0.3528 - val_mean_absolute_error: 0.0405 - 120ms/epoch - 7ms/step
# Epoch 14/1000
# 16/16 - 0s - loss: 0.1857 - root_mean_squared_error: 0.4309 - mean_absolute_error: 0.0628 - val_loss: 0.1245 - val_root_mean_squared_error: 0.3529 - val_mean_absolute_error: 0.0391 - 152ms/epoch - 9ms/step
# Epoch 15/1000
# 16/16 - 0s - loss: 0.1821 - root_mean_squared_error: 0.4267 - mean_absolute_error: 0.0619 - val_loss: 0.1198 - val_root_mean_squared_error: 0.3461 - val_mean_absolute_error: 0.0393 - 127ms/epoch - 8ms/step
# Epoch 16/1000
# 16/16 - 0s - loss: 0.1703 - root_mean_squared_error: 0.4127 - mean_absolute_error: 0.0593 - val_loss: 0.1216 - val_root_mean_squared_error: 0.3487 - val_mean_absolute_error: 0.0391 - 121ms/epoch - 8ms/step
# Epoch 17/1000
# 16/16 - 0s - loss: 0.1717 - root_mean_squared_error: 0.4143 - mean_absolute_error: 0.0577 - val_loss: 0.1178 - val_root_mean_squared_error: 0.3433 - val_mean_absolute_error: 0.0382 - 149ms/epoch - 9ms/step
# Epoch 18/1000
# 16/16 - 0s - loss: 0.1720 - root_mean_squared_error: 0.4147 - mean_absolute_error: 0.0572 - val_loss: 0.1202 - val_root_mean_squared_error: 0.3466 - val_mean_absolute_error: 0.0355 - 160ms/epoch - 10ms/step
# Epoch 19/1000
# 16/16 - 0s - loss: 0.1728 - root_mean_squared_error: 0.4157 - mean_absolute_error: 0.0582 - val_loss: 0.1137 - val_root_mean_squared_error: 0.3372 - val_mean_absolute_error: 0.0362 - 158ms/epoch - 10ms/step
# Epoch 20/1000
# 16/16 - 0s - loss: 0.1687 - root_mean_squared_error: 0.4107 - mean_absolute_error: 0.0566 - val_loss: 0.1148 - val_root_mean_squared_error: 0.3388 - val_mean_absolute_error: 0.0374 - 154ms/epoch - 10ms/step
# Epoch 21/1000
# 16/16 - 0s - loss: 0.1678 - root_mean_squared_error: 0.4096 - mean_absolute_error: 0.0560 - val_loss: 0.1149 - val_root_mean_squared_error: 0.3389 - val_mean_absolute_error: 0.0357 - 121ms/epoch - 8ms/step
# Epoch 22/1000
# 16/16 - 0s - loss: 0.1620 - root_mean_squared_error: 0.4025 - mean_absolute_error: 0.0541 - val_loss: 0.1192 - val_root_mean_squared_error: 0.3453 - val_mean_absolute_error: 0.0357 - 127ms/epoch - 8ms/step
# Epoch 23/1000
# 16/16 - 0s - loss: 0.1655 - root_mean_squared_error: 0.4068 - mean_absolute_error: 0.0541 - val_loss: 0.1195 - val_root_mean_squared_error: 0.3457 - val_mean_absolute_error: 0.0333 - 115ms/epoch - 7ms/step
# Epoch 24/1000
# 16/16 - 0s - loss: 0.1644 - root_mean_squared_error: 0.4055 - mean_absolute_error: 0.0520 - val_loss: 0.1146 - val_root_mean_squared_error: 0.3385 - val_mean_absolute_error: 0.0336 - 119ms/epoch - 7ms/step
# Epoch 25/1000
# 16/16 - 0s - loss: 0.1636 - root_mean_squared_error: 0.4045 - mean_absolute_error: 0.0504 - val_loss: 0.1135 - val_root_mean_squared_error: 0.3369 - val_mean_absolute_error: 0.0342 - 137ms/epoch - 9ms/step
# Epoch 26/1000
# 16/16 - 0s - loss: 0.1601 - root_mean_squared_error: 0.4002 - mean_absolute_error: 0.0524 - val_loss: 0.1100 - val_root_mean_squared_error: 0.3317 - val_mean_absolute_error: 0.0347 - 156ms/epoch - 10ms/step
# Epoch 27/1000
# 16/16 - 0s - loss: 0.1610 - root_mean_squared_error: 0.4012 - mean_absolute_error: 0.0532 - val_loss: 0.1124 - val_root_mean_squared_error: 0.3353 - val_mean_absolute_error: 0.0331 - 131ms/epoch - 8ms/step
# Epoch 28/1000
# 16/16 - 0s - loss: 0.1533 - root_mean_squared_error: 0.3915 - mean_absolute_error: 0.0507 - val_loss: 0.1084 - val_root_mean_squared_error: 0.3293 - val_mean_absolute_error: 0.0336 - 118ms/epoch - 7ms/step
# Epoch 29/1000
# 16/16 - 0s - loss: 0.1575 - root_mean_squared_error: 0.3969 - mean_absolute_error: 0.0512 - val_loss: 0.1086 - val_root_mean_squared_error: 0.3295 - val_mean_absolute_error: 0.0330 - 192ms/epoch - 12ms/step
# Epoch 30/1000
# 16/16 - 0s - loss: 0.1484 - root_mean_squared_error: 0.3852 - mean_absolute_error: 0.0501 - val_loss: 0.1067 - val_root_mean_squared_error: 0.3267 - val_mean_absolute_error: 0.0337 - 202ms/epoch - 13ms/step
# Epoch 31/1000
# 16/16 - 0s - loss: 0.1546 - root_mean_squared_error: 0.3932 - mean_absolute_error: 0.0502 - val_loss: 0.1067 - val_root_mean_squared_error: 0.3266 - val_mean_absolute_error: 0.0325 - 197ms/epoch - 12ms/step
# Epoch 32/1000
#
# Epoch 32: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.1485 - root_mean_squared_error: 0.3853 - mean_absolute_error: 0.0498 - val_loss: 0.1084 - val_root_mean_squared_error: 0.3293 - val_mean_absolute_error: 0.0322 - 376ms/epoch - 23ms/step
# Epoch 33/1000
# 16/16 - 0s - loss: 0.1495 - root_mean_squared_error: 0.3867 - mean_absolute_error: 0.0482 - val_loss: 0.1074 - val_root_mean_squared_error: 0.3277 - val_mean_absolute_error: 0.0313 - 198ms/epoch - 12ms/step
# Epoch 34/1000
# 16/16 - 0s - loss: 0.1409 - root_mean_squared_error: 0.3754 - mean_absolute_error: 0.0467 - val_loss: 0.1041 - val_root_mean_squared_error: 0.3227 - val_mean_absolute_error: 0.0314 - 170ms/epoch - 11ms/step
# Epoch 35/1000
# 16/16 - 0s - loss: 0.1449 - root_mean_squared_error: 0.3806 - mean_absolute_error: 0.0475 - val_loss: 0.1054 - val_root_mean_squared_error: 0.3246 - val_mean_absolute_error: 0.0308 - 197ms/epoch - 12ms/step
# Epoch 36/1000
# 16/16 - 0s - loss: 0.1402 - root_mean_squared_error: 0.3744 - mean_absolute_error: 0.0461 - val_loss: 0.1010 - val_root_mean_squared_error: 0.3179 - val_mean_absolute_error: 0.0308 - 219ms/epoch - 14ms/step
# Epoch 37/1000
# 16/16 - 0s - loss: 0.1371 - root_mean_squared_error: 0.3702 - mean_absolute_error: 0.0451 - val_loss: 0.1000 - val_root_mean_squared_error: 0.3163 - val_mean_absolute_error: 0.0303 - 193ms/epoch - 12ms/step
# Epoch 38/1000
# 16/16 - 0s - loss: 0.1420 - root_mean_squared_error: 0.3768 - mean_absolute_error: 0.0462 - val_loss: 0.1002 - val_root_mean_squared_error: 0.3166 - val_mean_absolute_error: 0.0298 - 186ms/epoch - 12ms/step
# Epoch 39/1000
# 16/16 - 0s - loss: 0.1371 - root_mean_squared_error: 0.3702 - mean_absolute_error: 0.0438 - val_loss: 0.1040 - val_root_mean_squared_error: 0.3225 - val_mean_absolute_error: 0.0290 - 194ms/epoch - 12ms/step
# Epoch 40/1000
# 16/16 - 0s - loss: 0.1388 - root_mean_squared_error: 0.3726 - mean_absolute_error: 0.0454 - val_loss: 0.1063 - val_root_mean_squared_error: 0.3261 - val_mean_absolute_error: 0.0292 - 190ms/epoch - 12ms/step
# Epoch 41/1000
# 16/16 - 0s - loss: 0.1374 - root_mean_squared_error: 0.3707 - mean_absolute_error: 0.0454 - val_loss: 0.0985 - val_root_mean_squared_error: 0.3138 - val_mean_absolute_error: 0.0308 - 211ms/epoch - 13ms/step
# Epoch 42/1000
# 16/16 - 0s - loss: 0.1415 - root_mean_squared_error: 0.3762 - mean_absolute_error: 0.0450 - val_loss: 0.0997 - val_root_mean_squared_error: 0.3158 - val_mean_absolute_error: 0.0301 - 197ms/epoch - 12ms/step
# Epoch 43/1000
# 16/16 - 0s - loss: 0.1340 - root_mean_squared_error: 0.3661 - mean_absolute_error: 0.0434 - val_loss: 0.1022 - val_root_mean_squared_error: 0.3197 - val_mean_absolute_error: 0.0280 - 196ms/epoch - 12ms/step
# Epoch 44/1000
# 16/16 - 0s - loss: 0.1349 - root_mean_squared_error: 0.3674 - mean_absolute_error: 0.0435 - val_loss: 0.1024 - val_root_mean_squared_error: 0.3201 - val_mean_absolute_error: 0.0278 - 207ms/epoch - 13ms/step
# Epoch 45/1000
# 16/16 - 0s - loss: 0.1284 - root_mean_squared_error: 0.3584 - mean_absolute_error: 0.0409 - val_loss: 0.0980 - val_root_mean_squared_error: 0.3130 - val_mean_absolute_error: 0.0284 - 181ms/epoch - 11ms/step
# Epoch 46/1000
# 16/16 - 0s - loss: 0.1256 - root_mean_squared_error: 0.3545 - mean_absolute_error: 0.0407 - val_loss: 0.1000 - val_root_mean_squared_error: 0.3162 - val_mean_absolute_error: 0.0276 - 137ms/epoch - 9ms/step
# Epoch 47/1000
# 16/16 - 0s - loss: 0.1277 - root_mean_squared_error: 0.3573 - mean_absolute_error: 0.0412 - val_loss: 0.0961 - val_root_mean_squared_error: 0.3100 - val_mean_absolute_error: 0.0282 - 123ms/epoch - 8ms/step
# Epoch 48/1000
# 16/16 - 0s - loss: 0.1307 - root_mean_squared_error: 0.3615 - mean_absolute_error: 0.0405 - val_loss: 0.0967 - val_root_mean_squared_error: 0.3109 - val_mean_absolute_error: 0.0273 - 159ms/epoch - 10ms/step
# Epoch 49/1000
# 16/16 - 0s - loss: 0.1259 - root_mean_squared_error: 0.3549 - mean_absolute_error: 0.0392 - val_loss: 0.0935 - val_root_mean_squared_error: 0.3057 - val_mean_absolute_error: 0.0268 - 119ms/epoch - 7ms/step
# Epoch 50/1000
# 16/16 - 0s - loss: 0.1260 - root_mean_squared_error: 0.3550 - mean_absolute_error: 0.0403 - val_loss: 0.1024 - val_root_mean_squared_error: 0.3200 - val_mean_absolute_error: 0.0257 - 127ms/epoch - 8ms/step
# Epoch 51/1000
# 16/16 - 0s - loss: 0.1262 - root_mean_squared_error: 0.3552 - mean_absolute_error: 0.0386 - val_loss: 0.0961 - val_root_mean_squared_error: 0.3100 - val_mean_absolute_error: 0.0262 - 118ms/epoch - 7ms/step
# Epoch 52/1000
# 16/16 - 0s - loss: 0.1205 - root_mean_squared_error: 0.3471 - mean_absolute_error: 0.0391 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3114 - val_mean_absolute_error: 0.0269 - 119ms/epoch - 7ms/step
# Epoch 53/1000
# 16/16 - 0s - loss: 0.1195 - root_mean_squared_error: 0.3456 - mean_absolute_error: 0.0377 - val_loss: 0.0935 - val_root_mean_squared_error: 0.3058 - val_mean_absolute_error: 0.0274 - 173ms/epoch - 11ms/step
# Epoch 54/1000
# 16/16 - 0s - loss: 0.1149 - root_mean_squared_error: 0.3389 - mean_absolute_error: 0.0370 - val_loss: 0.0934 - val_root_mean_squared_error: 0.3056 - val_mean_absolute_error: 0.0268 - 122ms/epoch - 8ms/step
# Epoch 55/1000
# 16/16 - 0s - loss: 0.1139 - root_mean_squared_error: 0.3375 - mean_absolute_error: 0.0369 - val_loss: 0.0982 - val_root_mean_squared_error: 0.3133 - val_mean_absolute_error: 0.0256 - 121ms/epoch - 8ms/step
# Epoch 56/1000
# 16/16 - 0s - loss: 0.1206 - root_mean_squared_error: 0.3473 - mean_absolute_error: 0.0380 - val_loss: 0.0939 - val_root_mean_squared_error: 0.3064 - val_mean_absolute_error: 0.0251 - 130ms/epoch - 8ms/step
# Epoch 57/1000
# 16/16 - 0s - loss: 0.1235 - root_mean_squared_error: 0.3515 - mean_absolute_error: 0.0375 - val_loss: 0.0963 - val_root_mean_squared_error: 0.3102 - val_mean_absolute_error: 0.0246 - 159ms/epoch - 10ms/step
# Epoch 58/1000
# 16/16 - 0s - loss: 0.1134 - root_mean_squared_error: 0.3367 - mean_absolute_error: 0.0366 - val_loss: 0.0923 - val_root_mean_squared_error: 0.3037 - val_mean_absolute_error: 0.0252 - 115ms/epoch - 7ms/step
# Epoch 59/1000
# 16/16 - 0s - loss: 0.1086 - root_mean_squared_error: 0.3295 - mean_absolute_error: 0.0359 - val_loss: 0.0914 - val_root_mean_squared_error: 0.3023 - val_mean_absolute_error: 0.0259 - 164ms/epoch - 10ms/step
# Epoch 60/1000
# 16/16 - 0s - loss: 0.1160 - root_mean_squared_error: 0.3406 - mean_absolute_error: 0.0364 - val_loss: 0.0920 - val_root_mean_squared_error: 0.3033 - val_mean_absolute_error: 0.0256 - 172ms/epoch - 11ms/step
# Epoch 61/1000
# 16/16 - 0s - loss: 0.1131 - root_mean_squared_error: 0.3363 - mean_absolute_error: 0.0361 - val_loss: 0.0934 - val_root_mean_squared_error: 0.3056 - val_mean_absolute_error: 0.0269 - 140ms/epoch - 9ms/step
# Epoch 62/1000
# 16/16 - 0s - loss: 0.1100 - root_mean_squared_error: 0.3316 - mean_absolute_error: 0.0351 - val_loss: 0.0897 - val_root_mean_squared_error: 0.2995 - val_mean_absolute_error: 0.0255 - 128ms/epoch - 8ms/step
# Epoch 63/1000
#
# Epoch 63: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.1115 - root_mean_squared_error: 0.3339 - mean_absolute_error: 0.0340 - val_loss: 0.0919 - val_root_mean_squared_error: 0.3031 - val_mean_absolute_error: 0.0258 - 258ms/epoch - 16ms/step
# Epoch 64/1000
# 16/16 - 0s - loss: 0.1136 - root_mean_squared_error: 0.3370 - mean_absolute_error: 0.0362 - val_loss: 0.0942 - val_root_mean_squared_error: 0.3069 - val_mean_absolute_error: 0.0254 - 156ms/epoch - 10ms/step
# Epoch 65/1000
# 16/16 - 0s - loss: 0.1062 - root_mean_squared_error: 0.3259 - mean_absolute_error: 0.0353 - val_loss: 0.0928 - val_root_mean_squared_error: 0.3047 - val_mean_absolute_error: 0.0259 - 123ms/epoch - 8ms/step
# Epoch 66/1000
# 16/16 - 0s - loss: 0.1088 - root_mean_squared_error: 0.3299 - mean_absolute_error: 0.0348 - val_loss: 0.0895 - val_root_mean_squared_error: 0.2992 - val_mean_absolute_error: 0.0256 - 141ms/epoch - 9ms/step
# Epoch 67/1000
# 16/16 - 0s - loss: 0.1138 - root_mean_squared_error: 0.3373 - mean_absolute_error: 0.0362 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3042 - val_mean_absolute_error: 0.0259 - 124ms/epoch - 8ms/step
# Epoch 68/1000
# 16/16 - 0s - loss: 0.1114 - root_mean_squared_error: 0.3338 - mean_absolute_error: 0.0343 - val_loss: 0.0948 - val_root_mean_squared_error: 0.3079 - val_mean_absolute_error: 0.0267 - 125ms/epoch - 8ms/step
# Epoch 69/1000
# 16/16 - 0s - loss: 0.1104 - root_mean_squared_error: 0.3323 - mean_absolute_error: 0.0348 - val_loss: 0.0923 - val_root_mean_squared_error: 0.3038 - val_mean_absolute_error: 0.0261 - 128ms/epoch - 8ms/step
# Epoch 70/1000
# 16/16 - 0s - loss: 0.1149 - root_mean_squared_error: 0.3390 - mean_absolute_error: 0.0372 - val_loss: 0.1006 - val_root_mean_squared_error: 0.3172 - val_mean_absolute_error: 0.0249 - 115ms/epoch - 7ms/step
# Epoch 71/1000
# 16/16 - 0s - loss: 0.1163 - root_mean_squared_error: 0.3410 - mean_absolute_error: 0.0361 - val_loss: 0.0968 - val_root_mean_squared_error: 0.3112 - val_mean_absolute_error: 0.0275 - 123ms/epoch - 8ms/step
# Epoch 72/1000
# 16/16 - 0s - loss: 0.1029 - root_mean_squared_error: 0.3207 - mean_absolute_error: 0.0338 - val_loss: 0.0916 - val_root_mean_squared_error: 0.3026 - val_mean_absolute_error: 0.0244 - 124ms/epoch - 8ms/step
# Epoch 73/1000
# 16/16 - 0s - loss: 0.1029 - root_mean_squared_error: 0.3207 - mean_absolute_error: 0.0337 - val_loss: 0.0911 - val_root_mean_squared_error: 0.3018 - val_mean_absolute_error: 0.0259 - 120ms/epoch - 8ms/step
# Epoch 74/1000
# 16/16 - 0s - loss: 0.1082 - root_mean_squared_error: 0.3289 - mean_absolute_error: 0.0342 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3114 - val_mean_absolute_error: 0.0277 - 125ms/epoch - 8ms/step
# Epoch 75/1000
# 16/16 - 0s - loss: 0.1000 - root_mean_squared_error: 0.3162 - mean_absolute_error: 0.0339 - val_loss: 0.0906 - val_root_mean_squared_error: 0.3011 - val_mean_absolute_error: 0.0250 - 125ms/epoch - 8ms/step
# Epoch 76/1000
# 16/16 - 0s - loss: 0.1086 - root_mean_squared_error: 0.3295 - mean_absolute_error: 0.0339 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3083 - val_mean_absolute_error: 0.0245 - 159ms/epoch - 10ms/step
# Epoch 77/1000
# 16/16 - 0s - loss: 0.1057 - root_mean_squared_error: 0.3251 - mean_absolute_error: 0.0340 - val_loss: 0.1001 - val_root_mean_squared_error: 0.3163 - val_mean_absolute_error: 0.0238 - 123ms/epoch - 8ms/step
# Epoch 78/1000
# 16/16 - 0s - loss: 0.1008 - root_mean_squared_error: 0.3175 - mean_absolute_error: 0.0329 - val_loss: 0.0924 - val_root_mean_squared_error: 0.3039 - val_mean_absolute_error: 0.0244 - 115ms/epoch - 7ms/step
# Epoch 79/1000
# 16/16 - 0s - loss: 0.1032 - root_mean_squared_error: 0.3212 - mean_absolute_error: 0.0329 - val_loss: 0.0943 - val_root_mean_squared_error: 0.3070 - val_mean_absolute_error: 0.0267 - 118ms/epoch - 7ms/step
# Epoch 80/1000
# 16/16 - 0s - loss: 0.1028 - root_mean_squared_error: 0.3207 - mean_absolute_error: 0.0334 - val_loss: 0.0922 - val_root_mean_squared_error: 0.3036 - val_mean_absolute_error: 0.0261 - 125ms/epoch - 8ms/step
# Epoch 81/1000
# 16/16 - 0s - loss: 0.0966 - root_mean_squared_error: 0.3108 - mean_absolute_error: 0.0317 - val_loss: 0.0956 - val_root_mean_squared_error: 0.3092 - val_mean_absolute_error: 0.0257 - 156ms/epoch - 10ms/step
# Epoch 82/1000
# 16/16 - 0s - loss: 0.1033 - root_mean_squared_error: 0.3214 - mean_absolute_error: 0.0335 - val_loss: 0.0927 - val_root_mean_squared_error: 0.3045 - val_mean_absolute_error: 0.0241 - 123ms/epoch - 8ms/step
# Epoch 83/1000
# 16/16 - 0s - loss: 0.1003 - root_mean_squared_error: 0.3168 - mean_absolute_error: 0.0324 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3080 - val_mean_absolute_error: 0.0244 - 130ms/epoch - 8ms/step
# Epoch 84/1000
# 16/16 - 0s - loss: 0.0950 - root_mean_squared_error: 0.3082 - mean_absolute_error: 0.0343 - val_loss: 0.0941 - val_root_mean_squared_error: 0.3067 - val_mean_absolute_error: 0.0238 - 120ms/epoch - 7ms/step
# Epoch 85/1000
# 16/16 - 0s - loss: 0.1006 - root_mean_squared_error: 0.3172 - mean_absolute_error: 0.0312 - val_loss: 0.0922 - val_root_mean_squared_error: 0.3037 - val_mean_absolute_error: 0.0256 - 124ms/epoch - 8ms/step
# Epoch 86/1000
# 16/16 - 0s - loss: 0.0979 - root_mean_squared_error: 0.3129 - mean_absolute_error: 0.0320 - val_loss: 0.0935 - val_root_mean_squared_error: 0.3057 - val_mean_absolute_error: 0.0268 - 153ms/epoch - 10ms/step
# Epoch 87/1000
# 16/16 - 0s - loss: 0.1019 - root_mean_squared_error: 0.3192 - mean_absolute_error: 0.0319 - val_loss: 0.0978 - val_root_mean_squared_error: 0.3128 - val_mean_absolute_error: 0.0284 - 161ms/epoch - 10ms/step
# Epoch 88/1000
# 16/16 - 0s - loss: 0.0947 - root_mean_squared_error: 0.3078 - mean_absolute_error: 0.0311 - val_loss: 0.0937 - val_root_mean_squared_error: 0.3061 - val_mean_absolute_error: 0.0250 - 140ms/epoch - 9ms/step
# Epoch 89/1000
# 16/16 - 0s - loss: 0.0963 - root_mean_squared_error: 0.3104 - mean_absolute_error: 0.0313 - val_loss: 0.0958 - val_root_mean_squared_error: 0.3095 - val_mean_absolute_error: 0.0284 - 120ms/epoch - 8ms/step
# Epoch 90/1000
# 16/16 - 0s - loss: 0.0894 - root_mean_squared_error: 0.2990 - mean_absolute_error: 0.0304 - val_loss: 0.0938 - val_root_mean_squared_error: 0.3062 - val_mean_absolute_error: 0.0254 - 132ms/epoch - 8ms/step
# Epoch 91/1000
# 16/16 - 0s - loss: 0.0931 - root_mean_squared_error: 0.3052 - mean_absolute_error: 0.0326 - val_loss: 0.0928 - val_root_mean_squared_error: 0.3047 - val_mean_absolute_error: 0.0245 - 158ms/epoch - 10ms/step
# Epoch 92/1000
# 16/16 - 0s - loss: 0.0993 - root_mean_squared_error: 0.3151 - mean_absolute_error: 0.0309 - val_loss: 0.0963 - val_root_mean_squared_error: 0.3103 - val_mean_absolute_error: 0.0245 - 163ms/epoch - 10ms/step
# Epoch 93/1000
# 16/16 - 0s - loss: 0.1009 - root_mean_squared_error: 0.3176 - mean_absolute_error: 0.0315 - val_loss: 0.0976 - val_root_mean_squared_error: 0.3124 - val_mean_absolute_error: 0.0273 - 121ms/epoch - 8ms/step
# Epoch 94/1000
#
# Epoch 94: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.1006 - root_mean_squared_error: 0.3172 - mean_absolute_error: 0.0330 - val_loss: 0.0994 - val_root_mean_squared_error: 0.3153 - val_mean_absolute_error: 0.0280 - 220ms/epoch - 14ms/step
# Epoch 95/1000
# 16/16 - 0s - loss: 0.0999 - root_mean_squared_error: 0.3160 - mean_absolute_error: 0.0316 - val_loss: 0.0953 - val_root_mean_squared_error: 0.3087 - val_mean_absolute_error: 0.0261 - 135ms/epoch - 8ms/step
# Epoch 96/1000
# 16/16 - 0s - loss: 0.0978 - root_mean_squared_error: 0.3128 - mean_absolute_error: 0.0320 - val_loss: 0.0954 - val_root_mean_squared_error: 0.3089 - val_mean_absolute_error: 0.0259 - 123ms/epoch - 8ms/step
# Epoch 97/1000
# 16/16 - 0s - loss: 0.0971 - root_mean_squared_error: 0.3116 - mean_absolute_error: 0.0330 - val_loss: 0.0982 - val_root_mean_squared_error: 0.3133 - val_mean_absolute_error: 0.0250 - 129ms/epoch - 8ms/step
# Epoch 98/1000
# 16/16 - 0s - loss: 0.0956 - root_mean_squared_error: 0.3091 - mean_absolute_error: 0.0312 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3076 - val_mean_absolute_error: 0.0247 - 136ms/epoch - 9ms/step
# Epoch 99/1000
# 16/16 - 0s - loss: 0.0930 - root_mean_squared_error: 0.3049 - mean_absolute_error: 0.0300 - val_loss: 0.0973 - val_root_mean_squared_error: 0.3119 - val_mean_absolute_error: 0.0260 - 167ms/epoch - 10ms/step
# Epoch 100/1000
# 16/16 - 0s - loss: 0.0950 - root_mean_squared_error: 0.3082 - mean_absolute_error: 0.0316 - val_loss: 0.0930 - val_root_mean_squared_error: 0.3050 - val_mean_absolute_error: 0.0245 - 165ms/epoch - 10ms/step
# Epoch 101/1000
# 16/16 - 0s - loss: 0.0963 - root_mean_squared_error: 0.3103 - mean_absolute_error: 0.0309 - val_loss: 0.0977 - val_root_mean_squared_error: 0.3125 - val_mean_absolute_error: 0.0266 - 156ms/epoch - 10ms/step
# Epoch 102/1000
# 16/16 - 0s - loss: 0.0934 - root_mean_squared_error: 0.3056 - mean_absolute_error: 0.0310 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3041 - val_mean_absolute_error: 0.0262 - 167ms/epoch - 10ms/step
# Epoch 103/1000
# 16/16 - 0s - loss: 0.0939 - root_mean_squared_error: 0.3064 - mean_absolute_error: 0.0307 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074 - val_mean_absolute_error: 0.0254 - 117ms/epoch - 7ms/step
# Epoch 104/1000
# 16/16 - 0s - loss: 0.0952 - root_mean_squared_error: 0.3085 - mean_absolute_error: 0.0308 - val_loss: 0.0931 - val_root_mean_squared_error: 0.3051 - val_mean_absolute_error: 0.0262 - 162ms/epoch - 10ms/step
# Epoch 105/1000
# 16/16 - 0s - loss: 0.0927 - root_mean_squared_error: 0.3044 - mean_absolute_error: 0.0315 - val_loss: 0.0940 - val_root_mean_squared_error: 0.3067 - val_mean_absolute_error: 0.0277 - 119ms/epoch - 7ms/step
# Epoch 106/1000
# 16/16 - 0s - loss: 0.0990 - root_mean_squared_error: 0.3147 - mean_absolute_error: 0.0315 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3073 - val_mean_absolute_error: 0.0270 - 166ms/epoch - 10ms/step
# Epoch 107/1000
# 16/16 - 0s - loss: 0.0857 - root_mean_squared_error: 0.2927 - mean_absolute_error: 0.0299 - val_loss: 0.0970 - val_root_mean_squared_error: 0.3115 - val_mean_absolute_error: 0.0270 - 120ms/epoch - 7ms/step
# Epoch 108/1000
# 16/16 - 0s - loss: 0.0947 - root_mean_squared_error: 0.3078 - mean_absolute_error: 0.0313 - val_loss: 0.0920 - val_root_mean_squared_error: 0.3032 - val_mean_absolute_error: 0.0255 - 131ms/epoch - 8ms/step
# Epoch 109/1000
# 16/16 - 0s - loss: 0.0888 - root_mean_squared_error: 0.2981 - mean_absolute_error: 0.0298 - val_loss: 0.0915 - val_root_mean_squared_error: 0.3025 - val_mean_absolute_error: 0.0259 - 120ms/epoch - 7ms/step
# Epoch 110/1000
# 16/16 - 0s - loss: 0.0873 - root_mean_squared_error: 0.2955 - mean_absolute_error: 0.0294 - val_loss: 0.0928 - val_root_mean_squared_error: 0.3047 - val_mean_absolute_error: 0.0245 - 122ms/epoch - 8ms/step
# Epoch 111/1000
# 16/16 - 0s - loss: 0.0875 - root_mean_squared_error: 0.2959 - mean_absolute_error: 0.0279 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3072 - val_mean_absolute_error: 0.0259 - 117ms/epoch - 7ms/step
# Epoch 112/1000
# 16/16 - 0s - loss: 0.0929 - root_mean_squared_error: 0.3048 - mean_absolute_error: 0.0304 - val_loss: 0.0936 - val_root_mean_squared_error: 0.3060 - val_mean_absolute_error: 0.0234 - 123ms/epoch - 8ms/step
# Epoch 113/1000
# 16/16 - 0s - loss: 0.0927 - root_mean_squared_error: 0.3044 - mean_absolute_error: 0.0311 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3080 - val_mean_absolute_error: 0.0251 - 156ms/epoch - 10ms/step
# Epoch 114/1000
# 16/16 - 0s - loss: 0.0855 - root_mean_squared_error: 0.2924 - mean_absolute_error: 0.0304 - val_loss: 0.0914 - val_root_mean_squared_error: 0.3024 - val_mean_absolute_error: 0.0248 - 177ms/epoch - 11ms/step
# Epoch 115/1000
# 16/16 - 0s - loss: 0.0854 - root_mean_squared_error: 0.2922 - mean_absolute_error: 0.0285 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3077 - val_mean_absolute_error: 0.0233 - 220ms/epoch - 14ms/step
# Epoch 116/1000
# 16/16 - 0s - loss: 0.0836 - root_mean_squared_error: 0.2891 - mean_absolute_error: 0.0285 - val_loss: 0.0923 - val_root_mean_squared_error: 0.3039 - val_mean_absolute_error: 0.0241 - 187ms/epoch - 12ms/step
# Epoch 117/1000
# 16/16 - 0s - loss: 0.0910 - root_mean_squared_error: 0.3016 - mean_absolute_error: 0.0297 - val_loss: 0.0940 - val_root_mean_squared_error: 0.3067 - val_mean_absolute_error: 0.0240 - 173ms/epoch - 11ms/step
# Epoch 118/1000
# 16/16 - 0s - loss: 0.0841 - root_mean_squared_error: 0.2899 - mean_absolute_error: 0.0289 - val_loss: 0.0949 - val_root_mean_squared_error: 0.3080 - val_mean_absolute_error: 0.0254 - 202ms/epoch - 13ms/step
# Epoch 119/1000
# 16/16 - 0s - loss: 0.0838 - root_mean_squared_error: 0.2894 - mean_absolute_error: 0.0275 - val_loss: 0.0926 - val_root_mean_squared_error: 0.3044 - val_mean_absolute_error: 0.0253 - 198ms/epoch - 12ms/step
# Epoch 120/1000
# 16/16 - 0s - loss: 0.0823 - root_mean_squared_error: 0.2869 - mean_absolute_error: 0.0277 - val_loss: 0.0984 - val_root_mean_squared_error: 0.3136 - val_mean_absolute_error: 0.0243 - 201ms/epoch - 13ms/step
# Epoch 121/1000
# 16/16 - 0s - loss: 0.0891 - root_mean_squared_error: 0.2986 - mean_absolute_error: 0.0288 - val_loss: 0.0941 - val_root_mean_squared_error: 0.3067 - val_mean_absolute_error: 0.0249 - 205ms/epoch - 13ms/step
# Epoch 122/1000
# 16/16 - 0s - loss: 0.0834 - root_mean_squared_error: 0.2887 - mean_absolute_error: 0.0285 - val_loss: 0.0918 - val_root_mean_squared_error: 0.3030 - val_mean_absolute_error: 0.0243 - 214ms/epoch - 13ms/step
# Epoch 123/1000
# 16/16 - 0s - loss: 0.0832 - root_mean_squared_error: 0.2885 - mean_absolute_error: 0.0276 - val_loss: 0.0927 - val_root_mean_squared_error: 0.3045 - val_mean_absolute_error: 0.0250 - 191ms/epoch - 12ms/step
# Epoch 124/1000
# 16/16 - 0s - loss: 0.0921 - root_mean_squared_error: 0.3034 - mean_absolute_error: 0.0297 - val_loss: 0.1000 - val_root_mean_squared_error: 0.3162 - val_mean_absolute_error: 0.0288 - 187ms/epoch - 12ms/step
# Epoch 125/1000
#
# Epoch 125: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.0872 - root_mean_squared_error: 0.2953 - mean_absolute_error: 0.0306 - val_loss: 0.0916 - val_root_mean_squared_error: 0.3026 - val_mean_absolute_error: 0.0234 - 292ms/epoch - 18ms/step
# Epoch 126/1000
# 16/16 - 0s - loss: 0.0886 - root_mean_squared_error: 0.2977 - mean_absolute_error: 0.0280 - val_loss: 0.0950 - val_root_mean_squared_error: 0.3082 - val_mean_absolute_error: 0.0251 - 208ms/epoch - 13ms/step
# Epoch 127/1000
# 16/16 - 0s - loss: 0.0936 - root_mean_squared_error: 0.3059 - mean_absolute_error: 0.0318 - val_loss: 0.0936 - val_root_mean_squared_error: 0.3060 - val_mean_absolute_error: 0.0244 - 187ms/epoch - 12ms/step
# Epoch 128/1000
# 16/16 - 0s - loss: 0.0801 - root_mean_squared_error: 0.2830 - mean_absolute_error: 0.0287 - val_loss: 0.0926 - val_root_mean_squared_error: 0.3042 - val_mean_absolute_error: 0.0231 - 207ms/epoch - 13ms/step
# Epoch 129/1000
# 16/16 - 0s - loss: 0.0827 - root_mean_squared_error: 0.2876 - mean_absolute_error: 0.0271 - val_loss: 0.0956 - val_root_mean_squared_error: 0.3092 - val_mean_absolute_error: 0.0259 - 291ms/epoch - 18ms/step
# Epoch 130/1000
# 16/16 - 0s - loss: 0.0835 - root_mean_squared_error: 0.2889 - mean_absolute_error: 0.0279 - val_loss: 0.0935 - val_root_mean_squared_error: 0.3058 - val_mean_absolute_error: 0.0229 - 244ms/epoch - 15ms/step
# Epoch 131/1000
# 16/16 - 0s - loss: 0.0850 - root_mean_squared_error: 0.2916 - mean_absolute_error: 0.0284 - val_loss: 0.0918 - val_root_mean_squared_error: 0.3029 - val_mean_absolute_error: 0.0248 - 249ms/epoch - 16ms/step
# Epoch 132/1000
# 16/16 - 0s - loss: 0.0932 - root_mean_squared_error: 0.3052 - mean_absolute_error: 0.0287 - val_loss: 0.0920 - val_root_mean_squared_error: 0.3033 - val_mean_absolute_error: 0.0256 - 229ms/epoch - 14ms/step
# Epoch 133/1000
# 16/16 - 0s - loss: 0.0839 - root_mean_squared_error: 0.2897 - mean_absolute_error: 0.0304 - val_loss: 0.0939 - val_root_mean_squared_error: 0.3065 - val_mean_absolute_error: 0.0259 - 124ms/epoch - 8ms/step
# Epoch 134/1000
# 16/16 - 0s - loss: 0.0826 - root_mean_squared_error: 0.2874 - mean_absolute_error: 0.0294 - val_loss: 0.0931 - val_root_mean_squared_error: 0.3051 - val_mean_absolute_error: 0.0232 - 141ms/epoch - 9ms/step
# Epoch 135/1000
# 16/16 - 0s - loss: 0.0886 - root_mean_squared_error: 0.2977 - mean_absolute_error: 0.0274 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3041 - val_mean_absolute_error: 0.0233 - 155ms/epoch - 10ms/step
# Epoch 136/1000
# 16/16 - 0s - loss: 0.0872 - root_mean_squared_error: 0.2953 - mean_absolute_error: 0.0299 - val_loss: 0.0911 - val_root_mean_squared_error: 0.3018 - val_mean_absolute_error: 0.0246 - 135ms/epoch - 8ms/step
# Epoch 137/1000
# 16/16 - 0s - loss: 0.0852 - root_mean_squared_error: 0.2919 - mean_absolute_error: 0.0285 - val_loss: 0.0931 - val_root_mean_squared_error: 0.3052 - val_mean_absolute_error: 0.0233 - 118ms/epoch - 7ms/step
# Epoch 138/1000
# 16/16 - 0s - loss: 0.0801 - root_mean_squared_error: 0.2831 - mean_absolute_error: 0.0281 - val_loss: 0.0903 - val_root_mean_squared_error: 0.3004 - val_mean_absolute_error: 0.0247 - 145ms/epoch - 9ms/step
# Epoch 139/1000
# 16/16 - 0s - loss: 0.0847 - root_mean_squared_error: 0.2910 - mean_absolute_error: 0.0281 - val_loss: 0.0924 - val_root_mean_squared_error: 0.3040 - val_mean_absolute_error: 0.0250 - 126ms/epoch - 8ms/step
# Epoch 140/1000
# 16/16 - 0s - loss: 0.0839 - root_mean_squared_error: 0.2897 - mean_absolute_error: 0.0284 - val_loss: 0.0905 - val_root_mean_squared_error: 0.3008 - val_mean_absolute_error: 0.0235 - 169ms/epoch - 11ms/step
# Epoch 141/1000
# 16/16 - 0s - loss: 0.0866 - root_mean_squared_error: 0.2944 - mean_absolute_error: 0.0284 - val_loss: 0.0911 - val_root_mean_squared_error: 0.3018 - val_mean_absolute_error: 0.0246 - 186ms/epoch - 12ms/step
# Epoch 142/1000
# 16/16 - 0s - loss: 0.0796 - root_mean_squared_error: 0.2822 - mean_absolute_error: 0.0281 - val_loss: 0.0927 - val_root_mean_squared_error: 0.3044 - val_mean_absolute_error: 0.0263 - 131ms/epoch - 8ms/step
# Epoch 143/1000
# 16/16 - 0s - loss: 0.0779 - root_mean_squared_error: 0.2791 - mean_absolute_error: 0.0269 - val_loss: 0.0934 - val_root_mean_squared_error: 0.3056 - val_mean_absolute_error: 0.0234 - 121ms/epoch - 8ms/step
# Epoch 144/1000
# 16/16 - 0s - loss: 0.0845 - root_mean_squared_error: 0.2907 - mean_absolute_error: 0.0272 - val_loss: 0.0905 - val_root_mean_squared_error: 0.3009 - val_mean_absolute_error: 0.0237 - 153ms/epoch - 10ms/step
# Epoch 145/1000
# 16/16 - 0s - loss: 0.0830 - root_mean_squared_error: 0.2881 - mean_absolute_error: 0.0283 - val_loss: 0.0931 - val_root_mean_squared_error: 0.3051 - val_mean_absolute_error: 0.0246 - 160ms/epoch - 10ms/step
# Epoch 146/1000
# 16/16 - 0s - loss: 0.0811 - root_mean_squared_error: 0.2849 - mean_absolute_error: 0.0282 - val_loss: 0.0924 - val_root_mean_squared_error: 0.3040 - val_mean_absolute_error: 0.0230 - 132ms/epoch - 8ms/step
# Epoch 147/1000
# 16/16 - 0s - loss: 0.0820 - root_mean_squared_error: 0.2863 - mean_absolute_error: 0.0279 - val_loss: 0.0899 - val_root_mean_squared_error: 0.2999 - val_mean_absolute_error: 0.0235 - 127ms/epoch - 8ms/step
# Epoch 148/1000
# 16/16 - 0s - loss: 0.0813 - root_mean_squared_error: 0.2852 - mean_absolute_error: 0.0261 - val_loss: 0.0933 - val_root_mean_squared_error: 0.3054 - val_mean_absolute_error: 0.0259 - 137ms/epoch - 9ms/step
# Epoch 149/1000
# 16/16 - 0s - loss: 0.0819 - root_mean_squared_error: 0.2862 - mean_absolute_error: 0.0283 - val_loss: 0.0927 - val_root_mean_squared_error: 0.3045 - val_mean_absolute_error: 0.0258 - 169ms/epoch - 11ms/step
# Epoch 150/1000
# 16/16 - 0s - loss: 0.0784 - root_mean_squared_error: 0.2800 - mean_absolute_error: 0.0260 - val_loss: 0.0888 - val_root_mean_squared_error: 0.2979 - val_mean_absolute_error: 0.0240 - 123ms/epoch - 8ms/step
# Epoch 151/1000
# 16/16 - 0s - loss: 0.0832 - root_mean_squared_error: 0.2884 - mean_absolute_error: 0.0273 - val_loss: 0.0895 - val_root_mean_squared_error: 0.2991 - val_mean_absolute_error: 0.0254 - 126ms/epoch - 8ms/step
# Epoch 152/1000
# 16/16 - 0s - loss: 0.0880 - root_mean_squared_error: 0.2967 - mean_absolute_error: 0.0312 - val_loss: 0.0943 - val_root_mean_squared_error: 0.3071 - val_mean_absolute_error: 0.0223 - 135ms/epoch - 8ms/step
# Epoch 153/1000
# 16/16 - 0s - loss: 0.0802 - root_mean_squared_error: 0.2832 - mean_absolute_error: 0.0280 - val_loss: 0.0922 - val_root_mean_squared_error: 0.3036 - val_mean_absolute_error: 0.0248 - 162ms/epoch - 10ms/step
# Epoch 154/1000
# 16/16 - 0s - loss: 0.0816 - root_mean_squared_error: 0.2856 - mean_absolute_error: 0.0267 - val_loss: 0.0897 - val_root_mean_squared_error: 0.2995 - val_mean_absolute_error: 0.0237 - 125ms/epoch - 8ms/step
# Epoch 155/1000
# 16/16 - 0s - loss: 0.0808 - root_mean_squared_error: 0.2842 - mean_absolute_error: 0.0284 - val_loss: 0.0926 - val_root_mean_squared_error: 0.3043 - val_mean_absolute_error: 0.0251 - 168ms/epoch - 11ms/step
# Epoch 156/1000
# 16/16 - 0s - loss: 0.0739 - root_mean_squared_error: 0.2719 - mean_absolute_error: 0.0256 - val_loss: 0.0907 - val_root_mean_squared_error: 0.3012 - val_mean_absolute_error: 0.0234 - 131ms/epoch - 8ms/step
# Epoch 157/1000
#
# Epoch 157: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.0772 - root_mean_squared_error: 0.2779 - mean_absolute_error: 0.0250 - val_loss: 0.0927 - val_root_mean_squared_error: 0.3045 - val_mean_absolute_error: 0.0244 - 263ms/epoch - 16ms/step
# Epoch 158/1000
# 16/16 - 0s - loss: 0.0815 - root_mean_squared_error: 0.2855 - mean_absolute_error: 0.0286 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3042 - val_mean_absolute_error: 0.0249 - 126ms/epoch - 8ms/step
# Epoch 159/1000
# 16/16 - 0s - loss: 0.0810 - root_mean_squared_error: 0.2846 - mean_absolute_error: 0.0275 - val_loss: 0.0918 - val_root_mean_squared_error: 0.3031 - val_mean_absolute_error: 0.0259 - 161ms/epoch - 10ms/step
# Epoch 160/1000
# 16/16 - 0s - loss: 0.0805 - root_mean_squared_error: 0.2837 - mean_absolute_error: 0.0288 - val_loss: 0.0891 - val_root_mean_squared_error: 0.2985 - val_mean_absolute_error: 0.0248 - 126ms/epoch - 8ms/step
# Epoch 161/1000
# 16/16 - 0s - loss: 0.0799 - root_mean_squared_error: 0.2826 - mean_absolute_error: 0.0268 - val_loss: 0.0890 - val_root_mean_squared_error: 0.2983 - val_mean_absolute_error: 0.0228 - 139ms/epoch - 9ms/step
# Epoch 162/1000
# 16/16 - 0s - loss: 0.0766 - root_mean_squared_error: 0.2768 - mean_absolute_error: 0.0253 - val_loss: 0.0936 - val_root_mean_squared_error: 0.3060 - val_mean_absolute_error: 0.0249 - 119ms/epoch - 7ms/step
# Epoch 163/1000
# 16/16 - 0s - loss: 0.0794 - root_mean_squared_error: 0.2818 - mean_absolute_error: 0.0274 - val_loss: 0.0930 - val_root_mean_squared_error: 0.3050 - val_mean_absolute_error: 0.0248 - 127ms/epoch - 8ms/step
# Epoch 164/1000
# 16/16 - 0s - loss: 0.0755 - root_mean_squared_error: 0.2747 - mean_absolute_error: 0.0268 - val_loss: 0.0919 - val_root_mean_squared_error: 0.3032 - val_mean_absolute_error: 0.0240 - 130ms/epoch - 8ms/step
# Epoch 165/1000
# 16/16 - 0s - loss: 0.0786 - root_mean_squared_error: 0.2804 - mean_absolute_error: 0.0273 - val_loss: 0.0930 - val_root_mean_squared_error: 0.3049 - val_mean_absolute_error: 0.0227 - 157ms/epoch - 10ms/step
# Epoch 166/1000
# 16/16 - 0s - loss: 0.0801 - root_mean_squared_error: 0.2831 - mean_absolute_error: 0.0273 - val_loss: 0.0916 - val_root_mean_squared_error: 0.3027 - val_mean_absolute_error: 0.0227 - 129ms/epoch - 8ms/step
# Epoch 167/1000
# 16/16 - 0s - loss: 0.0786 - root_mean_squared_error: 0.2804 - mean_absolute_error: 0.0261 - val_loss: 0.0876 - val_root_mean_squared_error: 0.2959 - val_mean_absolute_error: 0.0247 - 156ms/epoch - 10ms/step
# Epoch 168/1000
# 16/16 - 0s - loss: 0.0759 - root_mean_squared_error: 0.2756 - mean_absolute_error: 0.0267 - val_loss: 0.0898 - val_root_mean_squared_error: 0.2996 - val_mean_absolute_error: 0.0240 - 129ms/epoch - 8ms/step
# Epoch 169/1000
# 16/16 - 0s - loss: 0.0747 - root_mean_squared_error: 0.2733 - mean_absolute_error: 0.0269 - val_loss: 0.0908 - val_root_mean_squared_error: 0.3014 - val_mean_absolute_error: 0.0227 - 127ms/epoch - 8ms/step
# Epoch 170/1000
# 16/16 - 0s - loss: 0.0832 - root_mean_squared_error: 0.2884 - mean_absolute_error: 0.0267 - val_loss: 0.0911 - val_root_mean_squared_error: 0.3018 - val_mean_absolute_error: 0.0238 - 119ms/epoch - 7ms/step
# Epoch 171/1000
# 16/16 - 0s - loss: 0.0688 - root_mean_squared_error: 0.2623 - mean_absolute_error: 0.0252 - val_loss: 0.0959 - val_root_mean_squared_error: 0.3098 - val_mean_absolute_error: 0.0262 - 131ms/epoch - 8ms/step
# Epoch 172/1000
# 16/16 - 0s - loss: 0.0764 - root_mean_squared_error: 0.2764 - mean_absolute_error: 0.0258 - val_loss: 0.0957 - val_root_mean_squared_error: 0.3094 - val_mean_absolute_error: 0.0256 - 131ms/epoch - 8ms/step
# Epoch 173/1000
# 16/16 - 0s - loss: 0.0751 - root_mean_squared_error: 0.2740 - mean_absolute_error: 0.0261 - val_loss: 0.0893 - val_root_mean_squared_error: 0.2988 - val_mean_absolute_error: 0.0243 - 121ms/epoch - 8ms/step
# Epoch 174/1000
# 16/16 - 0s - loss: 0.0723 - root_mean_squared_error: 0.2689 - mean_absolute_error: 0.0254 - val_loss: 0.0903 - val_root_mean_squared_error: 0.3005 - val_mean_absolute_error: 0.0258 - 159ms/epoch - 10ms/step
# Epoch 175/1000
# 16/16 - 0s - loss: 0.0720 - root_mean_squared_error: 0.2684 - mean_absolute_error: 0.0245 - val_loss: 0.0890 - val_root_mean_squared_error: 0.2983 - val_mean_absolute_error: 0.0239 - 147ms/epoch - 9ms/step
# Epoch 176/1000
# 16/16 - 0s - loss: 0.0769 - root_mean_squared_error: 0.2773 - mean_absolute_error: 0.0264 - val_loss: 0.0920 - val_root_mean_squared_error: 0.3033 - val_mean_absolute_error: 0.0265 - 159ms/epoch - 10ms/step
# Epoch 177/1000
# 16/16 - 0s - loss: 0.0782 - root_mean_squared_error: 0.2797 - mean_absolute_error: 0.0271 - val_loss: 0.0899 - val_root_mean_squared_error: 0.2999 - val_mean_absolute_error: 0.0224 - 157ms/epoch - 10ms/step
# Epoch 178/1000
# 16/16 - 0s - loss: 0.0761 - root_mean_squared_error: 0.2758 - mean_absolute_error: 0.0260 - val_loss: 0.0902 - val_root_mean_squared_error: 0.3003 - val_mean_absolute_error: 0.0233 - 139ms/epoch - 9ms/step
# Epoch 179/1000
# 16/16 - 0s - loss: 0.0776 - root_mean_squared_error: 0.2785 - mean_absolute_error: 0.0269 - val_loss: 0.0891 - val_root_mean_squared_error: 0.2984 - val_mean_absolute_error: 0.0243 - 124ms/epoch - 8ms/step
# Epoch 180/1000
# 16/16 - 0s - loss: 0.0781 - root_mean_squared_error: 0.2794 - mean_absolute_error: 0.0260 - val_loss: 0.0885 - val_root_mean_squared_error: 0.2974 - val_mean_absolute_error: 0.0251 - 159ms/epoch - 10ms/step
# Epoch 181/1000
# 16/16 - 0s - loss: 0.0747 - root_mean_squared_error: 0.2734 - mean_absolute_error: 0.0273 - val_loss: 0.0888 - val_root_mean_squared_error: 0.2980 - val_mean_absolute_error: 0.0238 - 130ms/epoch - 8ms/step
# Epoch 182/1000
# 16/16 - 0s - loss: 0.0701 - root_mean_squared_error: 0.2647 - mean_absolute_error: 0.0251 - val_loss: 0.0902 - val_root_mean_squared_error: 0.3003 - val_mean_absolute_error: 0.0235 - 180ms/epoch - 11ms/step
# Epoch 183/1000
# 16/16 - 0s - loss: 0.0731 - root_mean_squared_error: 0.2704 - mean_absolute_error: 0.0246 - val_loss: 0.0896 - val_root_mean_squared_error: 0.2994 - val_mean_absolute_error: 0.0240 - 136ms/epoch - 8ms/step
# Epoch 184/1000
# 16/16 - 0s - loss: 0.0715 - root_mean_squared_error: 0.2675 - mean_absolute_error: 0.0257 - val_loss: 0.0914 - val_root_mean_squared_error: 0.3023 - val_mean_absolute_error: 0.0248 - 134ms/epoch - 8ms/step
# Epoch 185/1000
# 16/16 - 0s - loss: 0.0710 - root_mean_squared_error: 0.2664 - mean_absolute_error: 0.0249 - val_loss: 0.0943 - val_root_mean_squared_error: 0.3070 - val_mean_absolute_error: 0.0238 - 155ms/epoch - 10ms/step
# Epoch 186/1000
# 16/16 - 0s - loss: 0.0747 - root_mean_squared_error: 0.2733 - mean_absolute_error: 0.0249 - val_loss: 0.0905 - val_root_mean_squared_error: 0.3008 - val_mean_absolute_error: 0.0255 - 120ms/epoch - 8ms/step
# Epoch 187/1000
# 16/16 - 0s - loss: 0.0792 - root_mean_squared_error: 0.2815 - mean_absolute_error: 0.0263 - val_loss: 0.0926 - val_root_mean_squared_error: 0.3043 - val_mean_absolute_error: 0.0259 - 165ms/epoch - 10ms/step
# Epoch 188/1000
#
# Epoch 188: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.0760 - root_mean_squared_error: 0.2757 - mean_absolute_error: 0.0276 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077 - val_mean_absolute_error: 0.0264 - 259ms/epoch - 16ms/step
# Epoch 189/1000
# 16/16 - 0s - loss: 0.0726 - root_mean_squared_error: 0.2694 - mean_absolute_error: 0.0249 - val_loss: 0.0935 - val_root_mean_squared_error: 0.3057 - val_mean_absolute_error: 0.0248 - 135ms/epoch - 8ms/step
# Epoch 190/1000
# 16/16 - 0s - loss: 0.0777 - root_mean_squared_error: 0.2787 - mean_absolute_error: 0.0258 - val_loss: 0.0907 - val_root_mean_squared_error: 0.3012 - val_mean_absolute_error: 0.0224 - 124ms/epoch - 8ms/step
# Epoch 191/1000
# 16/16 - 0s - loss: 0.0687 - root_mean_squared_error: 0.2620 - mean_absolute_error: 0.0248 - val_loss: 0.0934 - val_root_mean_squared_error: 0.3056 - val_mean_absolute_error: 0.0263 - 159ms/epoch - 10ms/step
# Epoch 192/1000
# 16/16 - 0s - loss: 0.0707 - root_mean_squared_error: 0.2660 - mean_absolute_error: 0.0246 - val_loss: 0.0861 - val_root_mean_squared_error: 0.2935 - val_mean_absolute_error: 0.0221 - 123ms/epoch - 8ms/step
# Epoch 193/1000
# 16/16 - 0s - loss: 0.0726 - root_mean_squared_error: 0.2694 - mean_absolute_error: 0.0243 - val_loss: 0.0844 - val_root_mean_squared_error: 0.2906 - val_mean_absolute_error: 0.0231 - 130ms/epoch - 8ms/step
# Epoch 194/1000
# 16/16 - 0s - loss: 0.0736 - root_mean_squared_error: 0.2713 - mean_absolute_error: 0.0261 - val_loss: 0.0866 - val_root_mean_squared_error: 0.2943 - val_mean_absolute_error: 0.0220 - 133ms/epoch - 8ms/step
# Epoch 195/1000
# 16/16 - 0s - loss: 0.0680 - root_mean_squared_error: 0.2608 - mean_absolute_error: 0.0242 - val_loss: 0.0885 - val_root_mean_squared_error: 0.2975 - val_mean_absolute_error: 0.0243 - 201ms/epoch - 13ms/step
# Epoch 196/1000
# 16/16 - 0s - loss: 0.0676 - root_mean_squared_error: 0.2600 - mean_absolute_error: 0.0233 - val_loss: 0.0899 - val_root_mean_squared_error: 0.2999 - val_mean_absolute_error: 0.0262 - 185ms/epoch - 12ms/step
# Epoch 197/1000
# 16/16 - 0s - loss: 0.0780 - root_mean_squared_error: 0.2792 - mean_absolute_error: 0.0263 - val_loss: 0.0850 - val_root_mean_squared_error: 0.2915 - val_mean_absolute_error: 0.0225 - 196ms/epoch - 12ms/step
# Epoch 198/1000
# 16/16 - 0s - loss: 0.0747 - root_mean_squared_error: 0.2732 - mean_absolute_error: 0.0249 - val_loss: 0.0863 - val_root_mean_squared_error: 0.2938 - val_mean_absolute_error: 0.0240 - 204ms/epoch - 13ms/step
# Epoch 199/1000
# 16/16 - 0s - loss: 0.0712 - root_mean_squared_error: 0.2669 - mean_absolute_error: 0.0262 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3041 - val_mean_absolute_error: 0.0259 - 204ms/epoch - 13ms/step
# Epoch 200/1000
# 16/16 - 0s - loss: 0.0719 - root_mean_squared_error: 0.2681 - mean_absolute_error: 0.0251 - val_loss: 0.0879 - val_root_mean_squared_error: 0.2965 - val_mean_absolute_error: 0.0243 - 205ms/epoch - 13ms/step
# Epoch 201/1000
# 16/16 - 0s - loss: 0.0718 - root_mean_squared_error: 0.2680 - mean_absolute_error: 0.0246 - val_loss: 0.0839 - val_root_mean_squared_error: 0.2896 - val_mean_absolute_error: 0.0213 - 198ms/epoch - 12ms/step
# Epoch 202/1000
# 16/16 - 0s - loss: 0.0672 - root_mean_squared_error: 0.2592 - mean_absolute_error: 0.0236 - val_loss: 0.0985 - val_root_mean_squared_error: 0.3138 - val_mean_absolute_error: 0.0269 - 186ms/epoch - 12ms/step
# Epoch 203/1000
# 16/16 - 0s - loss: 0.0714 - root_mean_squared_error: 0.2672 - mean_absolute_error: 0.0247 - val_loss: 0.0905 - val_root_mean_squared_error: 0.3009 - val_mean_absolute_error: 0.0258 - 175ms/epoch - 11ms/step
# Epoch 204/1000
# 16/16 - 0s - loss: 0.0728 - root_mean_squared_error: 0.2698 - mean_absolute_error: 0.0255 - val_loss: 0.0862 - val_root_mean_squared_error: 0.2936 - val_mean_absolute_error: 0.0236 - 201ms/epoch - 13ms/step
# Epoch 205/1000
# 16/16 - 0s - loss: 0.0760 - root_mean_squared_error: 0.2757 - mean_absolute_error: 0.0270 - val_loss: 0.0843 - val_root_mean_squared_error: 0.2903 - val_mean_absolute_error: 0.0224 - 183ms/epoch - 11ms/step
# Epoch 206/1000
# 16/16 - 0s - loss: 0.0723 - root_mean_squared_error: 0.2689 - mean_absolute_error: 0.0254 - val_loss: 0.0835 - val_root_mean_squared_error: 0.2889 - val_mean_absolute_error: 0.0221 - 192ms/epoch - 12ms/step
# Epoch 207/1000
# 16/16 - 0s - loss: 0.0661 - root_mean_squared_error: 0.2571 - mean_absolute_error: 0.0230 - val_loss: 0.0872 - val_root_mean_squared_error: 0.2953 - val_mean_absolute_error: 0.0232 - 211ms/epoch - 13ms/step
# Epoch 208/1000
# 16/16 - 0s - loss: 0.0693 - root_mean_squared_error: 0.2632 - mean_absolute_error: 0.0242 - val_loss: 0.0915 - val_root_mean_squared_error: 0.3024 - val_mean_absolute_error: 0.0244 - 201ms/epoch - 13ms/step
# Epoch 209/1000
# 16/16 - 0s - loss: 0.0709 - root_mean_squared_error: 0.2662 - mean_absolute_error: 0.0256 - val_loss: 0.0859 - val_root_mean_squared_error: 0.2930 - val_mean_absolute_error: 0.0240 - 193ms/epoch - 12ms/step
# Epoch 210/1000
# 16/16 - 0s - loss: 0.0679 - root_mean_squared_error: 0.2606 - mean_absolute_error: 0.0239 - val_loss: 0.0871 - val_root_mean_squared_error: 0.2952 - val_mean_absolute_error: 0.0231 - 202ms/epoch - 13ms/step
# Epoch 211/1000
# 16/16 - 0s - loss: 0.0662 - root_mean_squared_error: 0.2573 - mean_absolute_error: 0.0237 - val_loss: 0.0854 - val_root_mean_squared_error: 0.2923 - val_mean_absolute_error: 0.0242 - 186ms/epoch - 12ms/step
# Epoch 212/1000
# 16/16 - 0s - loss: 0.0695 - root_mean_squared_error: 0.2637 - mean_absolute_error: 0.0248 - val_loss: 0.0869 - val_root_mean_squared_error: 0.2947 - val_mean_absolute_error: 0.0243 - 199ms/epoch - 12ms/step
# Epoch 213/1000
# 16/16 - 0s - loss: 0.0701 - root_mean_squared_error: 0.2647 - mean_absolute_error: 0.0242 - val_loss: 0.0903 - val_root_mean_squared_error: 0.3005 - val_mean_absolute_error: 0.0259 - 131ms/epoch - 8ms/step
# Epoch 214/1000
# 16/16 - 0s - loss: 0.0703 - root_mean_squared_error: 0.2652 - mean_absolute_error: 0.0240 - val_loss: 0.0898 - val_root_mean_squared_error: 0.2996 - val_mean_absolute_error: 0.0239 - 129ms/epoch - 8ms/step
# Epoch 215/1000
# ...
# Epoch 930/1000
# 16/16 - 0s - loss: 0.0378 - root_mean_squared_error: 0.1945 - mean_absolute_error: 0.0153 - val_loss: 0.0930 - val_root_mean_squared_error: 0.3050 - val_mean_absolute_error: 0.0222 - 227ms/epoch - 14ms/step
# Epoch 931/1000
# 16/16 - 0s - loss: 0.0366 - root_mean_squared_error: 0.1914 - mean_absolute_error: 0.0150 - val_loss: 0.0962 - val_root_mean_squared_error: 0.3102 - val_mean_absolute_error: 0.0218 - 219ms/epoch - 14ms/step
# Epoch 932/1000
# 16/16 - 0s - loss: 0.0380 - root_mean_squared_error: 0.1948 - mean_absolute_error: 0.0140 - val_loss: 0.0913 - val_root_mean_squared_error: 0.3022 - val_mean_absolute_error: 0.0192 - 208ms/epoch - 13ms/step
# Epoch 933/1000
# 16/16 - 0s - loss: 0.0378 - root_mean_squared_error: 0.1943 - mean_absolute_error: 0.0146 - val_loss: 0.0912 - val_root_mean_squared_error: 0.3020 - val_mean_absolute_error: 0.0218 - 214ms/epoch - 13ms/step
# Epoch 934/1000
# 16/16 - 0s - loss: 0.0391 - root_mean_squared_error: 0.1978 - mean_absolute_error: 0.0151 - val_loss: 0.0934 - val_root_mean_squared_error: 0.3056 - val_mean_absolute_error: 0.0204 - 225ms/epoch - 14ms/step
# Epoch 935/1000
# 16/16 - 0s - loss: 0.0389 - root_mean_squared_error: 0.1973 - mean_absolute_error: 0.0141 - val_loss: 0.0916 - val_root_mean_squared_error: 0.3027 - val_mean_absolute_error: 0.0225 - 182ms/epoch - 11ms/step
# Epoch 936/1000
# 16/16 - 0s - loss: 0.0404 - root_mean_squared_error: 0.2009 - mean_absolute_error: 0.0154 - val_loss: 0.0944 - val_root_mean_squared_error: 0.3073 - val_mean_absolute_error: 0.0215 - 210ms/epoch - 13ms/step
# Epoch 937/1000
# 16/16 - 0s - loss: 0.0425 - root_mean_squared_error: 0.2063 - mean_absolute_error: 0.0147 - val_loss: 0.0890 - val_root_mean_squared_error: 0.2983 - val_mean_absolute_error: 0.0199 - 218ms/epoch - 14ms/step
# Epoch 938/1000
#
# Epoch 938: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.0382 - root_mean_squared_error: 0.1955 - mean_absolute_error: 0.0147 - val_loss: 0.0940 - val_root_mean_squared_error: 0.3066 - val_mean_absolute_error: 0.0225 - 351ms/epoch - 22ms/step
# Epoch 939/1000
# 16/16 - 0s - loss: 0.0396 - root_mean_squared_error: 0.1990 - mean_absolute_error: 0.0154 - val_loss: 0.0932 - val_root_mean_squared_error: 0.3052 - val_mean_absolute_error: 0.0203 - 201ms/epoch - 13ms/step
# Epoch 940/1000
# 16/16 - 0s - loss: 0.0380 - root_mean_squared_error: 0.1950 - mean_absolute_error: 0.0146 - val_loss: 0.0885 - val_root_mean_squared_error: 0.2975 - val_mean_absolute_error: 0.0195 - 199ms/epoch - 12ms/step
# Epoch 941/1000
# 16/16 - 0s - loss: 0.0456 - root_mean_squared_error: 0.2136 - mean_absolute_error: 0.0164 - val_loss: 0.0972 - val_root_mean_squared_error: 0.3117 - val_mean_absolute_error: 0.0230 - 213ms/epoch - 13ms/step
# Epoch 942/1000
# 16/16 - 0s - loss: 0.0477 - root_mean_squared_error: 0.2184 - mean_absolute_error: 0.0167 - val_loss: 0.0921 - val_root_mean_squared_error: 0.3036 - val_mean_absolute_error: 0.0229 - 204ms/epoch - 13ms/step
# Epoch 943/1000
# 16/16 - 0s - loss: 0.0425 - root_mean_squared_error: 0.2062 - mean_absolute_error: 0.0150 - val_loss: 0.0890 - val_root_mean_squared_error: 0.2983 - val_mean_absolute_error: 0.0221 - 187ms/epoch - 12ms/step
# Epoch 944/1000
# 16/16 - 0s - loss: 0.0418 - root_mean_squared_error: 0.2044 - mean_absolute_error: 0.0163 - val_loss: 0.0902 - val_root_mean_squared_error: 0.3003 - val_mean_absolute_error: 0.0213 - 127ms/epoch - 8ms/step
# Epoch 945/1000
# 16/16 - 0s - loss: 0.0400 - root_mean_squared_error: 0.2001 - mean_absolute_error: 0.0138 - val_loss: 0.0995 - val_root_mean_squared_error: 0.3154 - val_mean_absolute_error: 0.0246 - 163ms/epoch - 10ms/step
# Epoch 946/1000
# 16/16 - 0s - loss: 0.0442 - root_mean_squared_error: 0.2102 - mean_absolute_error: 0.0164 - val_loss: 0.0987 - val_root_mean_squared_error: 0.3142 - val_mean_absolute_error: 0.0187 - 164ms/epoch - 10ms/step
# Epoch 947/1000
# 16/16 - 0s - loss: 0.0483 - root_mean_squared_error: 0.2197 - mean_absolute_error: 0.0169 - val_loss: 0.0951 - val_root_mean_squared_error: 0.3084 - val_mean_absolute_error: 0.0241 - 132ms/epoch - 8ms/step
# Epoch 948/1000
# 16/16 - 0s - loss: 0.0387 - root_mean_squared_error: 0.1967 - mean_absolute_error: 0.0154 - val_loss: 0.0952 - val_root_mean_squared_error: 0.3085 - val_mean_absolute_error: 0.0207 - 179ms/epoch - 11ms/step
# Epoch 949/1000
# 16/16 - 0s - loss: 0.0437 - root_mean_squared_error: 0.2091 - mean_absolute_error: 0.0161 - val_loss: 0.0928 - val_root_mean_squared_error: 0.3046 - val_mean_absolute_error: 0.0212 - 136ms/epoch - 8ms/step
# Epoch 950/1000
# 16/16 - 0s - loss: 0.0411 - root_mean_squared_error: 0.2027 - mean_absolute_error: 0.0142 - val_loss: 0.0958 - val_root_mean_squared_error: 0.3096 - val_mean_absolute_error: 0.0238 - 160ms/epoch - 10ms/step
# Epoch 951/1000
# 16/16 - 0s - loss: 0.0373 - root_mean_squared_error: 0.1931 - mean_absolute_error: 0.0164 - val_loss: 0.0933 - val_root_mean_squared_error: 0.3054 - val_mean_absolute_error: 0.0200 - 161ms/epoch - 10ms/step
# Epoch 952/1000
# 16/16 - 0s - loss: 0.0433 - root_mean_squared_error: 0.2081 - mean_absolute_error: 0.0141 - val_loss: 0.0903 - val_root_mean_squared_error: 0.3005 - val_mean_absolute_error: 0.0193 - 164ms/epoch - 10ms/step
# Epoch 953/1000
# 16/16 - 0s - loss: 0.0416 - root_mean_squared_error: 0.2039 - mean_absolute_error: 0.0148 - val_loss: 0.0962 - val_root_mean_squared_error: 0.3101 - val_mean_absolute_error: 0.0242 - 165ms/epoch - 10ms/step
# Epoch 954/1000
# 16/16 - 0s - loss: 0.0359 - root_mean_squared_error: 0.1896 - mean_absolute_error: 0.0156 - val_loss: 0.0903 - val_root_mean_squared_error: 0.3005 - val_mean_absolute_error: 0.0205 - 148ms/epoch - 9ms/step
# Epoch 955/1000
# 16/16 - 0s - loss: 0.0382 - root_mean_squared_error: 0.1954 - mean_absolute_error: 0.0142 - val_loss: 0.0914 - val_root_mean_squared_error: 0.3022 - val_mean_absolute_error: 0.0208 - 169ms/epoch - 11ms/step
# Epoch 956/1000
# 16/16 - 0s - loss: 0.0426 - root_mean_squared_error: 0.2065 - mean_absolute_error: 0.0146 - val_loss: 0.0943 - val_root_mean_squared_error: 0.3072 - val_mean_absolute_error: 0.0206 - 130ms/epoch - 8ms/step
# Epoch 957/1000
# 16/16 - 0s - loss: 0.0456 - root_mean_squared_error: 0.2135 - mean_absolute_error: 0.0153 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3042 - val_mean_absolute_error: 0.0197 - 128ms/epoch - 8ms/step
# Epoch 958/1000
# 16/16 - 0s - loss: 0.0380 - root_mean_squared_error: 0.1948 - mean_absolute_error: 0.0156 - val_loss: 0.1004 - val_root_mean_squared_error: 0.3168 - val_mean_absolute_error: 0.0239 - 160ms/epoch - 10ms/step
# Epoch 959/1000
# 16/16 - 0s - loss: 0.0399 - root_mean_squared_error: 0.1998 - mean_absolute_error: 0.0156 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3203 - val_mean_absolute_error: 0.0227 - 167ms/epoch - 10ms/step
# Epoch 960/1000
# 16/16 - 0s - loss: 0.0410 - root_mean_squared_error: 0.2025 - mean_absolute_error: 0.0148 - val_loss: 0.1011 - val_root_mean_squared_error: 0.3180 - val_mean_absolute_error: 0.0200 - 135ms/epoch - 8ms/step
# Epoch 961/1000
# 16/16 - 0s - loss: 0.0417 - root_mean_squared_error: 0.2042 - mean_absolute_error: 0.0147 - val_loss: 0.0962 - val_root_mean_squared_error: 0.3101 - val_mean_absolute_error: 0.0237 - 131ms/epoch - 8ms/step
# Epoch 962/1000
# 16/16 - 0s - loss: 0.0402 - root_mean_squared_error: 0.2004 - mean_absolute_error: 0.0150 - val_loss: 0.0918 - val_root_mean_squared_error: 0.3031 - val_mean_absolute_error: 0.0194 - 134ms/epoch - 8ms/step
# Epoch 963/1000
# 16/16 - 0s - loss: 0.0448 - root_mean_squared_error: 0.2116 - mean_absolute_error: 0.0162 - val_loss: 0.0933 - val_root_mean_squared_error: 0.3055 - val_mean_absolute_error: 0.0232 - 137ms/epoch - 9ms/step
# Epoch 964/1000
# 16/16 - 0s - loss: 0.0389 - root_mean_squared_error: 0.1971 - mean_absolute_error: 0.0164 - val_loss: 0.0968 - val_root_mean_squared_error: 0.3112 - val_mean_absolute_error: 0.0214 - 167ms/epoch - 10ms/step
# Epoch 965/1000
# 16/16 - 0s - loss: 0.0394 - root_mean_squared_error: 0.1985 - mean_absolute_error: 0.0141 - val_loss: 0.0922 - val_root_mean_squared_error: 0.3036 - val_mean_absolute_error: 0.0213 - 139ms/epoch - 9ms/step
# Epoch 966/1000
# 16/16 - 0s - loss: 0.0363 - root_mean_squared_error: 0.1906 - mean_absolute_error: 0.0146 - val_loss: 0.0911 - val_root_mean_squared_error: 0.3017 - val_mean_absolute_error: 0.0198 - 131ms/epoch - 8ms/step
# Epoch 967/1000
# 16/16 - 0s - loss: 0.0382 - root_mean_squared_error: 0.1955 - mean_absolute_error: 0.0141 - val_loss: 0.0898 - val_root_mean_squared_error: 0.2997 - val_mean_absolute_error: 0.0213 - 134ms/epoch - 8ms/step
# Epoch 968/1000
# 16/16 - 0s - loss: 0.0363 - root_mean_squared_error: 0.1906 - mean_absolute_error: 0.0146 - val_loss: 0.0925 - val_root_mean_squared_error: 0.3041 - val_mean_absolute_error: 0.0197 - 165ms/epoch - 10ms/step
# Epoch 969/1000
#
# Epoch 969: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.0392 - root_mean_squared_error: 0.1980 - mean_absolute_error: 0.0135 - val_loss: 0.0913 - val_root_mean_squared_error: 0.3021 - val_mean_absolute_error: 0.0210 - 260ms/epoch - 16ms/step
# Epoch 970/1000
# 16/16 - 0s - loss: 0.0368 - root_mean_squared_error: 0.1919 - mean_absolute_error: 0.0148 - val_loss: 0.1048 - val_root_mean_squared_error: 0.3238 - val_mean_absolute_error: 0.0249 - 136ms/epoch - 9ms/step
# Epoch 971/1000
# 16/16 - 0s - loss: 0.0424 - root_mean_squared_error: 0.2058 - mean_absolute_error: 0.0150 - val_loss: 0.0996 - val_root_mean_squared_error: 0.3156 - val_mean_absolute_error: 0.0193 - 163ms/epoch - 10ms/step
# Epoch 972/1000
# 16/16 - 0s - loss: 0.0374 - root_mean_squared_error: 0.1934 - mean_absolute_error: 0.0150 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3078 - val_mean_absolute_error: 0.0237 - 125ms/epoch - 8ms/step
# Epoch 973/1000
# 16/16 - 0s - loss: 0.0376 - root_mean_squared_error: 0.1939 - mean_absolute_error: 0.0147 - val_loss: 0.0954 - val_root_mean_squared_error: 0.3088 - val_mean_absolute_error: 0.0197 - 141ms/epoch - 9ms/step
# Epoch 974/1000
# 16/16 - 0s - loss: 0.0410 - root_mean_squared_error: 0.2026 - mean_absolute_error: 0.0152 - val_loss: 0.1045 - val_root_mean_squared_error: 0.3232 - val_mean_absolute_error: 0.0246 - 167ms/epoch - 10ms/step
# Epoch 975/1000
# 16/16 - 0s - loss: 0.0430 - root_mean_squared_error: 0.2073 - mean_absolute_error: 0.0144 - val_loss: 0.1055 - val_root_mean_squared_error: 0.3248 - val_mean_absolute_error: 0.0238 - 135ms/epoch - 8ms/step
# Epoch 976/1000
# 16/16 - 0s - loss: 0.0446 - root_mean_squared_error: 0.2111 - mean_absolute_error: 0.0157 - val_loss: 0.0959 - val_root_mean_squared_error: 0.3096 - val_mean_absolute_error: 0.0193 - 133ms/epoch - 8ms/step
# Epoch 977/1000
# 16/16 - 0s - loss: 0.0492 - root_mean_squared_error: 0.2219 - mean_absolute_error: 0.0164 - val_loss: 0.1111 - val_root_mean_squared_error: 0.3333 - val_mean_absolute_error: 0.0274 - 134ms/epoch - 8ms/step
# Epoch 978/1000
# 16/16 - 0s - loss: 0.0418 - root_mean_squared_error: 0.2043 - mean_absolute_error: 0.0154 - val_loss: 0.0875 - val_root_mean_squared_error: 0.2958 - val_mean_absolute_error: 0.0183 - 123ms/epoch - 8ms/step
# Epoch 979/1000
# 16/16 - 0s - loss: 0.0381 - root_mean_squared_error: 0.1951 - mean_absolute_error: 0.0169 - val_loss: 0.0932 - val_root_mean_squared_error: 0.3053 - val_mean_absolute_error: 0.0230 - 124ms/epoch - 8ms/step
# Epoch 980/1000
# 16/16 - 0s - loss: 0.0397 - root_mean_squared_error: 0.1993 - mean_absolute_error: 0.0152 - val_loss: 0.1023 - val_root_mean_squared_error: 0.3198 - val_mean_absolute_error: 0.0234 - 138ms/epoch - 9ms/step
# Epoch 981/1000
# 16/16 - 0s - loss: 0.0396 - root_mean_squared_error: 0.1991 - mean_absolute_error: 0.0140 - val_loss: 0.0974 - val_root_mean_squared_error: 0.3121 - val_mean_absolute_error: 0.0221 - 168ms/epoch - 10ms/step
# Epoch 982/1000
# 16/16 - 0s - loss: 0.0413 - root_mean_squared_error: 0.2032 - mean_absolute_error: 0.0154 - val_loss: 0.0983 - val_root_mean_squared_error: 0.3136 - val_mean_absolute_error: 0.0199 - 136ms/epoch - 9ms/step
# Epoch 983/1000
# 16/16 - 0s - loss: 0.0396 - root_mean_squared_error: 0.1989 - mean_absolute_error: 0.0149 - val_loss: 0.0997 - val_root_mean_squared_error: 0.3158 - val_mean_absolute_error: 0.0253 - 161ms/epoch - 10ms/step
# Epoch 984/1000
# 16/16 - 0s - loss: 0.0435 - root_mean_squared_error: 0.2085 - mean_absolute_error: 0.0173 - val_loss: 0.1008 - val_root_mean_squared_error: 0.3175 - val_mean_absolute_error: 0.0208 - 133ms/epoch - 8ms/step
# Epoch 985/1000
# 16/16 - 0s - loss: 0.0438 - root_mean_squared_error: 0.2094 - mean_absolute_error: 0.0158 - val_loss: 0.1112 - val_root_mean_squared_error: 0.3335 - val_mean_absolute_error: 0.0276 - 124ms/epoch - 8ms/step
# Epoch 986/1000
# 16/16 - 0s - loss: 0.0416 - root_mean_squared_error: 0.2041 - mean_absolute_error: 0.0153 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3203 - val_mean_absolute_error: 0.0199 - 130ms/epoch - 8ms/step
# Epoch 987/1000
# 16/16 - 0s - loss: 0.0384 - root_mean_squared_error: 0.1959 - mean_absolute_error: 0.0148 - val_loss: 0.0954 - val_root_mean_squared_error: 0.3088 - val_mean_absolute_error: 0.0221 - 144ms/epoch - 9ms/step
# Epoch 988/1000
# 16/16 - 0s - loss: 0.0401 - root_mean_squared_error: 0.2004 - mean_absolute_error: 0.0152 - val_loss: 0.1008 - val_root_mean_squared_error: 0.3174 - val_mean_absolute_error: 0.0229 - 170ms/epoch - 11ms/step
# Epoch 989/1000
# 16/16 - 0s - loss: 0.0388 - root_mean_squared_error: 0.1970 - mean_absolute_error: 0.0143 - val_loss: 0.0945 - val_root_mean_squared_error: 0.3074 - val_mean_absolute_error: 0.0193 - 133ms/epoch - 8ms/step
# Epoch 990/1000
# 16/16 - 0s - loss: 0.0440 - root_mean_squared_error: 0.2098 - mean_absolute_error: 0.0166 - val_loss: 0.1002 - val_root_mean_squared_error: 0.3166 - val_mean_absolute_error: 0.0240 - 160ms/epoch - 10ms/step
# Epoch 991/1000
# 16/16 - 0s - loss: 0.0355 - root_mean_squared_error: 0.1883 - mean_absolute_error: 0.0139 - val_loss: 0.0907 - val_root_mean_squared_error: 0.3011 - val_mean_absolute_error: 0.0203 - 131ms/epoch - 8ms/step
# Epoch 992/1000
# 16/16 - 0s - loss: 0.0430 - root_mean_squared_error: 0.2074 - mean_absolute_error: 0.0153 - val_loss: 0.0926 - val_root_mean_squared_error: 0.3043 - val_mean_absolute_error: 0.0227 - 161ms/epoch - 10ms/step
# Epoch 993/1000
# 16/16 - 0s - loss: 0.0435 - root_mean_squared_error: 0.2085 - mean_absolute_error: 0.0162 - val_loss: 0.0933 - val_root_mean_squared_error: 0.3055 - val_mean_absolute_error: 0.0199 - 139ms/epoch - 9ms/step
# Epoch 994/1000
# 16/16 - 0s - loss: 0.0400 - root_mean_squared_error: 0.2001 - mean_absolute_error: 0.0141 - val_loss: 0.0987 - val_root_mean_squared_error: 0.3142 - val_mean_absolute_error: 0.0229 - 135ms/epoch - 8ms/step
# Epoch 995/1000
# 16/16 - 0s - loss: 0.0381 - root_mean_squared_error: 0.1952 - mean_absolute_error: 0.0147 - val_loss: 0.0900 - val_root_mean_squared_error: 0.3001 - val_mean_absolute_error: 0.0213 - 128ms/epoch - 8ms/step
# Epoch 996/1000
# 16/16 - 0s - loss: 0.0409 - root_mean_squared_error: 0.2023 - mean_absolute_error: 0.0158 - val_loss: 0.0885 - val_root_mean_squared_error: 0.2974 - val_mean_absolute_error: 0.0189 - 143ms/epoch - 9ms/step
# Epoch 997/1000
# 16/16 - 0s - loss: 0.0378 - root_mean_squared_error: 0.1945 - mean_absolute_error: 0.0134 - val_loss: 0.0913 - val_root_mean_squared_error: 0.3021 - val_mean_absolute_error: 0.0223 - 121ms/epoch - 8ms/step
# Epoch 998/1000
# 16/16 - 0s - loss: 0.0391 - root_mean_squared_error: 0.1977 - mean_absolute_error: 0.0151 - val_loss: 0.0897 - val_root_mean_squared_error: 0.2995 - val_mean_absolute_error: 0.0194 - 131ms/epoch - 8ms/step
# Epoch 999/1000
# 16/16 - 0s - loss: 0.0427 - root_mean_squared_error: 0.2067 - mean_absolute_error: 0.0139 - val_loss: 0.0917 - val_root_mean_squared_error: 0.3029 - val_mean_absolute_error: 0.0232 - 171ms/epoch - 11ms/step
# Epoch 1000/1000
#
# Epoch 1000: saving model to dae_training_ft_kettle/cp.ckpt
# 16/16 - 0s - loss: 0.0407 - root_mean_squared_error: 0.2017 - mean_absolute_error: 0.0170 - val_loss: 0.0887 - val_root_mean_squared_error: 0.2979 - val_mean_absolute_error: 0.0189 - 242ms/epoch - 15ms/step

# %%
if not SKIP_TRAINING:
    print('Time spent', time_spent)
    plot_model_history(history)
# Out:
# Time spent 171.88990037999997
# dict_keys(['loss', 'root_mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error'])

# %%
def get_test_data(df_test, feature, ref_norm, seq_len, seq_per_batch):
    x_test = df_test[['mains_active']].values
    y_test = df_test[[feature]].values

    original_len = len(x_test)

    x_test = normalize(x_test, ref_norm)
    y_test = normalize(y_test, ref_norm)

    print('x_test.shape, y_test.shape')
    print(x_test.shape, y_test.shape)

    extra_test = seq_len - (len(x_test) % seq_len)

    x_test = np.append(x_test, np.zeros(extra_test))
    y_test = np.append(y_test, np.zeros(extra_test))

    x_test = np.reshape(x_test, (len(x_test) // seq_len, seq_len, 1))

    return x_test, y_test, original_len

def predict(model, feature, df_test, ref_norm, seq_len, seq_per_batch):
    x_test, y_test, original_len = get_test_data(df_test, feature=feature, ref_norm=ref_norm, seq_len=seq_len, seq_per_batch=seq_per_batch)

    y_pred = model.predict(x_test, batch_size=seq_per_batch)

    print('y_test.shape, y_pred.shape')
    print(y_test.shape, y_pred.shape)

    y_pred = np.reshape(y_pred, (y_test.shape[0]))[:original_len]
    y_test = y_test[:original_len]

    print('y_test.shape, y_pred.shape')
    print(y_test.shape, y_pred.shape)

    assert(y_test.shape == y_pred.shape)

    print('Normalized: y_test.mean, y_pred.mean')
    print(y_test.mean(), y_pred.mean())

    y_pred[y_pred < 0] = 0
    y_test = denormalize(y_test, ref_norm)
    y_pred = denormalize(y_pred, ref_norm)

    print('Denormalized: y_test.mean, y_pred.mean')
    print(y_test.mean(), y_pred.mean())

    return y_test, y_pred

# %%
# Predict from test split
y_test, y_pred = predict(model, feature=FEATURE, df_test=df_test, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH)
# Out:
# x_test.shape, y_test.shape
# (190700, 1) (190700, 1)
# 6/6 [==============================] - 0s 9ms/step
# y_test.shape, y_pred.shape
# (190720,) (5960, 32, 1)
# y_test.shape, y_pred.shape
# (190700,) (190700,)
# Normalized: y_test.mean, y_pred.mean
# 0.03981637957236118 0.033786435
# Denormalized: y_test.mean, y_pred.mean
# 12.943956508445407 10.983945

# %%
# plot_prediction_windows(FEATURE, y_test_denorm, y_pred_denorm)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=False, n_samples=n_samples)

# %%
n_samples = 80
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, active_factor=4, n_samples=n_samples)

# %%
n_samples = 200
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, n_samples=n_samples)

# %%
from lib import analysis
from lib.logging import losses_to_file, metrics_to_file

# %%
params = {}
params["algo"] = 'dae'
params["feature"] = FEATURE
params["seq_len"] = SEQ_LEN
params["seq_per_batch"] = SEQ_PER_BATCH
params["strides"] = N_STRIDES
params["epochs"] = EPOCHS
params["train_rows"] = df_train.shape[0]
params["val_rows"] = df_val.shape[0]
params["test_rows"] = df_test.shape[0]
params["norm_value"] = ref_norm
params["norm_type"] = NORM_TYPE
params["learning_rate"] = LEARNING_RATE
params["loss"] = 'adam'
params["clipvalue"] = CLIP_VALUE

# %%
print(params)
# Out:
# {'algo': 'dae', 'feature': 'ft_kettle', 'seq_len': 32, 'seq_per_batch': 1024, 'strides': 1, 'epochs': 1000, 'train_rows': 521300, 'val_rows': 316800, 'test_rows': 190700, 'norm_value': 325.09125, 'norm_type': 'mean', 'learning_rate': 0.001, 'loss': 'adam', 'clipvalue': 10.0}

# %%
results = analysis.classification_results(y_test, y_pred, on_threshold = 100)

metrics = {}
metrics["mae"] = analysis.mse_loss(y_test, y_pred)
metrics["mse"] = analysis.mae_loss(y_test, y_pred)
metrics["f1"] = analysis.f1(results)
metrics["accuracy"] = analysis.accuracy(results)
metrics["precision"] = analysis.precision(results)
metrics["recall"] = analysis.recall(results)

# %%
print(metrics)
# Out:
# {'mae': 8814.569378781385, 'mse': 5.809391283046113, 'f1': 0.721502011622709, 'accuracy': 0.9967330886208705, 'precision': 0.642515923566879, 'recall': 0.8226299694189603}

# %%
if not SKIP_TRAINING:
    losses_to_file(1, params, history.history)

# %%
metrics_to_file(1, params, metrics)
