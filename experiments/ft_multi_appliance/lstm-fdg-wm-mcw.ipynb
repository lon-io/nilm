# %%
# Constants
MAX_NO_ROWS = 1000000
LOAD_MODEL=True
SKIP_TRAINING=True
FEATURES = ['ft_fridge', 'ft_washing_machine', 'ft_microwave']
SEQ_PER_BATCH = 1024
SEQ_LEN = 32
N_STRIDES = 1
NORM_TYPE = 'max'
LEARNING_RATE = 1e-2
CLIP_VALUE = 10.
EPOCHS = 100
ALGO = 'lstm'
CHECKPOINT_PATH = f"{ALGO}_training_{'_'.join(FEATURES)}/cp.ckpt"

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Dissertation
# Out:
# /content/drive/My Drive/Colab Notebooks/Dissertation

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from lib.chunk_reader import read_labels, get_merged_chunks, get_dates
from lib.plotting import plot_ft_days, plot_model_history, plot_prediction_windows
from lib.analysis import print_heads_tails

# %%
labels = read_labels(1)
for house in range(1,2):
    print('House {}: '.format(house), labels[house], '\n')
# Out:
# House 1:  ['mains_active', 'mains_apparent', 'mains_rms', 'aggregate_apparent', 'ft_boiler', 'ft_solar_thermal_pump', 'ft_washing_machine', 'ft_dishwasher', 'ft_tv', 'ft_kitchen_lights', 'ft_htpc', 'ft_kettle', 'ft_toaster', 'ft_fridge', 'ft_microwave', 'ft_amp_livingroom', 'ft_adsl_router', 'ft_livingroom_s_lamp', 'ft_lighting_circuit', 'ft_subwoofer_livingroom', 'ft_livingroom_lamp_tv', 'ft_kitchen_phone&stereo', 'ft_coffee_machine', 'ft_gas_oven', 'ft_data_logger_pc', 'ft_office_lamp2', 'aggregate_active', 'unix_time']

# %%
ref_chunk_df = get_merged_chunks(1, 1)
print('Original DF shape', ref_chunk_df.shape)
print('---')
ref_chunk_df = ref_chunk_df[0:MAX_NO_ROWS]
# Out:
# reading house 1; chunk 1
# reading file data/ukdale-parsed-chunks/house_1/chunk_1.dat; for house 1 and chunk 1
# read house 1; chunk 1; df.shape is (4500000, 29)
# Original DF shape (4500000, 29)
# ---

# %%
dates = {}
# for house in range(1,2):
dates[1] = get_dates(ref_chunk_df, 1)
# Out:
# House 1 data contain 71 days from 2013-04-11 to 2013-06-20.
# ...

# %%
# Constants 2
rows_per_day = ref_chunk_df.loc[:dates[1][2]].shape[0]

# %%
from algos.processing import split_df_by_dates
from algos.multi.lstm import create_model
from algos.multi.cnn import train, predict
from algos.norm import get_ref_norm

# %%
# Separate house 1 data into train, validation and test data
df_train, df_val, df_test  =  split_df_by_dates(ref_chunk_df, dates=dates, house=1)
# Out:
# df_train.shape:  (521300, 29)
# df_val.shape:  (316800, 29)
# df_test.shape:  (190700, 29)

# %%
ref_norm = get_ref_norm(df_train, NORM_TYPE)
# Out:
# ref_mean: 325.09124755859375; ref_max: 6002.919921875; ref_std: 434.2580871582031
# norm_type: max; ref_norm 6002.919921875

# %%
model = create_model(seq_len=SEQ_LEN, learning_rate=LEARNING_RATE, clipvalue=CLIP_VALUE)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 32, 16)            80
#
#  bidirectional (Bidirectiona  (None, 32, 256)          148480
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 512)              1050624
#  nal)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 3)                 387
#
# ...
# Total params: 1,265,235
# Trainable params: 1,265,235
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !!!!!!!Counter!!!!!!! 
# Manually update for every new loaded training
# Run Counter = 0

# Load and or Train
if LOAD_MODEL:
  model.load_weights(CHECKPOINT_PATH)
if SKIP_TRAINING:
  pass
else:
  model, history, time_spent = train(model, features=FEATURES, df_train=df_train, df_val=df_val, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH, epochs=EPOCHS, checkpoint_path=CHECKPOINT_PATH)

# %%
if not SKIP_TRAINING:
    print('Time spent', time_spent)
    plot_model_history(history)

# %%
# Predict from test split
y_test, y_pred = predict(model, features=FEATURES, df_test=df_test, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH)
# Out:
# x_test.shape, y_test.shape
# (190700, 1) (190700, 3)
# mains.shape, meters.shape =>  (190700, 1) (190700, 3)
# self.data_len 190700
# seq_len 32
# n_sequences 190668
# x.shape, y.shape (190668, 32, 1) (190668, 3)
# seq_index 0
# seq_index 160000
# 187/187 [==============================] - 15s 32ms/step
# y_test.shape, y_pred.shape
# (190668, 3) (190668, 3)
# y_test.shape, y_pred.shape
# (190668, 3) (190668, 3)
# Normalized: y_test.mean, y_pred.mean
# 0.003337573 0.0028088165
# Denormalized: y_test.mean, y_pred.mean
# 20.035181 18.074709

# %%
FT_FDG, y_test_fdg,y_pred_fdg = FEATURES[0], y_test[:,0], y_pred[:,0]
FT_WM, y_test_wm,y_pred_wm = FEATURES[1], y_test[:,1], y_pred[:,1]
FT_MCW, y_test_mcw,y_pred_mcw = FEATURES[2], y_test[:,2], y_pred[:,2]

# %%
plot_prediction_windows(FT_FDG, y_test_fdg, y_pred_fdg)

# %%
plot_prediction_windows(FT_WM, y_test_wm,y_pred_wm)

# %%
plot_prediction_windows(FT_MCW, y_test_mcw,y_pred_mcw)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FT_FDG, y_test_fdg,y_pred_fdg, use_active=False, n_samples=n_samples)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FT_WM, y_test_wm,y_pred_wm, use_active=False, n_samples=n_samples)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FT_MCW, y_test_mcw,y_pred_mcw, use_active=False, n_samples=n_samples)

# %%
from lib import analysis
from lib.logging import losses_to_file, metrics_to_file

# %%
def report_results(feature, y_test, y_pred, on_threshold = 10):
    results = analysis.classification_results(y_test, y_pred, on_threshold = 10)

    metrics = {}
    metrics["mae"] = analysis.mse_loss(y_test, y_pred)
    metrics["mse"] = analysis.mae_loss(y_test, y_pred)
    metrics["f1"] = analysis.f1(results)
    metrics["accuracy"] = analysis.accuracy(results)
    metrics["precision"] = analysis.precision(results)
    metrics["recall"] = analysis.recall(results)

    return metrics

# %%
print(report_results(FT_FDG, y_test_fdg,y_pred_fdg, 10))
# Out:
# {'mae': 1778.807865891033, 'mse': 22.494533244728515, 'f1': 0.8058924187188454, 'accuracy': 0.8084314095705625, 'precision': 0.69013725561583, 'recall': 0.9683038336781346}

# %%
print(report_results(FT_WM, y_test_wm,y_pred_wm, 50))
# Out:
# {'mae': 2505.6546569774578, 'mse': 7.091408635215977, 'f1': 0.6586318276044931, 'accuracy': 0.9628621478171482, 'precision': 0.5013577981651376, 'recall': 0.9596796853048609}

# %%
print(report_results(FT_MCW, y_test_mcw,y_pred_mcw, 100))
# Out:
# {'mae': 5450.365148770924, 'mse': 6.168417517656079, 'f1': 0.3333333333333333, 'accuracy': 0.9869301613275432, 'precision': 0.20829154129053828, 'recall': 0.8340026773761714}
