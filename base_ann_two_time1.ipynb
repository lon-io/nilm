# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import display
import datetime
import time
import math
import warnings
warnings.filterwarnings("ignore")
import glob

# %%
def read_label():
    label = {}
    for i in range(1, 6):
        hi = 'data/ukdale/house_{}/labels.dat'.format(i)
        label[i] = {}
        with open(hi) as f:
            for line in f:
                splitted_line = line.split(' ')
                label[i][int(splitted_line[0])] = splitted_line[1].strip() + '_' + splitted_line[0]
        label[i]['mains'] = 'mains'
    return label
labels = read_label()
# for i in range(1,3):
#     print('House {}: '.format(i), labels[i], '\n')
for i in range(1,2):
    print('House {}: '.format(i), labels[i], '\n')
# Out:
# House 1:  {1: 'aggregate_1', 2: 'boiler_2', 3: 'solar_thermal_pump_3', 4: 'laptop_4', 5: 'washing_machine_5', 6: 'dishwasher_6', 7: 'tv_7', 8: 'kitchen_lights_8', 9: 'htpc_9', 10: 'kettle_10', 11: 'toaster_11', 12: 'fridge_12', 13: 'microwave_13', 14: 'lcd_office_14', 15: 'hifi_office_15', 16: 'breadmaker_16', 17: 'amp_livingroom_17', 18: 'adsl_router_18', 19: 'livingroom_s_lamp_19', 20: 'soldering_iron_20', 21: 'gigE_&_USBhub_21', 22: 'hoover_22', 23: 'kitchen_dt_lamp_23', 24: 'bedroom_ds_lamp_24', 25: 'lighting_circuit_25', 26: 'livingroom_s_lamp2_26', 27: 'iPad_charger_27', 28: 'subwoofer_livingroom_28', 29: 'livingroom_lamp_tv_29', 30: 'DAB_radio_livingroom_30', 31: 'kitchen_lamp2_31', 32: 'kitchen_phone&stereo_32', 33: 'utilityrm_lamp_33', 34: 'samsung_charger_34', 35: 'bedroom_d_lamp_35', 36: 'coffee_machine_36', 37: 'kitchen_radio_37', 38: 'bedroom_chargers_38', 39: 'hair_dryer_39', 40: 'straighteners_40', 41: 'iron_41', 42: 'gas_oven_42', 43: 'data_logger_pc_43', 44: 'childs_table_lamp_44', 45: 'childs_ds_lamp_45', 46: 'baby_monitor_tx_46', 47: 'battery_charger_47', 48: 'office_lamp1_48', 49: 'office_lamp2_49', 50: 'office_lamp3_50', 51: 'office_pc_51', 52: 'office_fan_52', 53: 'LED_printer_53', 'mains': 'mains'}

# %%
def get_house_path(house):
    return f'data/ukdale/house_{house}/'
    
def get_chan_path(house, channel):
    return get_house_path(house) + f'channel_{channel}.dat'

def get_num_apps(house):
    return len(glob.glob(get_house_path(house) + 'channel_*[0-9].dat'))

def read_file(house, channel):
    file = get_chan_path(house, channel)
    
    df = pd.read_table(file, sep = ' ', names = ['unix_time', labels[house][channel]], 
                                       dtype = {'unix_time': 'int64', labels[house][channel]:'float64'}) 

    return df

def parse_data(df, sort_index = True, drop_duplicates = True):
#     df.insert(0, 'line_nr', range(0, len(df)))
    df['timestamp'] = df['unix_time'].astype("datetime64[s]")
    df = df.set_index(df['timestamp'].values)
    df.drop(['unix_time'], axis=1, inplace=True)

#     tz = 'US/Eastern'
#     # Convert the integer index column to timezone-aware datetime 
#     df.index = pd.to_datetime(df.index.values, unit='s', utc=True)
#     df = df.tz_convert(tz)

    if sort_index:
        df = df.sort_index() # raw REDD data isn't always sorted
        
        
#     df.drop(['unix_time','timestamp'], axis=1, inplace=True)
        
    if drop_duplicates:
        dups_in_index = df.index.duplicated(keep='first')
        if dups_in_index.any():
#             print('Data has duplicates', house, channel, dups_in_index[dups_in_index == True])
            df = df[~dups_in_index]

    return df

def get_timeframe(df):
    start = df.index[0]
    end = df.index[-1]
    
    return start, end

# %%
DATA_SIZE_LIMIT = 17000000

# %%
parsed_labels = {}
def parse_labels(house):
    parsed_labels[house] = {}
    parsed_labels[house][1] = labels[house][1]
    num_apps = get_num_apps(house)
    
    for i in range(2, num_apps + 1):
        data = read_file(house, i)
        
        if data.shape[0] >= DATA_SIZE_LIMIT:
            if i == 2 or i % 7 == 0: 
                print('parsing label', house, i)
            parsed_labels[house][i] = labels[house][i]
            
    return parsed_labels

# %%
for i in range(1,2):
    parsed_labels = parse_labels(i)
# Out:
# parsing label 1 2
# parsing label 1 7
# parsing label 1 28
# parsing label 1 35
# parsing label 1 42
# parsing label 1 49

# %%
def read_merge_data(house):
    print(f'reading house {house}; channel {1}');
    df = read_file(house, 1)
    df = parse_data(df)
    path = f'data/ukdale/house_{house}/'

    #     file = path + 'mains.dat'
#     df = pd.read_table(file, sep = ' ', names = ['unix_time', 'mains_active_p_w', 'mains_apparent_p_va', 'mains_rms_v' ], 
#                                        dtype = {'unix_time': 'float64', 'mains_active_p_w':'float64', 'mains_apparent_p_va': 'float64', 'mains_rms_v': 'float64'}) 
#     df['timestamp'] = df['unix_time'].astype("datetime64[s]")
    
    num_apps = get_num_apps(house)


    # tv_7, fridge_12, microwave_13, gas_oven_42
#     for i in [7, 52, 53]:
    for i in range(2, num_apps + 1):
        data = read_file(house, i)
        if data.shape[0] >= DATA_SIZE_LIMIT:
            print(f'reading house {house}; channel {i}; df.shape is {df.shape}; data.shape is {data.shape}')
            data = parse_data(data)

            start_x, end_x = get_timeframe(data)
            start_y, end_y = get_timeframe(df)

            start = start_x if start_x > start_y else start_y
            end = end_x if end_x < end_y else end_y

            data = data[(data.index >= start) &
                                   (data.index <= end)]
            df = df[(df.index >= start) &
                                   (df.index <= end)]

            df = pd.merge_asof(df, data, on = 'timestamp', tolerance=pd.Timedelta('6s'))
            df = df.set_index(df['timestamp'].values)
        else:
            print(f'skipping house {house}; channel {i}; df.shape is {df.shape}; data.shape is {data.shape}')
#         df = pd.merge(df, data, how = 'inner', on = 'unix_time')

    return df

df = {}
# for i in range(1,3):
#     df[i] = read_merge_data(i)
for i in range(1,2):
    df[i] = read_merge_data(i)
# Out:
# reading house 1; channel 1
# reading house 1; channel 2; df.shape is (21837636, 2); data.shape is (21281331, 2)
# reading house 1; channel 3; df.shape is (21837634, 3); data.shape is (21281208, 2)
# skipping house 1; channel 4; df.shape is (21837632, 4); data.shape is (4539118, 2)
# reading house 1; channel 5; df.shape is (21837632, 4); data.shape is (19555935, 2)
# reading house 1; channel 6; df.shape is (21837632, 5); data.shape is (19819392, 2)
# reading house 1; channel 7; df.shape is (21837632, 6); data.shape is (19763329, 2)
# reading house 1; channel 8; df.shape is (21837632, 7); data.shape is (21449386, 2)
# reading house 1; channel 9; df.shape is (21802477, 8); data.shape is (19543268, 2)
# reading house 1; channel 10; df.shape is (21568110, 9); data.shape is (18881051, 2)
# reading house 1; channel 11; df.shape is (21568110, 10); data.shape is (19404267, 2)
# reading house 1; channel 12; df.shape is (21568110, 11); data.shape is (19381298, 2)
# reading house 1; channel 13; df.shape is (21568110, 12); data.shape is (19406625, 2)
# skipping house 1; channel 14; df.shape is (21568110, 13); data.shape is (4143648, 2)
# skipping house 1; channel 15; df.shape is (21568110, 13); data.shape is (4157704, 2)
# skipping house 1; channel 16; df.shape is (21568110, 13); data.shape is (13351860, 2)
# reading house 1; channel 17; df.shape is (21568110, 13); data.shape is (19547699, 2)
# reading house 1; channel 18; df.shape is (21568110, 14); data.shape is (19116542, 2)
# reading house 1; channel 19; df.shape is (21217277, 15); data.shape is (18609054, 2)
# skipping house 1; channel 20; df.shape is (20779414, 16); data.shape is (617699, 2)
# skipping house 1; channel 21; df.shape is (20779414, 16); data.shape is (3602216, 2)
# skipping house 1; channel 22; df.shape is (20779414, 16); data.shape is (134467, 2)
# skipping house 1; channel 23; df.shape is (20779414, 16); data.shape is (10670426, 2)
# skipping house 1; channel 24; df.shape is (20779414, 16); data.shape is (16218474, 2)
# reading house 1; channel 25; df.shape is (20779414, 16); data.shape is (20785844, 2)
# reading house 1; channel 26; df.shape is (20435000, 17); data.shape is (18618217, 2)
# skipping house 1; channel 27; df.shape is (20434888, 18); data.shape is (12253298, 2)
# reading house 1; channel 28; df.shape is (20434888, 18); data.shape is (18645123, 2)
# reading house 1; channel 29; df.shape is (20434887, 19); data.shape is (18651142, 2)
# skipping house 1; channel 30; df.shape is (20434887, 20); data.shape is (677711, 2)
# skipping house 1; channel 31; df.shape is (20434887, 20); data.shape is (11355561, 2)
# reading house 1; channel 32; df.shape is (20434887, 20); data.shape is (18497094, 2)
# reading house 1; channel 33; df.shape is (20416085, 21); data.shape is (17439431, 2)
# reading house 1; channel 34; df.shape is (20416085, 22); data.shape is (17003826, 2)
# reading house 1; channel 35; df.shape is (20416085, 23); data.shape is (17934605, 2)
# reading house 1; channel 36; df.shape is (20416085, 24); data.shape is (17304547, 2)
# reading house 1; channel 37; df.shape is (20237178, 25); data.shape is (18506920, 2)
# skipping house 1; channel 38; df.shape is (20237178, 26); data.shape is (12207918, 2)
# skipping house 1; channel 39; df.shape is (20237178, 26); data.shape is (181497, 2)
# skipping house 1; channel 40; df.shape is (20237178, 26); data.shape is (45239, 2)
# skipping house 1; channel 41; df.shape is (20237178, 26); data.shape is (7160, 2)
# reading house 1; channel 42; df.shape is (20237178, 26); data.shape is (18185875, 2)
# reading house 1; channel 43; df.shape is (20223873, 27); data.shape is (18621408, 2)
# reading house 1; channel 44; df.shape is (20223873, 28); data.shape is (18327970, 2)
# reading house 1; channel 45; df.shape is (20216769, 29); data.shape is (18004938, 2)
# reading house 1; channel 46; df.shape is (20216769, 30); data.shape is (17820706, 2)
# skipping house 1; channel 47; df.shape is (20216769, 31); data.shape is (13333663, 2)
# reading house 1; channel 48; df.shape is (20216769, 31); data.shape is (18179281, 2)
# reading house 1; channel 49; df.shape is (19843093, 32); data.shape is (17649667, 2)
# skipping house 1; channel 50; df.shape is (19843093, 33); data.shape is (3323283, 2)
# skipping house 1; channel 51; df.shape is (19843093, 33); data.shape is (3391394, 2)
# skipping house 1; channel 52; df.shape is (19843093, 33); data.shape is (2632277, 2)
# skipping house 1; channel 53; df.shape is (19843093, 33); data.shape is (2977937, 2)

# %%
print(parsed_labels)
# Out:
# {1: {1: 'aggregate_1', 2: 'boiler_2', 3: 'solar_thermal_pump_3', 5: 'washing_machine_5', 6: 'dishwasher_6', 7: 'tv_7', 8: 'kitchen_lights_8', 9: 'htpc_9', 10: 'kettle_10', 11: 'toaster_11', 12: 'fridge_12', 13: 'microwave_13', 17: 'amp_livingroom_17', 18: 'adsl_router_18', 19: 'livingroom_s_lamp_19', 25: 'lighting_circuit_25', 26: 'livingroom_s_lamp2_26', 28: 'subwoofer_livingroom_28', 29: 'livingroom_lamp_tv_29', 32: 'kitchen_phone&stereo_32', 33: 'utilityrm_lamp_33', 34: 'samsung_charger_34', 35: 'bedroom_d_lamp_35', 36: 'coffee_machine_36', 37: 'kitchen_radio_37', 42: 'gas_oven_42', 43: 'data_logger_pc_43', 44: 'childs_table_lamp_44', 45: 'childs_ds_lamp_45', 46: 'baby_monitor_tx_46', 48: 'office_lamp1_48', 49: 'office_lamp2_49'}}

# %%
def print_heads_tails(df_local= df, h=True,t=True):
    for i in range(1,2):
        print('House {} data has shape: '.format(i), df[i].shape)
        if h:
            display(df_local[i].head(2))

        print()

        if t:
            display(df_local[i].tail(2))

print_heads_tails(t=False)
# Out:
# House 1 data has shape:  (19843093, 33)
#                      aggregate_1           timestamp  boiler_2  \
# 2013-04-11 19:09:00        675.0 2013-04-11 19:09:00       0.0
# 2013-04-11 19:09:06        679.0 2013-04-11 19:09:06      12.0
#
#                      solar_thermal_pump_3  washing_machine_5  dishwasher_6  \
# 2013-04-11 19:09:00                   0.0                0.0           1.0
# 2013-04-11 19:09:06                   0.0                0.0           1.0
#
#                      tv_7  kitchen_lights_8  htpc_9  kettle_10  ...  \
# 2013-04-11 19:09:00  97.0               0.0    88.0        1.0  ...
# 2013-04-11 19:09:06  96.0               0.0    68.0        1.0  ...
#
#                      bedroom_d_lamp_35  coffee_machine_36  kitchen_radio_37  \
# 2013-04-11 19:09:00                0.0                1.0               1.0
# 2013-04-11 19:09:06                0.0                1.0               1.0
#
#                      gas_oven_42  data_logger_pc_43  childs_table_lamp_44  \
# 2013-04-11 19:09:00         46.0               12.0                   0.0
# 2013-04-11 19:09:06         46.0               13.0                   0.0
#
#                      childs_ds_lamp_45  baby_monitor_tx_46  office_lamp1_48  \
# 2013-04-11 19:09:00                0.0                 0.0             14.0
# 2013-04-11 19:09:06                0.0                 0.0             14.0
#
#                      office_lamp2_49
# 2013-04-11 19:09:00              NaN
# 2013-04-11 19:09:06             10.0
#
# [2 rows x 33 columns]

# %%
for i in range(1,2):
    path = f'data/ukdale/house_{i}/'
    num_apps = len(glob.glob(path + 'channel_*[0-9].dat'))
    for j in range(1, num_apps + 1):
        if j in parsed_labels[i] and df[i][parsed_labels[i][j]].isnull().sum() > 0:
            print(f'interpolating house {i}; channel {j}; {parsed_labels[i][j]}. prev NaN count was {df[i][parsed_labels[i][j]].isnull().sum()}')
            df[i][parsed_labels[i][j]].interpolate(method='linear', inplace=True)
            df[i][parsed_labels[i][j]].fillna(0.0, inplace=True)
# Out:
# interpolating house 1; channel 2; boiler_2. prev NaN count was 765506
# interpolating house 1; channel 3; solar_thermal_pump_3. prev NaN count was 765514
# interpolating house 1; channel 5; washing_machine_5. prev NaN count was 1667216
# interpolating house 1; channel 6; dishwasher_6. prev NaN count was 1369906
# interpolating house 1; channel 7; tv_7. prev NaN count was 1389617
# interpolating house 1; channel 8; kitchen_lights_8. prev NaN count was 445893
# interpolating house 1; channel 9; htpc_9. prev NaN count was 1352039
# interpolating house 1; channel 10; kettle_10. prev NaN count was 2095235
# interpolating house 1; channel 11; toaster_11. prev NaN count was 1488614
# interpolating house 1; channel 12; fridge_12. prev NaN count was 1504595
# interpolating house 1; channel 13; microwave_13. prev NaN count was 1498069
# interpolating house 1; channel 17; amp_livingroom_17. prev NaN count was 1352802
# interpolating house 1; channel 18; adsl_router_18. prev NaN count was 1385381
# interpolating house 1; channel 19; livingroom_s_lamp_19. prev NaN count was 1740171
# interpolating house 1; channel 26; livingroom_s_lamp2_26. prev NaN count was 1397774
# interpolating house 1; channel 28; subwoofer_livingroom_28. prev NaN count was 1415085
# interpolating house 1; channel 29; livingroom_lamp_tv_29. prev NaN count was 1369406
# interpolating house 1; channel 32; kitchen_phone&stereo_32. prev NaN count was 1471211
# interpolating house 1; channel 33; utilityrm_lamp_33. prev NaN count was 2272532
# interpolating house 1; channel 34; samsung_charger_34. prev NaN count was 2963061
# interpolating house 1; channel 35; bedroom_d_lamp_35. prev NaN count was 2035960
# interpolating house 1; channel 36; coffee_machine_36. prev NaN count was 2277183
# interpolating house 1; channel 37; kitchen_radio_37. prev NaN count was 1505743
# interpolating house 1; channel 42; gas_oven_42. prev NaN count was 1779866
# interpolating house 1; channel 43; data_logger_pc_43. prev NaN count was 1311319
# interpolating house 1; channel 44; childs_table_lamp_44. prev NaN count was 1347050
# interpolating house 1; channel 45; childs_ds_lamp_45. prev NaN count was 1989641
# interpolating house 1; channel 46; baby_monitor_tx_46. prev NaN count was 2218190
# interpolating house 1; channel 48; office_lamp1_48. prev NaN count was 1478304
# interpolating house 1; channel 49; office_lamp2_49. prev NaN count was 2036843

# %%
print_heads_tails()
# Out:
# House 1 data has shape:  (19843093, 33)
#                      aggregate_1           timestamp  boiler_2  \
# 2013-04-11 19:09:00        675.0 2013-04-11 19:09:00       0.0
# 2013-04-11 19:09:06        679.0 2013-04-11 19:09:06      12.0
#
#                      solar_thermal_pump_3  washing_machine_5  dishwasher_6  \
# 2013-04-11 19:09:00                   0.0                0.0           1.0
# 2013-04-11 19:09:06                   0.0                0.0           1.0
#
#                      tv_7  kitchen_lights_8  htpc_9  kettle_10  ...  \
# 2013-04-11 19:09:00  97.0               0.0    88.0        1.0  ...
# 2013-04-11 19:09:06  96.0               0.0    68.0        1.0  ...
#
#                      bedroom_d_lamp_35  coffee_machine_36  kitchen_radio_37  \
# 2013-04-11 19:09:00                0.0                1.0               1.0
# 2013-04-11 19:09:06                0.0                1.0               1.0
#
#                      gas_oven_42  data_logger_pc_43  childs_table_lamp_44  \
# 2013-04-11 19:09:00         46.0               12.0                   0.0
# 2013-04-11 19:09:06         46.0               13.0                   0.0
#
#                      childs_ds_lamp_45  baby_monitor_tx_46  office_lamp1_48  \
# 2013-04-11 19:09:00                0.0                 0.0             14.0
# 2013-04-11 19:09:06                0.0                 0.0             14.0
#
#                      office_lamp2_49
# 2013-04-11 19:09:00              0.0
# 2013-04-11 19:09:06             10.0
#
# [2 rows x 33 columns]
#                      aggregate_1           timestamp  boiler_2  \
# 2017-03-19 10:58:50       2534.0 2017-03-19 10:58:50      13.0
# 2017-03-19 10:58:57       2526.0 2017-03-19 10:58:57      12.0
#
#                      solar_thermal_pump_3  washing_machine_5  dishwasher_6  \
# 2017-03-19 10:58:50                  51.0             2198.5           1.0
# 2017-03-19 10:58:57                  51.0             2157.0           1.0
#
#                      tv_7  kitchen_lights_8  htpc_9  kettle_10  ...  \
# 2017-03-19 10:58:50   0.0               0.0     3.5        1.0  ...
# 2017-03-19 10:58:57   0.0               0.0     4.0        1.0  ...
#
#                      bedroom_d_lamp_35  coffee_machine_36  kitchen_radio_37  \
# 2017-03-19 10:58:50                0.0                1.0               1.0
# 2017-03-19 10:58:57                0.0                1.0               1.0
#
#                      gas_oven_42  data_logger_pc_43  childs_table_lamp_44  \
# 2017-03-19 10:58:50          3.0               13.0                   0.0
# 2017-03-19 10:58:57          3.0               14.0                   0.0
#
#                      childs_ds_lamp_45  baby_monitor_tx_46  office_lamp1_48  \
# 2017-03-19 10:58:50                8.0                 0.0              0.5
# 2017-03-19 10:58:57                8.0                 0.0              1.0
#
#                      office_lamp2_49
# 2017-03-19 10:58:50              0.0
# 2017-03-19 10:58:57              0.0
#
# [2 rows x 33 columns]

# %%
def add_time_slice_feature(df):
    for i in range(1,2):
        df[i]['timeslice'] = df[i].timestamp.dt.hour

add_time_slice_feature(df)

# %%
def re_add_unix_time_feature(df):
    df['unix_time'] = df.timestamp.map(pd.Timestamp.timestamp)
    df = df.set_index(df['unix_time'].values)
    df.drop(['timestamp'], axis=1, inplace=True)
    
    return df

# %%
new_df = {}
for i in range(1,2):
    new_df[i] = re_add_unix_time_feature(df[i])
print_heads_tails(new_df)
# Out:
# House 1 data has shape:  (19843093, 35)
#               aggregate_1  boiler_2  solar_thermal_pump_3  washing_machine_5  \
# 1.365707e+09        675.0       0.0                   0.0                0.0
# 1.365707e+09        679.0      12.0                   0.0                0.0
#
#               dishwasher_6  tv_7  kitchen_lights_8  htpc_9  kettle_10  \
# 1.365707e+09           1.0  97.0               0.0    88.0        1.0
# 1.365707e+09           1.0  96.0               0.0    68.0        1.0
#
#               toaster_11  ...  kitchen_radio_37  gas_oven_42  \
# 1.365707e+09         0.0  ...               1.0         46.0
# 1.365707e+09         0.0  ...               1.0         46.0
#
#               data_logger_pc_43  childs_table_lamp_44  childs_ds_lamp_45  \
# 1.365707e+09               12.0                   0.0                0.0
# 1.365707e+09               13.0                   0.0                0.0
#
#               baby_monitor_tx_46  office_lamp1_48  office_lamp2_49  timeslice  \
# 1.365707e+09                 0.0             14.0              0.0         19
# 1.365707e+09                 0.0             14.0             10.0         19
#
#                  unix_time
# 1.365707e+09  1.365707e+09
# 1.365707e+09  1.365707e+09
#
# [2 rows x 34 columns]
#               aggregate_1  boiler_2  solar_thermal_pump_3  washing_machine_5  \
# 1.489921e+09       2534.0      13.0                  51.0             2198.5
# 1.489921e+09       2526.0      12.0                  51.0             2157.0
#
#               dishwasher_6  tv_7  kitchen_lights_8  htpc_9  kettle_10  \
# 1.489921e+09           1.0   0.0               0.0     3.5        1.0
# 1.489921e+09           1.0   0.0               0.0     4.0        1.0
#
#               toaster_11  ...  kitchen_radio_37  gas_oven_42  \
# 1.489921e+09         0.0  ...               1.0          3.0
# 1.489921e+09         0.0  ...               1.0          3.0
#
#               data_logger_pc_43  childs_table_lamp_44  childs_ds_lamp_45  \
# 1.489921e+09               13.0                   0.0                8.0
# 1.489921e+09               14.0                   0.0                8.0
#
#               baby_monitor_tx_46  office_lamp1_48  office_lamp2_49  timeslice  \
# 1.489921e+09                 0.0              0.5              0.0         10
# 1.489921e+09                 0.0              1.0              0.0         10
#
#                  unix_time
# 1.489921e+09  1.489921e+09
# 1.489921e+09  1.489921e+09
#
# [2 rows x 34 columns]

# %% [markdown]
# ### Drop Low Power Devices

# %%
averages = {}
def get_devices_mean_power(df):
    for house in range(1,2):
        averages[house] = {}
        averages[house]['list'] = []
        averages[house]['map'] = {}
        num_apps = get_num_apps(i)
        for chan in range(1, num_apps + 1):
            if chan in parsed_labels[house]:
                label = parsed_labels[house][chan]
                mean = df[house][label].mean()
                averages[house]['list'].append((label, mean),)
                averages[house]['map'][label] = mean

get_devices_mean_power(df)

# %%
for house in range(1,2):
    sorted_averages = sorted(averages[house]['list'], key=lambda x: x[1])
    for chan, avg in reversed(sorted_averages):
        print(chan, (25 - len(chan)) * " ",  avg)
# Out:
# aggregate_1                374.7432447653196
# fridge_12                  40.547284563953816
# lighting_circuit_25        28.326183423118565
# washing_machine_5          24.559641684892572
# dishwasher_6               24.099111665706552
# kitchen_lights_8           19.661100716506244
# htpc_9                     18.980325597425765
# boiler_2                   17.961991409302975
# data_logger_pc_43          13.461728799033498
# kettle_10                  13.258863877723094
# tv_7                       12.967296706214096
# solar_thermal_pump_3       9.938443996608795
# toaster_11                 7.458045023525314
# adsl_router_18             7.20151125129535
# microwave_13               7.079313970861297
# gas_oven_42                3.903755352051215
# amp_livingroom_17          3.5976847964175747
# livingroom_s_lamp_19       3.3603978472509293
# subwoofer_livingroom_28    3.3177215366576167
# kitchen_phone&stereo_32    2.8671032283122395
# coffee_machine_36          2.079081572615721
# livingroom_lamp_tv_29      1.3725727385342597
# office_lamp2_49            1.141394338070179
# kitchen_radio_37           0.9427548416973099
# livingroom_s_lamp2_26      0.9031685735686468
# utilityrm_lamp_33          0.7255403933247707
# office_lamp1_48            0.5470053736078342
# bedroom_d_lamp_35          0.474718281066364
# childs_ds_lamp_45          0.32077872134147634
# samsung_charger_34         0.3170368399724781
# baby_monitor_tx_46         0.020332314120585938
# childs_table_lamp_44       0.012246654289227995

# %%
print_heads_tails(t=False)
# Out:
# House 1 data has shape:  (19843093, 35)
#                      aggregate_1           timestamp  boiler_2  \
# 2013-04-11 19:09:00        675.0 2013-04-11 19:09:00       0.0
# 2013-04-11 19:09:06        679.0 2013-04-11 19:09:06      12.0
#
#                      solar_thermal_pump_3  washing_machine_5  dishwasher_6  \
# 2013-04-11 19:09:00                   0.0                0.0           1.0
# 2013-04-11 19:09:06                   0.0                0.0           1.0
#
#                      tv_7  kitchen_lights_8  htpc_9  kettle_10  ...  \
# 2013-04-11 19:09:00  97.0               0.0    88.0        1.0  ...
# 2013-04-11 19:09:06  96.0               0.0    68.0        1.0  ...
#
#                      kitchen_radio_37  gas_oven_42  data_logger_pc_43  \
# 2013-04-11 19:09:00               1.0         46.0               12.0
# 2013-04-11 19:09:06               1.0         46.0               13.0
#
#                      childs_table_lamp_44  childs_ds_lamp_45  \
# 2013-04-11 19:09:00                   0.0                0.0
# 2013-04-11 19:09:06                   0.0                0.0
#
#                      baby_monitor_tx_46  office_lamp1_48  office_lamp2_49  \
# 2013-04-11 19:09:00                 0.0             14.0              0.0
# 2013-04-11 19:09:06                 0.0             14.0             10.0
#
#                      timeslice            unix_time
# 2013-04-11 19:09:00         19  1365707340000000000
# 2013-04-11 19:09:06         19  1365707346000000000
#
# [2 rows x 35 columns]

# %%
dates = {}
for i in range(1,2):
    dates[i] = [str(time)[:10] for time in df[i].index.values]
    dates[i] = sorted(list(set(dates[i])))
    print('House {0} data contain {1} days from {2} to {3}.'.format(i,len(dates[i]),dates[i][0], dates[i][-1]))
    print(dates[i], '\n')
# Out:
# House 1 data contain 1431 days from 2013-04-11 to 2017-03-19.
# ['2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05-13', '2013-05-14', '2013-05-15', '2013-05-16', '2013-05-17', '2013-05-18', '2013-05-19', '2013-05-20', '2013-05-21', '2013-05-22', '2013-05-23', '2013-05-24', '2013-05-25', '2013-05-26', '2013-05-27', '2013-05-28', '2013-05-29', '2013-05-30', '2013-05-31', '2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04', '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08', '2013-06-09', '2013-06-10', '2013-06-11', '2013-06-12', '2013-06-13', '2013-06-14', '2013-06-15', '2013-06-16', '2013-06-17', '2013-06-18', '2013-06-19', '2013-06-20', '2013-06-21', '2013-06-22', '2013-06-23', '2013-06-24', '2013-06-25', '2013-06-26', '2013-06-27', '2013-06-28', '2013-06-29', '2013-06-30', '2013-07-01', '2013-07-02', '2013-07-03', '2013-07-04', '2013-07-05', '2013-07-06', '2013-07-07', '2013-07-08', '2013-07-09', '2013-07-10', '2013-07-11', '2013-07-12', '2013-07-13', '2013-07-14', '2013-07-15', '2013-07-16', '2013-07-17', '2013-07-18', '2013-07-19', '2013-07-20', '2013-07-21', '2013-07-22', '2013-07-23', '2013-07-24', '2013-07-25', '2013-07-26', '2013-07-27', '2013-07-28', '2013-07-29', '2013-07-30', '2013-07-31', '2013-08-01', '2013-08-02', '2013-08-03', '2013-08-04', '2013-08-05', '2013-08-06', '2013-08-07', '2013-08-08', '2013-08-09', '2013-08-10', '2013-08-11', '2013-08-12', '2013-08-13', '2013-08-14', '2013-08-15', '2013-08-16', '2013-08-17', '2013-08-18', '2013-08-19', '2013-08-20', '2013-08-21', '2013-08-22', '2013-08-23', '2013-08-24', '2013-08-25', '2013-08-26', '2013-08-27', '2013-08-28', '2013-08-29', '2013-08-30', '2013-08-31', '2013-09-01', '2013-09-02', '2013-09-03', '2013-09-04', '2013-09-05', '2013-09-06', '2013-09-07', '2013-09-08', '2013-09-09', '2013-09-10', '2013-09-11', '2013-09-12', '2013-09-13', '2013-09-14', '2013-09-15', '2013-09-16', '2013-09-17', '2013-09-18', '2013-09-19', '2013-09-20', '2013-09-21', '2013-09-22', '2013-09-23', '2013-09-24', '2013-09-25', '2013-09-26', '2013-09-27', '2013-09-28', '2013-09-29', '2013-09-30', '2013-10-01', '2013-10-02', '2013-10-03', '2013-10-04', '2013-10-05', '2013-10-06', '2013-10-07', '2013-10-08', '2013-10-09', '2013-10-10', '2013-10-11', '2013-10-12', '2013-10-13', '2013-10-14', '2013-10-15', '2013-10-16', '2013-10-17', '2013-10-18', '2013-10-19', '2013-10-20', '2013-10-21', '2013-10-22', '2013-10-23', '2013-10-24', '2013-10-25', '2013-10-26', '2013-10-27', '2013-10-28', '2013-10-29', '2013-10-30', '2013-10-31', '2013-11-01', '2013-11-02', '2013-11-03', '2013-11-04', '2013-11-05', '2013-11-06', '2013-11-07', '2013-11-08', '2013-11-09', '2013-11-10', '2013-11-11', '2013-11-12', '2013-11-13', '2013-11-14', '2013-11-15', '2013-11-16', '2013-11-17', '2013-11-18', '2013-11-19', '2013-11-20', '2013-11-21', '2013-11-22', '2013-11-23', '2013-11-24', '2013-11-25', '2013-11-26', '2013-11-27', '2013-11-28', '2013-11-29', '2013-11-30', '2013-12-01', '2013-12-02', '2013-12-03', '2013-12-04', '2013-12-05', '2013-12-06', '2013-12-07', '2013-12-08', '2013-12-09', '2013-12-10', '2013-12-11', '2013-12-12', '2013-12-13', '2013-12-14', '2013-12-15', '2013-12-16', '2013-12-17', '2013-12-18', '2013-12-19', '2013-12-20', '2013-12-21', '2013-12-22', '2013-12-23', '2013-12-24', '2013-12-25', '2013-12-26', '2013-12-27', '2013-12-28', '2013-12-29', '2013-12-30', '2013-12-31', '2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04', '2014-01-05', '2014-01-06', '2014-01-07', '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-11', '2014-01-12', '2014-01-13', '2014-01-14', '2014-01-15', '2014-01-16', '2014-01-17', '2014-01-18', '2014-01-19', '2014-01-20', '2014-01- ...

# %%
# Plot 2 first day data of house 1 and 2
# def plot_df(df, title):
#     apps = df.columns.values
#     num_apps = len(apps) 
#     fig, axes = plt.subplots((num_apps+1)//2,2, figsize=(24, num_apps*2) )
#     for i, key in enumerate(apps):
#         axes.flat[i].plot(df[key], alpha = 0.6)
#         axes.flat[i].set_title(key, fontsize = '15')
#     plt.suptitle(title, fontsize = '30')
#     fig.tight_layout()
#     fig.subplots_adjust(top=0.95)

# for i in range(1,2):
#     plot_df(df[i].ix[:dates[i][50]], 'First 50 day data of house {}'.format(i))

# %% [markdown]
# ### Dump Data into new CSVs

# %%
import pathlib
newDataDir = 'data/ukdale-parsed';
pathlib.Path(newDataDir).mkdir(parents=True, exist_ok=True) 

for house in range(1,2):
    houseDir = f"{newDataDir}/house_{house}"
    pathlib.Path(houseDir).mkdir(parents=True, exist_ok=True)

# %%
def df_to_csv(house, chan, df):
    file_name = f"{newDataDir}/house_{house}/channel_{chan}.dat"
    df.to_csv(file_name, sep = ' ')
    
def label_to_txt(house, chan, label):
    file_name = f"{newDataDir}/house_{house}/labels.dat"
    mode = "w" if chan == 1 else "a"
    with open(file_name, mode) as file:
        file.write(f"{chan} {label}\n")

# %%
for house in range(1,2):
    num_apps = get_num_apps(i)
    for chan in range(1, num_apps + 1):
        if chan in parsed_labels[house]:
            label = parsed_labels[house][chan]
            label_split = label.split(f"_{chan}")[0]
            mean = averages[house]['map'][label]
            
            if mean > 1.0:
                print(f'saving house data and label to new files for house - {house} chan - {chan} label - {label_split}')
                label_to_txt(house, chan, label_split)
                df_to_csv(house, chan, new_df[house][label])
            else:
                print(f'skipping house data and label due to low mean - {mean} - {house} chan - {chan} label - {label_split}')
# Out:
# saving house data and label to new files for house - 1 chan - 1 label - aggregate
# saving house data and label to new files for house - 1 chan - 2 label - boiler
# saving house data and label to new files for house - 1 chan - 3 label - solar_thermal_pump
# saving house data and label to new files for house - 1 chan - 5 label - washing_machine
# saving house data and label to new files for house - 1 chan - 6 label - dishwasher
# saving house data and label to new files for house - 1 chan - 7 label - tv
# saving house data and label to new files for house - 1 chan - 8 label - kitchen_lights
# saving house data and label to new files for house - 1 chan - 9 label - htpc
# saving house data and label to new files for house - 1 chan - 10 label - kettle
# saving house data and label to new files for house - 1 chan - 11 label - toaster
# saving house data and label to new files for house - 1 chan - 12 label - fridge
# saving house data and label to new files for house - 1 chan - 13 label - microwave
# saving house data and label to new files for house - 1 chan - 17 label - amp_livingroom
# saving house data and label to new files for house - 1 chan - 18 label - adsl_router
# saving house data and label to new files for house - 1 chan - 19 label - livingroom_s_lamp
# saving house data and label to new files for house - 1 chan - 25 label - lighting_circuit
# skipping house data and label due to low mean - 0.9031685735686468 - 1 chan - 26 label - livingroom_s_lamp2
# saving house data and label to new files for house - 1 chan - 28 label - subwoofer_livingroom
# saving house data and label to new files for house - 1 chan - 29 label - livingroom_lamp_tv
# saving house data and label to new files for house - 1 chan - 32 label - kitchen_phone&stereo
# skipping house data and label due to low mean - 0.7255403933247707 - 1 chan - 33 label - utilityrm_lamp
# skipping house data and label due to low mean - 0.3170368399724781 - 1 chan - 34 label - samsung_charger
# skipping house data and label due to low mean - 0.474718281066364 - 1 chan - 35 label - bedroom_d_lamp
# saving house data and label to new files for house - 1 chan - 36 label - coffee_machine
# skipping house data and label due to low mean - 0.9427548416973099 - 1 chan - 37 label - kitchen_radio
# saving house data and label to new files for house - 1 chan - 42 label - gas_oven
# saving house data and label to new files for house - 1 chan - 43 label - data_logger_pc
# skipping house data and label due to low mean - 0.012246654289227995 - 1 chan - 44 label - childs_table_lamp
# skipping house data and label due to low mean - 0.32077872134147634 - 1 chan - 45 label - childs_ds_lamp
# skipping house data and label due to low mean - 0.020332314120585938 - 1 chan - 46 label - baby_monitor_tx
# skipping house data and label due to low mean - 0.5470053736078342 - 1 chan - 48 label - office_lamp1
# saving house data and label to new files for house - 1 chan - 49 label - office_lamp2

# %%
# Separate house 1 data into train, validation and test data
df1_train = df[1].ix[:dates[1][800]]
df1_val = df[1].ix[dates[1][801]:dates[1][1200]]
df1_test = df[1].ix[dates[1][1201]:]
print('df_train.shape: ', df1_train.shape)
print('df_val.shape: ', df1_val.shape)
print('df_test.shape: ', df1_test.shape)

# %%
# Using aggregate_1 to predict tv_7
x_train = df1_train[['aggregate_1', 'timeslice']].values
y_train = df1_train.drop(['aggregate_1', 'timestamp'], axis=1).values
x_val = df1_val[['aggregate_1', 'timeslice']].values
y_val = df1_val.drop(['aggregate_1', 'timestamp'], axis=1).values
x_test = df1_test[['aggregate_1', 'timeslice']].values
y_test = df1_test.drop(['aggregate_1', 'timestamp'], axis=1).values
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)
print(y_train.shape[1])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError


from timeit import default_timer as timer

class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

def compile_model(model):
    # output the model's structure
#     model.summary()

    # Model compilation
    optimizer = Adam(lr=0.01)
    # Consider regression metrics rather than accuracy : rmse, mae     
    model.compile(loss='mse', optimizer=optimizer,metrics=['accuracy', RootMeanSquaredError(), MeanAbsoluteError()])
    time_cb = TimingCallback()
    callbacks = [time_cb]

    # Model Training
    history = model.fit(x_train, y_train, epochs=3, batch_size=100, validation_data=(x_val, y_val), callbacks=callbacks)

    return history, sum(time_cb.logs)


model = Sequential()
# m.add(Flatten(input_shape=(943, 1)))
model.add(Dense(1000, activation='relu', input_dim = 2))
model.add(Dense(1000, activation='relu'))
model.add(Dense(y_train.shape[1],activation='linear'))

model.summary()

history, time_spent = compile_model(model)
# view_model_results(model, history)
print('Time spent', time_spent)

# %%
def view_model_results(model, history):
    fig = plt.figure()
    fig.add_subplot(1,2,1)
    plt.plot(history.history['loss'], label='train loss')
    plt.plot(history.history['val_loss'], label='test loss')
    plt.legend()
    plt.grid(True)
    plt.xlim([0,3])
    plt.ylim([0,1.0])
    plt.xlabel('epoch')

    fig.add_subplot(1,2,2)
    plt.plot(history.history['accuracy'], label='train accuracy')
    plt.plot(history.history['val_accuracy'], label='test accuracy')
    plt.legend()
    plt.grid(True)
    plt.xlim([0,3])
    plt.ylim([0,1.0])
    plt.xlabel('epoch')


    print(history.history.keys())
    
view_model_results(model, history)
