# %%
# Constants
MAX_NO_ROWS = 1000000
LOAD_MODEL=False
SKIP_TRAINING=False
FEATURE = 'ft_fridge'
SEQ_PER_BATCH = 1024
SEQ_LEN = 32
N_STRIDES = 1
NORM_TYPE = 'mean'
LEARNING_RATE = 1e-2
CLIP_VALUE = 10.
EPOCHS = 2000
CHECKPOINT_PATH = f"dae_training_{FEATURE}/cp.ckpt"

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Dissertation
# Out:
# /content/drive/My Drive/Colab Notebooks/Dissertation

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.21.6)

# %%
from lib.chunk_reader import read_labels, get_merged_chunks, get_dates
from lib.plotting import plot_ft_days, plot_model_history, plot_prediction_windows
from lib.analysis import print_heads_tails

# %%
labels = read_labels(1)
for house in range(1,2):
    print('House {}: '.format(house), labels[house], '\n')
# Out:
# House 1:  ['mains_active', 'mains_apparent', 'mains_rms', 'aggregate_apparent', 'ft_boiler', 'ft_solar_thermal_pump', 'ft_washing_machine', 'ft_dishwasher', 'ft_tv', 'ft_kitchen_lights', 'ft_htpc', 'ft_kettle', 'ft_toaster', 'ft_fridge', 'ft_microwave', 'ft_amp_livingroom', 'ft_adsl_router', 'ft_livingroom_s_lamp', 'ft_lighting_circuit', 'ft_subwoofer_livingroom', 'ft_livingroom_lamp_tv', 'ft_kitchen_phone&stereo', 'ft_coffee_machine', 'ft_gas_oven', 'ft_data_logger_pc', 'ft_office_lamp2', 'aggregate_active', 'unix_time']

# %%
ref_chunk_df = get_merged_chunks(1, 1)
print('Original DF shape', ref_chunk_df.shape)
print('---')
ref_chunk_df = ref_chunk_df[0:MAX_NO_ROWS]
# Out:
# reading house 1; chunk 1
# reading file data/ukdale-parsed-chunks/house_1/chunk_1.dat; for house 1 and chunk 1
# read house 1; chunk 1; df.shape is (4500000, 29)
# Original DF shape (4500000, 29)
# ---

# %%
dates = {}
# for house in range(1,2):
dates[1] = get_dates(ref_chunk_df, 1)
# Out:
# House 1 data contain 71 days from 2013-04-11 to 2013-06-20.
# ['2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05-13', '2013-05-14', '2013-05-15', '2013-05-16', '2013-05-17', '2013-05-18', '2013-05-19', '2013-05-20', '2013-05-21', '2013-05-22', '2013-05-23', '2013-05-24', '2013-05-25', '2013-05-26', '2013-05-27', '2013-05-28', '2013-05-29', '2013-05-30', '2013-05-31', '2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04', '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08', '2013-06-09', '2013-06-10', '2013-06-11', '2013-06-12', '2013-06-13', '2013-06-14', '2013-06-15', '2013-06-16', '2013-06-17', '2013-06-18', '2013-06-19', '2013-06-20']

# %%
# Constants 2
rows_per_day = ref_chunk_df.loc[:dates[1][2]].shape[0]

# %%
plot_ft_days(ref_chunk_df, dates, 1, FEATURE, 2)
# Out:
# (31700,)
# (15850, 2)

# %%
from algos.processing import split_df_by_dates
from algos.dae import create_model, train, predict
from algos.norm import get_ref_norm

# %%
# Separate house 1 data into train, validation and test data
df_train, df_val, df_test  =  split_df_by_dates(ref_chunk_df, dates=dates, house=1)
# Out:
# df_train.shape:  (521300, 29)
# df_val.shape:  (316800, 29)
# df_test.shape:  (190700, 29)

# %%
ref_norm = get_ref_norm(df_train, NORM_TYPE)
# Out:
# ref_mean: 325.09124755859375; ref_max: 6002.919921875; ref_std: 434.2580871582031
# norm_type: mean; ref_norm 325.09124755859375

# %%
model = create_model(seq_len=SEQ_LEN, learning_rate=LEARNING_RATE, clipvalue=CLIP_VALUE)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 32, 8)             40
#
#  flatten (Flatten)           (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  reshape (Reshape)           (None, 32, 8)             0
#
#  conv1d_1 (Conv1D)           (None, 32, 1)             33
#
# =================================================================
# Total params: 131,785
# Trainable params: 131,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !!!!!!!Counter!!!!!!! 
# Manually update for every new loaded training
# Run Counter = 0

# Load and or Train
if LOAD_MODEL:
  model.load_weights(CHECKPOINT_PATH)
if SKIP_TRAINING:
  pass
else:
  model, history, time_spent = train(model, feature=FEATURE, df_train=df_train, df_val=df_val, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH, epochs=EPOCHS, checkpoint_path=CHECKPOINT_PATH)
# Out:
# (521300, 1) (521300, 1) (316800, 1) (316800, 1)
# sequence_len 32
# epochs 2000
# Input initial shape (16291, 32, 1); input final shape (16291, 32, 1)
# Output initial shape (16291, 32, 1); Output final shape (16291, 32, 1)
# Epoch 1/2000
# 16/16 - 8s - loss: 0.0522 - root_mean_squared_error: 0.2285 - mean_absolute_error: 0.1376 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1761 - val_mean_absolute_error: 0.1096 - 8s/epoch - 486ms/step
# Epoch 2/2000
# 16/16 - 0s - loss: 0.0300 - root_mean_squared_error: 0.1733 - mean_absolute_error: 0.1252 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1606 - val_mean_absolute_error: 0.1207 - 169ms/epoch - 11ms/step
# Epoch 3/2000
# 16/16 - 0s - loss: 0.0268 - root_mean_squared_error: 0.1637 - mean_absolute_error: 0.1307 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1570 - val_mean_absolute_error: 0.1296 - 162ms/epoch - 10ms/step
# Epoch 4/2000
# 16/16 - 0s - loss: 0.0259 - root_mean_squared_error: 0.1611 - mean_absolute_error: 0.1341 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575 - val_mean_absolute_error: 0.1320 - 121ms/epoch - 8ms/step
# Epoch 5/2000
# 16/16 - 0s - loss: 0.0257 - root_mean_squared_error: 0.1603 - mean_absolute_error: 0.1351 - val_loss: 0.0247 - val_root_mean_squared_error: 0.1570 - val_mean_absolute_error: 0.1323 - 118ms/epoch - 7ms/step
# Epoch 6/2000
# 16/16 - 0s - loss: 0.0255 - root_mean_squared_error: 0.1597 - mean_absolute_error: 0.1350 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1567 - val_mean_absolute_error: 0.1320 - 151ms/epoch - 9ms/step
# Epoch 7/2000
# 16/16 - 0s - loss: 0.0254 - root_mean_squared_error: 0.1594 - mean_absolute_error: 0.1348 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1561 - val_mean_absolute_error: 0.1312 - 124ms/epoch - 8ms/step
# Epoch 8/2000
# 16/16 - 0s - loss: 0.0253 - root_mean_squared_error: 0.1590 - mean_absolute_error: 0.1343 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1557 - val_mean_absolute_error: 0.1298 - 114ms/epoch - 7ms/step
# Epoch 9/2000
# 16/16 - 0s - loss: 0.0251 - root_mean_squared_error: 0.1583 - mean_absolute_error: 0.1335 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1536 - val_mean_absolute_error: 0.1285 - 161ms/epoch - 10ms/step
# Epoch 10/2000
# 16/16 - 0s - loss: 0.0248 - root_mean_squared_error: 0.1573 - mean_absolute_error: 0.1320 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1511 - val_mean_absolute_error: 0.1252 - 127ms/epoch - 8ms/step
# Epoch 11/2000
# 16/16 - 0s - loss: 0.0241 - root_mean_squared_error: 0.1553 - mean_absolute_error: 0.1289 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1464 - val_mean_absolute_error: 0.1176 - 119ms/epoch - 7ms/step
# Epoch 12/2000
# 16/16 - 0s - loss: 0.0228 - root_mean_squared_error: 0.1510 - mean_absolute_error: 0.1210 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1396 - val_mean_absolute_error: 0.1041 - 131ms/epoch - 8ms/step
# Epoch 13/2000
# 16/16 - 0s - loss: 0.0220 - root_mean_squared_error: 0.1483 - mean_absolute_error: 0.1148 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1389 - val_mean_absolute_error: 0.0991 - 160ms/epoch - 10ms/step
# Epoch 14/2000
# 16/16 - 0s - loss: 0.0216 - root_mean_squared_error: 0.1468 - mean_absolute_error: 0.1116 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1367 - val_mean_absolute_error: 0.0957 - 115ms/epoch - 7ms/step
# Epoch 15/2000
# 16/16 - 0s - loss: 0.0212 - root_mean_squared_error: 0.1454 - mean_absolute_error: 0.1094 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1362 - val_mean_absolute_error: 0.0934 - 159ms/epoch - 10ms/step
# Epoch 16/2000
# 16/16 - 0s - loss: 0.0210 - root_mean_squared_error: 0.1451 - mean_absolute_error: 0.1093 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1339 - val_mean_absolute_error: 0.0911 - 163ms/epoch - 10ms/step
# Epoch 17/2000
# 16/16 - 0s - loss: 0.0209 - root_mean_squared_error: 0.1445 - mean_absolute_error: 0.1082 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1344 - val_mean_absolute_error: 0.0906 - 151ms/epoch - 9ms/step
# Epoch 18/2000
# 16/16 - 0s - loss: 0.0207 - root_mean_squared_error: 0.1438 - mean_absolute_error: 0.1073 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1342 - val_mean_absolute_error: 0.0905 - 120ms/epoch - 7ms/step
# Epoch 19/2000
# 16/16 - 0s - loss: 0.0205 - root_mean_squared_error: 0.1433 - mean_absolute_error: 0.1065 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1342 - val_mean_absolute_error: 0.0897 - 157ms/epoch - 10ms/step
# Epoch 20/2000
# 16/16 - 0s - loss: 0.0204 - root_mean_squared_error: 0.1428 - mean_absolute_error: 0.1055 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347 - val_mean_absolute_error: 0.0894 - 114ms/epoch - 7ms/step
# Epoch 21/2000
# 16/16 - 0s - loss: 0.0203 - root_mean_squared_error: 0.1426 - mean_absolute_error: 0.1048 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1336 - val_mean_absolute_error: 0.0876 - 118ms/epoch - 7ms/step
# Epoch 22/2000
# 16/16 - 0s - loss: 0.0202 - root_mean_squared_error: 0.1420 - mean_absolute_error: 0.1034 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327 - val_mean_absolute_error: 0.0862 - 162ms/epoch - 10ms/step
# Epoch 23/2000
# 16/16 - 0s - loss: 0.0201 - root_mean_squared_error: 0.1416 - mean_absolute_error: 0.1029 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1325 - val_mean_absolute_error: 0.0859 - 171ms/epoch - 11ms/step
# Epoch 24/2000
# 16/16 - 0s - loss: 0.0200 - root_mean_squared_error: 0.1413 - mean_absolute_error: 0.1019 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327 - val_mean_absolute_error: 0.0855 - 121ms/epoch - 8ms/step
# Epoch 25/2000
# 16/16 - 0s - loss: 0.0198 - root_mean_squared_error: 0.1408 - mean_absolute_error: 0.1011 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1341 - val_mean_absolute_error: 0.0852 - 156ms/epoch - 10ms/step
# Epoch 26/2000
# 16/16 - 0s - loss: 0.0198 - root_mean_squared_error: 0.1406 - mean_absolute_error: 0.1003 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1333 - val_mean_absolute_error: 0.0851 - 159ms/epoch - 10ms/step
# Epoch 27/2000
# 16/16 - 0s - loss: 0.0197 - root_mean_squared_error: 0.1405 - mean_absolute_error: 0.0998 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1356 - val_mean_absolute_error: 0.0858 - 116ms/epoch - 7ms/step
# Epoch 28/2000
# 16/16 - 0s - loss: 0.0197 - root_mean_squared_error: 0.1403 - mean_absolute_error: 0.0997 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1322 - val_mean_absolute_error: 0.0829 - 127ms/epoch - 8ms/step
# Epoch 29/2000
# 16/16 - 0s - loss: 0.0195 - root_mean_squared_error: 0.1398 - mean_absolute_error: 0.0986 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313 - val_mean_absolute_error: 0.0820 - 119ms/epoch - 7ms/step
# Epoch 30/2000
# 16/16 - 0s - loss: 0.0195 - root_mean_squared_error: 0.1397 - mean_absolute_error: 0.0983 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1318 - val_mean_absolute_error: 0.0822 - 127ms/epoch - 8ms/step
# Epoch 31/2000
# 16/16 - 0s - loss: 0.0194 - root_mean_squared_error: 0.1392 - mean_absolute_error: 0.0975 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1354 - val_mean_absolute_error: 0.0844 - 117ms/epoch - 7ms/step
# Epoch 32/2000
#
# Epoch 32: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0193 - root_mean_squared_error: 0.1390 - mean_absolute_error: 0.0971 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1320 - val_mean_absolute_error: 0.0818 - 241ms/epoch - 15ms/step
# Epoch 33/2000
# 16/16 - 0s - loss: 0.0193 - root_mean_squared_error: 0.1391 - mean_absolute_error: 0.0970 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347 - val_mean_absolute_error: 0.0837 - 159ms/epoch - 10ms/step
# Epoch 34/2000
# 16/16 - 0s - loss: 0.0192 - root_mean_squared_error: 0.1387 - mean_absolute_error: 0.0966 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347 - val_mean_absolute_error: 0.0826 - 120ms/epoch - 8ms/step
# Epoch 35/2000
# 16/16 - 0s - loss: 0.0192 - root_mean_squared_error: 0.1385 - mean_absolute_error: 0.0962 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315 - val_mean_absolute_error: 0.0799 - 161ms/epoch - 10ms/step
# Epoch 36/2000
# 16/16 - 0s - loss: 0.0192 - root_mean_squared_error: 0.1385 - mean_absolute_error: 0.0958 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1314 - val_mean_absolute_error: 0.0803 - 124ms/epoch - 8ms/step
# Epoch 37/2000
# 16/16 - 0s - loss: 0.0191 - root_mean_squared_error: 0.1382 - mean_absolute_error: 0.0957 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1307 - val_mean_absolute_error: 0.0795 - 180ms/epoch - 11ms/step
# Epoch 38/2000
# 16/16 - 0s - loss: 0.0191 - root_mean_squared_error: 0.1381 - mean_absolute_error: 0.0954 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1360 - val_mean_absolute_error: 0.0835 - 175ms/epoch - 11ms/step
# Epoch 39/2000
# 16/16 - 0s - loss: 0.0190 - root_mean_squared_error: 0.1377 - mean_absolute_error: 0.0952 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300 - val_mean_absolute_error: 0.0776 - 201ms/epoch - 13ms/step
# Epoch 40/2000
# 16/16 - 0s - loss: 0.0190 - root_mean_squared_error: 0.1377 - mean_absolute_error: 0.0945 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1324 - val_mean_absolute_error: 0.0794 - 196ms/epoch - 12ms/step
# Epoch 41/2000
# 16/16 - 0s - loss: 0.0190 - root_mean_squared_error: 0.1378 - mean_absolute_error: 0.0945 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291 - val_mean_absolute_error: 0.0768 - 197ms/epoch - 12ms/step
# Epoch 42/2000
# 16/16 - 0s - loss: 0.0190 - root_mean_squared_error: 0.1379 - mean_absolute_error: 0.0949 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1318 - val_mean_absolute_error: 0.0793 - 214ms/epoch - 13ms/step
# Epoch 43/2000
# 16/16 - 0s - loss: 0.0189 - root_mean_squared_error: 0.1376 - mean_absolute_error: 0.0948 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1317 - val_mean_absolute_error: 0.0791 - 195ms/epoch - 12ms/step
# Epoch 44/2000
# 16/16 - 0s - loss: 0.0189 - root_mean_squared_error: 0.1374 - mean_absolute_error: 0.0944 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293 - val_mean_absolute_error: 0.0766 - 167ms/epoch - 10ms/step
# Epoch 45/2000
# 16/16 - 0s - loss: 0.0189 - root_mean_squared_error: 0.1375 - mean_absolute_error: 0.0940 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1330 - val_mean_absolute_error: 0.0801 - 180ms/epoch - 11ms/step
# Epoch 46/2000
# 16/16 - 0s - loss: 0.0187 - root_mean_squared_error: 0.1369 - mean_absolute_error: 0.0936 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295 - val_mean_absolute_error: 0.0773 - 192ms/epoch - 12ms/step
# Epoch 47/2000
# 16/16 - 0s - loss: 0.0187 - root_mean_squared_error: 0.1367 - mean_absolute_error: 0.0932 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1325 - val_mean_absolute_error: 0.0800 - 192ms/epoch - 12ms/step
# Epoch 48/2000
# 16/16 - 0s - loss: 0.0187 - root_mean_squared_error: 0.1369 - mean_absolute_error: 0.0938 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301 - val_mean_absolute_error: 0.0769 - 174ms/epoch - 11ms/step
# Epoch 49/2000
# 16/16 - 0s - loss: 0.0187 - root_mean_squared_error: 0.1369 - mean_absolute_error: 0.0936 - val_loss: 0.0178 - val_root_mean_squared_error: 0.1334 - val_mean_absolute_error: 0.0800 - 203ms/epoch - 13ms/step
# Epoch 50/2000
# 16/16 - 0s - loss: 0.0187 - root_mean_squared_error: 0.1366 - mean_absolute_error: 0.0931 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1307 - val_mean_absolute_error: 0.0776 - 208ms/epoch - 13ms/step
# Epoch 51/2000
# 16/16 - 0s - loss: 0.0185 - root_mean_squared_error: 0.1360 - mean_absolute_error: 0.0927 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1302 - val_mean_absolute_error: 0.0770 - 212ms/epoch - 13ms/step
# Epoch 52/2000
# 16/16 - 0s - loss: 0.0186 - root_mean_squared_error: 0.1362 - mean_absolute_error: 0.0928 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303 - val_mean_absolute_error: 0.0774 - 193ms/epoch - 12ms/step
# Epoch 53/2000
# 16/16 - 0s - loss: 0.0186 - root_mean_squared_error: 0.1363 - mean_absolute_error: 0.0926 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1302 - val_mean_absolute_error: 0.0769 - 179ms/epoch - 11ms/step
# Epoch 54/2000
# 16/16 - 0s - loss: 0.0185 - root_mean_squared_error: 0.1360 - mean_absolute_error: 0.0920 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299 - val_mean_absolute_error: 0.0762 - 179ms/epoch - 11ms/step
# Epoch 55/2000
# 16/16 - 0s - loss: 0.0183 - root_mean_squared_error: 0.1353 - mean_absolute_error: 0.0919 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1306 - val_mean_absolute_error: 0.0767 - 115ms/epoch - 7ms/step
# Epoch 56/2000
# 16/16 - 0s - loss: 0.0184 - root_mean_squared_error: 0.1357 - mean_absolute_error: 0.0920 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291 - val_mean_absolute_error: 0.0753 - 157ms/epoch - 10ms/step
# Epoch 57/2000
# 16/16 - 0s - loss: 0.0183 - root_mean_squared_error: 0.1352 - mean_absolute_error: 0.0914 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1311 - val_mean_absolute_error: 0.0771 - 117ms/epoch - 7ms/step
# Epoch 58/2000
# 16/16 - 0s - loss: 0.0183 - root_mean_squared_error: 0.1354 - mean_absolute_error: 0.0916 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270 - val_mean_absolute_error: 0.0733 - 120ms/epoch - 8ms/step
# Epoch 59/2000
# 16/16 - 0s - loss: 0.0183 - root_mean_squared_error: 0.1352 - mean_absolute_error: 0.0914 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310 - val_mean_absolute_error: 0.0756 - 160ms/epoch - 10ms/step
# Epoch 60/2000
# 16/16 - 0s - loss: 0.0183 - root_mean_squared_error: 0.1351 - mean_absolute_error: 0.0915 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293 - val_mean_absolute_error: 0.0752 - 160ms/epoch - 10ms/step
# Epoch 61/2000
# 16/16 - 0s - loss: 0.0183 - root_mean_squared_error: 0.1352 - mean_absolute_error: 0.0910 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292 - val_mean_absolute_error: 0.0753 - 118ms/epoch - 7ms/step
# Epoch 62/2000
# 16/16 - 0s - loss: 0.0182 - root_mean_squared_error: 0.1348 - mean_absolute_error: 0.0910 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299 - val_mean_absolute_error: 0.0755 - 118ms/epoch - 7ms/step
# Epoch 63/2000
#
# Epoch 63: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0181 - root_mean_squared_error: 0.1345 - mean_absolute_error: 0.0904 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266 - val_mean_absolute_error: 0.0726 - 263ms/epoch - 16ms/step
# Epoch 64/2000
# 16/16 - 0s - loss: 0.0181 - root_mean_squared_error: 0.1347 - mean_absolute_error: 0.0907 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1321 - val_mean_absolute_error: 0.0767 - 161ms/epoch - 10ms/step
# Epoch 65/2000
# 16/16 - 0s - loss: 0.0181 - root_mean_squared_error: 0.1344 - mean_absolute_error: 0.0905 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281 - val_mean_absolute_error: 0.0740 - 163ms/epoch - 10ms/step
# Epoch 66/2000
# 16/16 - 0s - loss: 0.0182 - root_mean_squared_error: 0.1348 - mean_absolute_error: 0.0907 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1292 - val_mean_absolute_error: 0.0746 - 122ms/epoch - 8ms/step
# Epoch 67/2000
# 16/16 - 0s - loss: 0.0179 - root_mean_squared_error: 0.1339 - mean_absolute_error: 0.0900 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290 - val_mean_absolute_error: 0.0736 - 121ms/epoch - 8ms/step
# Epoch 68/2000
# 16/16 - 0s - loss: 0.0180 - root_mean_squared_error: 0.1340 - mean_absolute_error: 0.0899 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297 - val_mean_absolute_error: 0.0748 - 119ms/epoch - 7ms/step
# Epoch 69/2000
# 16/16 - 0s - loss: 0.0180 - root_mean_squared_error: 0.1340 - mean_absolute_error: 0.0898 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1305 - val_mean_absolute_error: 0.0758 - 116ms/epoch - 7ms/step
# Epoch 70/2000
# 16/16 - 0s - loss: 0.0182 - root_mean_squared_error: 0.1347 - mean_absolute_error: 0.0904 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300 - val_mean_absolute_error: 0.0753 - 162ms/epoch - 10ms/step
# Epoch 71/2000
# 16/16 - 0s - loss: 0.0179 - root_mean_squared_error: 0.1336 - mean_absolute_error: 0.0894 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1329 - val_mean_absolute_error: 0.0775 - 159ms/epoch - 10ms/step
# Epoch 72/2000
# 16/16 - 0s - loss: 0.0180 - root_mean_squared_error: 0.1341 - mean_absolute_error: 0.0896 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290 - val_mean_absolute_error: 0.0740 - 127ms/epoch - 8ms/step
# Epoch 73/2000
# 16/16 - 0s - loss: 0.0179 - root_mean_squared_error: 0.1337 - mean_absolute_error: 0.0894 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1302 - val_mean_absolute_error: 0.0747 - 120ms/epoch - 8ms/step
# Epoch 74/2000
# 16/16 - 0s - loss: 0.0178 - root_mean_squared_error: 0.1334 - mean_absolute_error: 0.0892 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1259 - val_mean_absolute_error: 0.0718 - 130ms/epoch - 8ms/step
# Epoch 75/2000
# 16/16 - 0s - loss: 0.0178 - root_mean_squared_error: 0.1332 - mean_absolute_error: 0.0891 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290 - val_mean_absolute_error: 0.0743 - 159ms/epoch - 10ms/step
# Epoch 76/2000
# 16/16 - 0s - loss: 0.0177 - root_mean_squared_error: 0.1332 - mean_absolute_error: 0.0889 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290 - val_mean_absolute_error: 0.0735 - 121ms/epoch - 8ms/step
# Epoch 77/2000
# 16/16 - 0s - loss: 0.0178 - root_mean_squared_error: 0.1333 - mean_absolute_error: 0.0893 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1325 - val_mean_absolute_error: 0.0769 - 161ms/epoch - 10ms/step
# Epoch 78/2000
# 16/16 - 0s - loss: 0.0177 - root_mean_squared_error: 0.1331 - mean_absolute_error: 0.0892 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266 - val_mean_absolute_error: 0.0718 - 120ms/epoch - 7ms/step
# Epoch 79/2000
# 16/16 - 0s - loss: 0.0177 - root_mean_squared_error: 0.1332 - mean_absolute_error: 0.0888 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282 - val_mean_absolute_error: 0.0730 - 126ms/epoch - 8ms/step
# Epoch 80/2000
# 16/16 - 0s - loss: 0.0176 - root_mean_squared_error: 0.1328 - mean_absolute_error: 0.0887 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279 - val_mean_absolute_error: 0.0725 - 117ms/epoch - 7ms/step
# Epoch 81/2000
# 16/16 - 0s - loss: 0.0177 - root_mean_squared_error: 0.1329 - mean_absolute_error: 0.0887 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1294 - val_mean_absolute_error: 0.0744 - 126ms/epoch - 8ms/step
# Epoch 82/2000
# 16/16 - 0s - loss: 0.0176 - root_mean_squared_error: 0.1327 - mean_absolute_error: 0.0885 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1301 - val_mean_absolute_error: 0.0747 - 160ms/epoch - 10ms/step
# Epoch 83/2000
# 16/16 - 0s - loss: 0.0176 - root_mean_squared_error: 0.1326 - mean_absolute_error: 0.0886 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1309 - val_mean_absolute_error: 0.0759 - 122ms/epoch - 8ms/step
# Epoch 84/2000
# 16/16 - 0s - loss: 0.0175 - root_mean_squared_error: 0.1323 - mean_absolute_error: 0.0884 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289 - val_mean_absolute_error: 0.0738 - 115ms/epoch - 7ms/step
# Epoch 85/2000
# 16/16 - 0s - loss: 0.0175 - root_mean_squared_error: 0.1323 - mean_absolute_error: 0.0880 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291 - val_mean_absolute_error: 0.0731 - 123ms/epoch - 8ms/step
# Epoch 86/2000
# 16/16 - 0s - loss: 0.0175 - root_mean_squared_error: 0.1322 - mean_absolute_error: 0.0881 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1296 - val_mean_absolute_error: 0.0740 - 119ms/epoch - 7ms/step
# Epoch 87/2000
# 16/16 - 0s - loss: 0.0175 - root_mean_squared_error: 0.1322 - mean_absolute_error: 0.0881 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287 - val_mean_absolute_error: 0.0728 - 120ms/epoch - 8ms/step
# Epoch 88/2000
# 16/16 - 0s - loss: 0.0174 - root_mean_squared_error: 0.1318 - mean_absolute_error: 0.0877 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279 - val_mean_absolute_error: 0.0728 - 162ms/epoch - 10ms/step
# Epoch 89/2000
# 16/16 - 0s - loss: 0.0173 - root_mean_squared_error: 0.1316 - mean_absolute_error: 0.0875 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1276 - val_mean_absolute_error: 0.0714 - 116ms/epoch - 7ms/step
# Epoch 90/2000
# 16/16 - 0s - loss: 0.0173 - root_mean_squared_error: 0.1316 - mean_absolute_error: 0.0871 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299 - val_mean_absolute_error: 0.0738 - 124ms/epoch - 8ms/step
# Epoch 91/2000
# 16/16 - 0s - loss: 0.0173 - root_mean_squared_error: 0.1314 - mean_absolute_error: 0.0874 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281 - val_mean_absolute_error: 0.0726 - 151ms/epoch - 9ms/step
# Epoch 92/2000
# 16/16 - 0s - loss: 0.0174 - root_mean_squared_error: 0.1319 - mean_absolute_error: 0.0873 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278 - val_mean_absolute_error: 0.0733 - 118ms/epoch - 7ms/step
# Epoch 93/2000
# 16/16 - 0s - loss: 0.0173 - root_mean_squared_error: 0.1314 - mean_absolute_error: 0.0871 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289 - val_mean_absolute_error: 0.0730 - 125ms/epoch - 8ms/step
# Epoch 94/2000
#
# Epoch 94: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0173 - root_mean_squared_error: 0.1316 - mean_absolute_error: 0.0870 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286 - val_mean_absolute_error: 0.0729 - 217ms/epoch - 14ms/step
# Epoch 95/2000
# 16/16 - 0s - loss: 0.0173 - root_mean_squared_error: 0.1316 - mean_absolute_error: 0.0870 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279 - val_mean_absolute_error: 0.0731 - 131ms/epoch - 8ms/step
# Epoch 96/2000
# 16/16 - 0s - loss: 0.0173 - root_mean_squared_error: 0.1314 - mean_absolute_error: 0.0871 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290 - val_mean_absolute_error: 0.0736 - 124ms/epoch - 8ms/step
# Epoch 97/2000
# 16/16 - 0s - loss: 0.0172 - root_mean_squared_error: 0.1312 - mean_absolute_error: 0.0868 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295 - val_mean_absolute_error: 0.0744 - 125ms/epoch - 8ms/step
# Epoch 98/2000
# 16/16 - 0s - loss: 0.0172 - root_mean_squared_error: 0.1312 - mean_absolute_error: 0.0866 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300 - val_mean_absolute_error: 0.0748 - 169ms/epoch - 11ms/step
# Epoch 99/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1306 - mean_absolute_error: 0.0860 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1290 - val_mean_absolute_error: 0.0733 - 124ms/epoch - 8ms/step
# Epoch 100/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1308 - mean_absolute_error: 0.0861 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289 - val_mean_absolute_error: 0.0731 - 116ms/epoch - 7ms/step
# Epoch 101/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1306 - mean_absolute_error: 0.0860 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283 - val_mean_absolute_error: 0.0718 - 167ms/epoch - 10ms/step
# Epoch 102/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1307 - mean_absolute_error: 0.0866 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310 - val_mean_absolute_error: 0.0740 - 117ms/epoch - 7ms/step
# Epoch 103/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1306 - mean_absolute_error: 0.0861 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1271 - val_mean_absolute_error: 0.0713 - 112ms/epoch - 7ms/step
# Epoch 104/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1306 - mean_absolute_error: 0.0858 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285 - val_mean_absolute_error: 0.0735 - 119ms/epoch - 7ms/step
# Epoch 105/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1306 - mean_absolute_error: 0.0861 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1275 - val_mean_absolute_error: 0.0707 - 120ms/epoch - 8ms/step
# Epoch 106/2000
# 16/16 - 0s - loss: 0.0170 - root_mean_squared_error: 0.1305 - mean_absolute_error: 0.0858 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1340 - val_mean_absolute_error: 0.0776 - 113ms/epoch - 7ms/step
# Epoch 107/2000
# 16/16 - 0s - loss: 0.0171 - root_mean_squared_error: 0.1309 - mean_absolute_error: 0.0864 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1251 - val_mean_absolute_error: 0.0694 - 118ms/epoch - 7ms/step
# Epoch 108/2000
# 16/16 - 0s - loss: 0.0170 - root_mean_squared_error: 0.1303 - mean_absolute_error: 0.0858 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295 - val_mean_absolute_error: 0.0741 - 114ms/epoch - 7ms/step
# Epoch 109/2000
# 16/16 - 0s - loss: 0.0170 - root_mean_squared_error: 0.1304 - mean_absolute_error: 0.0860 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1302 - val_mean_absolute_error: 0.0741 - 170ms/epoch - 11ms/step
# Epoch 110/2000
# 16/16 - 0s - loss: 0.0170 - root_mean_squared_error: 0.1304 - mean_absolute_error: 0.0852 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293 - val_mean_absolute_error: 0.0731 - 120ms/epoch - 8ms/step
# Epoch 111/2000
# 16/16 - 0s - loss: 0.0169 - root_mean_squared_error: 0.1300 - mean_absolute_error: 0.0852 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280 - val_mean_absolute_error: 0.0721 - 158ms/epoch - 10ms/step
# Epoch 112/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1295 - mean_absolute_error: 0.0847 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291 - val_mean_absolute_error: 0.0733 - 124ms/epoch - 8ms/step
# Epoch 113/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1297 - mean_absolute_error: 0.0850 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279 - val_mean_absolute_error: 0.0723 - 158ms/epoch - 10ms/step
# Epoch 114/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1297 - mean_absolute_error: 0.0849 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285 - val_mean_absolute_error: 0.0730 - 155ms/epoch - 10ms/step
# Epoch 115/2000
# 16/16 - 0s - loss: 0.0167 - root_mean_squared_error: 0.1294 - mean_absolute_error: 0.0847 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1291 - val_mean_absolute_error: 0.0732 - 123ms/epoch - 8ms/step
# Epoch 116/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1295 - mean_absolute_error: 0.0846 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295 - val_mean_absolute_error: 0.0737 - 117ms/epoch - 7ms/step
# Epoch 117/2000
# 16/16 - 0s - loss: 0.0167 - root_mean_squared_error: 0.1292 - mean_absolute_error: 0.0847 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295 - val_mean_absolute_error: 0.0737 - 120ms/epoch - 8ms/step
# Epoch 118/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1297 - mean_absolute_error: 0.0847 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287 - val_mean_absolute_error: 0.0723 - 117ms/epoch - 7ms/step
# Epoch 119/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1296 - mean_absolute_error: 0.0848 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293 - val_mean_absolute_error: 0.0733 - 152ms/epoch - 9ms/step
# Epoch 120/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1295 - mean_absolute_error: 0.0848 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295 - val_mean_absolute_error: 0.0727 - 160ms/epoch - 10ms/step
# Epoch 121/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1288 - mean_absolute_error: 0.0844 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303 - val_mean_absolute_error: 0.0735 - 121ms/epoch - 8ms/step
# Epoch 122/2000
# 16/16 - 0s - loss: 0.0167 - root_mean_squared_error: 0.1291 - mean_absolute_error: 0.0841 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1313 - val_mean_absolute_error: 0.0746 - 116ms/epoch - 7ms/step
# Epoch 123/2000
# 16/16 - 0s - loss: 0.0167 - root_mean_squared_error: 0.1294 - mean_absolute_error: 0.0846 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248 - val_mean_absolute_error: 0.0687 - 167ms/epoch - 10ms/step
# Epoch 124/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1290 - mean_absolute_error: 0.0844 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269 - val_mean_absolute_error: 0.0702 - 124ms/epoch - 8ms/step
# Epoch 125/2000
#
# Epoch 125: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0167 - root_mean_squared_error: 0.1294 - mean_absolute_error: 0.0848 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273 - val_mean_absolute_error: 0.0703 - 300ms/epoch - 19ms/step
# Epoch 126/2000
# 16/16 - 0s - loss: 0.0168 - root_mean_squared_error: 0.1294 - mean_absolute_error: 0.0843 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270 - val_mean_absolute_error: 0.0702 - 192ms/epoch - 12ms/step
# Epoch 127/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1285 - mean_absolute_error: 0.0841 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1271 - val_mean_absolute_error: 0.0700 - 194ms/epoch - 12ms/step
# Epoch 128/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1289 - mean_absolute_error: 0.0838 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281 - val_mean_absolute_error: 0.0714 - 192ms/epoch - 12ms/step
# Epoch 129/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1290 - mean_absolute_error: 0.0845 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287 - val_mean_absolute_error: 0.0716 - 191ms/epoch - 12ms/step
# Epoch 130/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1287 - mean_absolute_error: 0.0841 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269 - val_mean_absolute_error: 0.0701 - 170ms/epoch - 11ms/step
# Epoch 131/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1285 - mean_absolute_error: 0.0837 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265 - val_mean_absolute_error: 0.0694 - 170ms/epoch - 11ms/step
# Epoch 132/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1287 - mean_absolute_error: 0.0836 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269 - val_mean_absolute_error: 0.0696 - 199ms/epoch - 12ms/step
# Epoch 133/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1288 - mean_absolute_error: 0.0839 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286 - val_mean_absolute_error: 0.0716 - 190ms/epoch - 12ms/step
# Epoch 134/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1287 - mean_absolute_error: 0.0835 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1295 - val_mean_absolute_error: 0.0719 - 202ms/epoch - 13ms/step
# Epoch 135/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1289 - mean_absolute_error: 0.0838 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1300 - val_mean_absolute_error: 0.0729 - 189ms/epoch - 12ms/step
# Epoch 136/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1285 - mean_absolute_error: 0.0832 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1288 - val_mean_absolute_error: 0.0723 - 211ms/epoch - 13ms/step
# Epoch 137/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1290 - mean_absolute_error: 0.0839 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1276 - val_mean_absolute_error: 0.0710 - 201ms/epoch - 13ms/step
# Epoch 138/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1284 - mean_absolute_error: 0.0834 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264 - val_mean_absolute_error: 0.0690 - 182ms/epoch - 11ms/step
# Epoch 139/2000
# 16/16 - 0s - loss: 0.0166 - root_mean_squared_error: 0.1287 - mean_absolute_error: 0.0841 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1277 - val_mean_absolute_error: 0.0712 - 193ms/epoch - 12ms/step
# Epoch 140/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1280 - mean_absolute_error: 0.0829 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1267 - val_mean_absolute_error: 0.0694 - 186ms/epoch - 12ms/step
# Epoch 141/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1284 - mean_absolute_error: 0.0835 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1298 - val_mean_absolute_error: 0.0728 - 157ms/epoch - 10ms/step
# Epoch 142/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1283 - mean_absolute_error: 0.0838 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1312 - val_mean_absolute_error: 0.0743 - 128ms/epoch - 8ms/step
# Epoch 143/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1282 - mean_absolute_error: 0.0835 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287 - val_mean_absolute_error: 0.0718 - 124ms/epoch - 8ms/step
# Epoch 144/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1284 - mean_absolute_error: 0.0833 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1276 - val_mean_absolute_error: 0.0707 - 120ms/epoch - 8ms/step
# Epoch 145/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1281 - mean_absolute_error: 0.0832 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282 - val_mean_absolute_error: 0.0717 - 173ms/epoch - 11ms/step
# Epoch 146/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1278 - mean_absolute_error: 0.0830 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287 - val_mean_absolute_error: 0.0717 - 154ms/epoch - 10ms/step
# Epoch 147/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1281 - mean_absolute_error: 0.0829 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289 - val_mean_absolute_error: 0.0716 - 125ms/epoch - 8ms/step
# Epoch 148/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1275 - mean_absolute_error: 0.0827 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1246 - val_mean_absolute_error: 0.0675 - 111ms/epoch - 7ms/step
# Epoch 149/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1279 - mean_absolute_error: 0.0830 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1288 - val_mean_absolute_error: 0.0715 - 155ms/epoch - 10ms/step
# Epoch 150/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1278 - mean_absolute_error: 0.0828 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273 - val_mean_absolute_error: 0.0701 - 115ms/epoch - 7ms/step
# Epoch 151/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1277 - mean_absolute_error: 0.0829 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1252 - val_mean_absolute_error: 0.0677 - 119ms/epoch - 7ms/step
# Epoch 152/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1282 - mean_absolute_error: 0.0828 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1276 - val_mean_absolute_error: 0.0702 - 124ms/epoch - 8ms/step
# Epoch 153/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1276 - mean_absolute_error: 0.0827 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278 - val_mean_absolute_error: 0.0697 - 153ms/epoch - 10ms/step
# Epoch 154/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1276 - mean_absolute_error: 0.0827 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299 - val_mean_absolute_error: 0.0723 - 123ms/epoch - 8ms/step
# Epoch 155/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1281 - mean_absolute_error: 0.0830 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266 - val_mean_absolute_error: 0.0695 - 159ms/epoch - 10ms/step
# Epoch 156/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1276 - mean_absolute_error: 0.0827 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264 - val_mean_absolute_error: 0.0690 - 120ms/epoch - 7ms/step
# Epoch 157/2000
#
# Epoch 157: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1281 - mean_absolute_error: 0.0828 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270 - val_mean_absolute_error: 0.0692 - 251ms/epoch - 16ms/step
# Epoch 158/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1273 - mean_absolute_error: 0.0829 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272 - val_mean_absolute_error: 0.0691 - 151ms/epoch - 9ms/step
# Epoch 159/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1278 - mean_absolute_error: 0.0826 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1255 - val_mean_absolute_error: 0.0679 - 157ms/epoch - 10ms/step
# Epoch 160/2000
# 16/16 - 0s - loss: 0.0161 - root_mean_squared_error: 0.1269 - mean_absolute_error: 0.0824 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278 - val_mean_absolute_error: 0.0705 - 127ms/epoch - 8ms/step
# Epoch 161/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1275 - mean_absolute_error: 0.0823 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265 - val_mean_absolute_error: 0.0704 - 162ms/epoch - 10ms/step
# Epoch 162/2000
# 16/16 - 0s - loss: 0.0165 - root_mean_squared_error: 0.1284 - mean_absolute_error: 0.0830 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270 - val_mean_absolute_error: 0.0700 - 161ms/epoch - 10ms/step
# Epoch 163/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1273 - mean_absolute_error: 0.0824 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281 - val_mean_absolute_error: 0.0713 - 117ms/epoch - 7ms/step
# Epoch 164/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1278 - mean_absolute_error: 0.0825 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286 - val_mean_absolute_error: 0.0710 - 150ms/epoch - 9ms/step
# Epoch 165/2000
# 16/16 - 0s - loss: 0.0161 - root_mean_squared_error: 0.1270 - mean_absolute_error: 0.0822 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264 - val_mean_absolute_error: 0.0692 - 166ms/epoch - 10ms/step
# Epoch 166/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1272 - mean_absolute_error: 0.0824 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1262 - val_mean_absolute_error: 0.0688 - 116ms/epoch - 7ms/step
# Epoch 167/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1274 - mean_absolute_error: 0.0827 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293 - val_mean_absolute_error: 0.0720 - 125ms/epoch - 8ms/step
# Epoch 168/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1272 - mean_absolute_error: 0.0822 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251 - val_mean_absolute_error: 0.0678 - 112ms/epoch - 7ms/step
# Epoch 169/2000
# 16/16 - 0s - loss: 0.0164 - root_mean_squared_error: 0.1279 - mean_absolute_error: 0.0830 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1262 - val_mean_absolute_error: 0.0698 - 122ms/epoch - 8ms/step
# Epoch 170/2000
# 16/16 - 0s - loss: 0.0163 - root_mean_squared_error: 0.1277 - mean_absolute_error: 0.0831 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1308 - val_mean_absolute_error: 0.0740 - 152ms/epoch - 10ms/step
# Epoch 171/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1274 - mean_absolute_error: 0.0823 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299 - val_mean_absolute_error: 0.0724 - 155ms/epoch - 10ms/step
# Epoch 172/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1273 - mean_absolute_error: 0.0825 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261 - val_mean_absolute_error: 0.0689 - 164ms/epoch - 10ms/step
# Epoch 173/2000
# 16/16 - 0s - loss: 0.0161 - root_mean_squared_error: 0.1269 - mean_absolute_error: 0.0821 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1269 - val_mean_absolute_error: 0.0693 - 131ms/epoch - 8ms/step
# Epoch 174/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1267 - mean_absolute_error: 0.0819 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294 - val_mean_absolute_error: 0.0713 - 172ms/epoch - 11ms/step
# Epoch 175/2000
# 16/16 - 0s - loss: 0.0161 - root_mean_squared_error: 0.1271 - mean_absolute_error: 0.0820 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261 - val_mean_absolute_error: 0.0688 - 156ms/epoch - 10ms/step
# Epoch 176/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1272 - mean_absolute_error: 0.0818 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1308 - val_mean_absolute_error: 0.0734 - 115ms/epoch - 7ms/step
# Epoch 177/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1273 - mean_absolute_error: 0.0822 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285 - val_mean_absolute_error: 0.0713 - 126ms/epoch - 8ms/step
# Epoch 178/2000
# 16/16 - 0s - loss: 0.0161 - root_mean_squared_error: 0.1269 - mean_absolute_error: 0.0822 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278 - val_mean_absolute_error: 0.0711 - 153ms/epoch - 10ms/step
# Epoch 179/2000
# 16/16 - 0s - loss: 0.0159 - root_mean_squared_error: 0.1263 - mean_absolute_error: 0.0816 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1281 - val_mean_absolute_error: 0.0699 - 166ms/epoch - 10ms/step
# Epoch 180/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1272 - mean_absolute_error: 0.0819 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293 - val_mean_absolute_error: 0.0719 - 123ms/epoch - 8ms/step
# Epoch 181/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1274 - mean_absolute_error: 0.0826 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1293 - val_mean_absolute_error: 0.0723 - 161ms/epoch - 10ms/step
# Epoch 182/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1273 - mean_absolute_error: 0.0826 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1242 - val_mean_absolute_error: 0.0673 - 161ms/epoch - 10ms/step
# Epoch 183/2000
# 16/16 - 0s - loss: 0.0162 - root_mean_squared_error: 0.1273 - mean_absolute_error: 0.0827 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289 - val_mean_absolute_error: 0.0713 - 169ms/epoch - 11ms/step
# Epoch 184/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1264 - mean_absolute_error: 0.0816 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261 - val_mean_absolute_error: 0.0694 - 126ms/epoch - 8ms/step
# Epoch 185/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1263 - mean_absolute_error: 0.0813 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254 - val_mean_absolute_error: 0.0684 - 135ms/epoch - 8ms/step
# Epoch 186/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_error: 0.0817 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294 - val_mean_absolute_error: 0.0724 - 123ms/epoch - 8ms/step
# Epoch 187/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_error: 0.0813 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289 - val_mean_absolute_error: 0.0709 - 126ms/epoch - 8ms/step
# Epoch 188/2000
#
# Epoch 188: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0159 - root_mean_squared_error: 0.1263 - mean_absolute_error: 0.0814 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1287 - val_mean_absolute_error: 0.0713 - 232ms/epoch - 14ms/step
# Epoch 189/2000
# 16/16 - 0s - loss: 0.0159 - root_mean_squared_error: 0.1263 - mean_absolute_error: 0.0817 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1275 - val_mean_absolute_error: 0.0692 - 159ms/epoch - 10ms/step
# Epoch 190/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_error: 0.0814 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283 - val_mean_absolute_error: 0.0708 - 142ms/epoch - 9ms/step
# Epoch 191/2000
# 16/16 - 0s - loss: 0.0161 - root_mean_squared_error: 0.1270 - mean_absolute_error: 0.0816 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1267 - val_mean_absolute_error: 0.0690 - 122ms/epoch - 8ms/step
# Epoch 192/2000
# 16/16 - 0s - loss: 0.0161 - root_mean_squared_error: 0.1270 - mean_absolute_error: 0.0816 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270 - val_mean_absolute_error: 0.0687 - 161ms/epoch - 10ms/step
# Epoch 193/2000
# 16/16 - 0s - loss: 0.0158 - root_mean_squared_error: 0.1258 - mean_absolute_error: 0.0815 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1268 - val_mean_absolute_error: 0.0683 - 165ms/epoch - 10ms/step
# Epoch 194/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1263 - mean_absolute_error: 0.0812 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1288 - val_mean_absolute_error: 0.0711 - 164ms/epoch - 10ms/step
# Epoch 195/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_error: 0.0809 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1282 - val_mean_absolute_error: 0.0701 - 161ms/epoch - 10ms/step
# Epoch 196/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1266 - mean_absolute_error: 0.0813 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272 - val_mean_absolute_error: 0.0700 - 152ms/epoch - 9ms/step
# Epoch 197/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_error: 0.0814 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280 - val_mean_absolute_error: 0.0707 - 156ms/epoch - 10ms/step
# Epoch 198/2000
# 16/16 - 0s - loss: 0.0159 - root_mean_squared_error: 0.1261 - mean_absolute_error: 0.0813 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1272 - val_mean_absolute_error: 0.0694 - 128ms/epoch - 8ms/step
# Epoch 199/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1263 - mean_absolute_error: 0.0818 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258 - val_mean_absolute_error: 0.0683 - 158ms/epoch - 10ms/step
# Epoch 200/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_error: 0.0818 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1298 - val_mean_absolute_error: 0.0714 - 123ms/epoch - 8ms/step
# Epoch 201/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1264 - mean_absolute_error: 0.0812 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1257 - val_mean_absolute_error: 0.0682 - 112ms/epoch - 7ms/step
# Epoch 202/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_error: 0.0815 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280 - val_mean_absolute_error: 0.0709 - 123ms/epoch - 8ms/step
# Epoch 203/2000
# 16/16 - 0s - loss: 0.0159 - root_mean_squared_error: 0.1261 - mean_absolute_error: 0.0815 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263 - val_mean_absolute_error: 0.0692 - 156ms/epoch - 10ms/step
# Epoch 204/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1264 - mean_absolute_error: 0.0811 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1261 - val_mean_absolute_error: 0.0678 - 121ms/epoch - 8ms/step
# Epoch 205/2000
# 16/16 - 0s - loss: 0.0160 - root_mean_squared_error: 0.1263 - mean_absolute_error: 0.0811 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1273 - val_mean_absolute_error: 0.0697 - 161ms/epoch - 10ms/step
# Epoch 206/2000
# 16/16 - 0s - loss: 0.0158 - root_mean_squared_error: 0.1258 - mean_absolute_error: 0.0810 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1283 - val_mean_absolute_error: 0.0708 - 120ms/epoch - 8ms/step
# Epoch 207/2000
# 16/16 - 0s - loss: 0.0159 - root_mean_squared_error: 0.1262 - mean_absolute_error: 0.0808 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264 - val_mean_absolute_error: 0.0689 - 129ms/epoch - 8ms/step
# Epoch 208/2000
# 16/16 - 0s - loss: 0.0158 - root_mean_squared_error: 0.1257 - mean_absolute_error: 0.0810 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1296 - val_mean_absolute_error: 0.0712 - 170ms/epoch - 11ms/step
# Epoch 209/2000
# 16/16 - 0s - loss: 0.0159 - root_mean_squared_error: 0.1259 - mean_absolute_error: 0.0808 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1262 - val_mean_absolute_error: 0.0681 - 200ms/epoch - 13ms/step
# Epoch 210/2000
# 16/16 - 0s - loss: 0.0157 - root_mean_squared_error: 0.1254 - mean_absolute_error: 0.0809 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1256 - val_mean_absolute_error: 0.0671 - 197ms/epoch - 12ms/step
# Epoch 211/2000
# 16/16 - 0s - loss: 0.0158 - root_mean_squared_error: 0.1257 - mean_absolute_error: 0.0809 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1289 - val_mean_absolute_error: 0.0709 - 199ms/epoch - 12ms/step
# Epoch 212/2000
# 16/16 - 0s - loss: 0.0157 - root_mean_squared_error: 0.1254 - mean_absolute_error: 0.0807 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1270 - val_mean_absolute_error: 0.0681 - 198ms/epoch - 12ms/step
# Epoch 213/2000
# 16/16 - 0s - loss: 0.0158 - root_mean_squared_error: 0.1259 - mean_absolute_error: 0.0807 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285 - val_mean_absolute_error: 0.0698 - 196ms/epoch - 12ms/step
# Epoch 214/2000
# 16/16 - 0s - loss: 0.0158 - root_mean_squared_error: 0.1258 - mean_absolute_error: 0.0808 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1264 - val_mean_absolute_error: 0.0685 - 196ms/epoch - 12ms/step
# Epoch 215/2000
# ...
# Epoch 1930/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1074 - mean_absolute_error: 0.0612 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1235 - val_mean_absolute_error: 0.0602 - 136ms/epoch - 8ms/step
# Epoch 1931/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1072 - mean_absolute_error: 0.0618 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1231 - val_mean_absolute_error: 0.0601 - 125ms/epoch - 8ms/step
# Epoch 1932/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0614 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223 - val_mean_absolute_error: 0.0596 - 142ms/epoch - 9ms/step
# Epoch 1933/2000
# 16/16 - 0s - loss: 0.0116 - root_mean_squared_error: 0.1079 - mean_absolute_error: 0.0615 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1229 - val_mean_absolute_error: 0.0599 - 146ms/epoch - 9ms/step
# Epoch 1934/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0610 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221 - val_mean_absolute_error: 0.0597 - 129ms/epoch - 8ms/step
# Epoch 1935/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1071 - mean_absolute_error: 0.0615 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223 - val_mean_absolute_error: 0.0594 - 123ms/epoch - 8ms/step
# Epoch 1936/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0610 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.0596 - 123ms/epoch - 8ms/step
# Epoch 1937/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0617 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1222 - val_mean_absolute_error: 0.0592 - 130ms/epoch - 8ms/step
# Epoch 1938/2000
#
# Epoch 1938: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1071 - mean_absolute_error: 0.0606 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1252 - val_mean_absolute_error: 0.0619 - 209ms/epoch - 13ms/step
# Epoch 1939/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1073 - mean_absolute_error: 0.0608 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1223 - val_mean_absolute_error: 0.0582 - 142ms/epoch - 9ms/step
# Epoch 1940/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1061 - mean_absolute_error: 0.0606 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1254 - val_mean_absolute_error: 0.0622 - 165ms/epoch - 10ms/step
# Epoch 1941/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1072 - mean_absolute_error: 0.0611 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1218 - val_mean_absolute_error: 0.0580 - 128ms/epoch - 8ms/step
# Epoch 1942/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1067 - mean_absolute_error: 0.0605 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265 - val_mean_absolute_error: 0.0631 - 166ms/epoch - 10ms/step
# Epoch 1943/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1080 - mean_absolute_error: 0.0608 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233 - val_mean_absolute_error: 0.0600 - 137ms/epoch - 9ms/step
# Epoch 1944/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1072 - mean_absolute_error: 0.0609 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.0594 - 135ms/epoch - 8ms/step
# Epoch 1945/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1066 - mean_absolute_error: 0.0610 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.0588 - 135ms/epoch - 8ms/step
# Epoch 1946/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1068 - mean_absolute_error: 0.0613 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225 - val_mean_absolute_error: 0.0590 - 179ms/epoch - 11ms/step
# Epoch 1947/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1071 - mean_absolute_error: 0.0610 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1243 - val_mean_absolute_error: 0.0604 - 140ms/epoch - 9ms/step
# Epoch 1948/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1071 - mean_absolute_error: 0.0614 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219 - val_mean_absolute_error: 0.0587 - 132ms/epoch - 8ms/step
# Epoch 1949/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1074 - mean_absolute_error: 0.0613 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1256 - val_mean_absolute_error: 0.0625 - 158ms/epoch - 10ms/step
# Epoch 1950/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1071 - mean_absolute_error: 0.0612 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1220 - val_mean_absolute_error: 0.0583 - 129ms/epoch - 8ms/step
# Epoch 1951/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1064 - mean_absolute_error: 0.0605 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.0603 - 130ms/epoch - 8ms/step
# Epoch 1952/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1065 - mean_absolute_error: 0.0609 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.0590 - 177ms/epoch - 11ms/step
# Epoch 1953/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1080 - mean_absolute_error: 0.0614 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1223 - val_mean_absolute_error: 0.0585 - 169ms/epoch - 11ms/step
# Epoch 1954/2000
# 16/16 - 0s - loss: 0.0116 - root_mean_squared_error: 0.1079 - mean_absolute_error: 0.0612 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1240 - val_mean_absolute_error: 0.0619 - 136ms/epoch - 9ms/step
# Epoch 1955/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1068 - mean_absolute_error: 0.0610 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1223 - val_mean_absolute_error: 0.0593 - 133ms/epoch - 8ms/step
# Epoch 1956/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1073 - mean_absolute_error: 0.0612 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1242 - val_mean_absolute_error: 0.0620 - 131ms/epoch - 8ms/step
# Epoch 1957/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1081 - mean_absolute_error: 0.0616 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.0597 - 143ms/epoch - 9ms/step
# Epoch 1958/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0609 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.0598 - 135ms/epoch - 8ms/step
# Epoch 1959/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1064 - mean_absolute_error: 0.0605 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248 - val_mean_absolute_error: 0.0607 - 136ms/epoch - 9ms/step
# Epoch 1960/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1080 - mean_absolute_error: 0.0617 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1208 - val_mean_absolute_error: 0.0581 - 143ms/epoch - 9ms/step
# Epoch 1961/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1074 - mean_absolute_error: 0.0616 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214 - val_mean_absolute_error: 0.0593 - 131ms/epoch - 8ms/step
# Epoch 1962/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1071 - mean_absolute_error: 0.0611 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1252 - val_mean_absolute_error: 0.0624 - 167ms/epoch - 10ms/step
# Epoch 1963/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1074 - mean_absolute_error: 0.0610 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212 - val_mean_absolute_error: 0.0590 - 184ms/epoch - 11ms/step
# Epoch 1964/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0609 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1231 - val_mean_absolute_error: 0.0603 - 136ms/epoch - 8ms/step
# Epoch 1965/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1067 - mean_absolute_error: 0.0611 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.0599 - 182ms/epoch - 11ms/step
# Epoch 1966/2000
# 16/16 - 0s - loss: 0.0116 - root_mean_squared_error: 0.1078 - mean_absolute_error: 0.0611 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.0593 - 136ms/epoch - 9ms/step
# Epoch 1967/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1068 - mean_absolute_error: 0.0610 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244 - val_mean_absolute_error: 0.0613 - 195ms/epoch - 12ms/step
# Epoch 1968/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1074 - mean_absolute_error: 0.0610 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221 - val_mean_absolute_error: 0.0587 - 134ms/epoch - 8ms/step
# Epoch 1969/2000
#
# Epoch 1969: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1066 - mean_absolute_error: 0.0608 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1253 - val_mean_absolute_error: 0.0623 - 245ms/epoch - 15ms/step
# Epoch 1970/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1082 - mean_absolute_error: 0.0615 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.0589 - 193ms/epoch - 12ms/step
# Epoch 1971/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1065 - mean_absolute_error: 0.0609 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249 - val_mean_absolute_error: 0.0619 - 155ms/epoch - 10ms/step
# Epoch 1972/2000
# 16/16 - 0s - loss: 0.0112 - root_mean_squared_error: 0.1059 - mean_absolute_error: 0.0611 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1243 - val_mean_absolute_error: 0.0612 - 136ms/epoch - 9ms/step
# Epoch 1973/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1063 - mean_absolute_error: 0.0607 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1245 - val_mean_absolute_error: 0.0613 - 138ms/epoch - 9ms/step
# Epoch 1974/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1067 - mean_absolute_error: 0.0611 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1205 - val_mean_absolute_error: 0.0576 - 176ms/epoch - 11ms/step
# Epoch 1975/2000
# 16/16 - 0s - loss: 0.0116 - root_mean_squared_error: 0.1077 - mean_absolute_error: 0.0612 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215 - val_mean_absolute_error: 0.0584 - 161ms/epoch - 10ms/step
# Epoch 1976/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0610 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238 - val_mean_absolute_error: 0.0605 - 142ms/epoch - 9ms/step
# Epoch 1977/2000
# 16/16 - 0s - loss: 0.0116 - root_mean_squared_error: 0.1075 - mean_absolute_error: 0.0613 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1200 - val_mean_absolute_error: 0.0565 - 148ms/epoch - 9ms/step
# Epoch 1978/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0607 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.0589 - 166ms/epoch - 10ms/step
# Epoch 1979/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1084 - mean_absolute_error: 0.0616 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233 - val_mean_absolute_error: 0.0594 - 175ms/epoch - 11ms/step
# Epoch 1980/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1068 - mean_absolute_error: 0.0610 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1225 - val_mean_absolute_error: 0.0596 - 140ms/epoch - 9ms/step
# Epoch 1981/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1068 - mean_absolute_error: 0.0610 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.0595 - 213ms/epoch - 13ms/step
# Epoch 1982/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0610 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1237 - val_mean_absolute_error: 0.0613 - 190ms/epoch - 12ms/step
# Epoch 1983/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1064 - mean_absolute_error: 0.0606 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223 - val_mean_absolute_error: 0.0595 - 208ms/epoch - 13ms/step
# Epoch 1984/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1072 - mean_absolute_error: 0.0614 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.0591 - 215ms/epoch - 13ms/step
# Epoch 1985/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1081 - mean_absolute_error: 0.0614 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1241 - val_mean_absolute_error: 0.0608 - 219ms/epoch - 14ms/step
# Epoch 1986/2000
# 16/16 - 0s - loss: 0.0116 - root_mean_squared_error: 0.1076 - mean_absolute_error: 0.0614 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1231 - val_mean_absolute_error: 0.0602 - 223ms/epoch - 14ms/step
# Epoch 1987/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1062 - mean_absolute_error: 0.0611 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215 - val_mean_absolute_error: 0.0582 - 227ms/epoch - 14ms/step
# Epoch 1988/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1073 - mean_absolute_error: 0.0610 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1243 - val_mean_absolute_error: 0.0608 - 216ms/epoch - 14ms/step
# Epoch 1989/2000
# 16/16 - 0s - loss: 0.0117 - root_mean_squared_error: 0.1081 - mean_absolute_error: 0.0610 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1232 - val_mean_absolute_error: 0.0599 - 223ms/epoch - 14ms/step
# Epoch 1990/2000
# 16/16 - 0s - loss: 0.0114 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0612 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1240 - val_mean_absolute_error: 0.0605 - 236ms/epoch - 15ms/step
# Epoch 1991/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1074 - mean_absolute_error: 0.0612 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1239 - val_mean_absolute_error: 0.0604 - 205ms/epoch - 13ms/step
# Epoch 1992/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0611 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210 - val_mean_absolute_error: 0.0585 - 219ms/epoch - 14ms/step
# Epoch 1993/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1073 - mean_absolute_error: 0.0613 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233 - val_mean_absolute_error: 0.0603 - 198ms/epoch - 12ms/step
# Epoch 1994/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1071 - mean_absolute_error: 0.0612 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1215 - val_mean_absolute_error: 0.0576 - 237ms/epoch - 15ms/step
# Epoch 1995/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1073 - mean_absolute_error: 0.0613 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238 - val_mean_absolute_error: 0.0607 - 231ms/epoch - 14ms/step
# Epoch 1996/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1072 - mean_absolute_error: 0.0605 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.0596 - 218ms/epoch - 14ms/step
# Epoch 1997/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1063 - mean_absolute_error: 0.0606 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221 - val_mean_absolute_error: 0.0589 - 225ms/epoch - 14ms/step
# Epoch 1998/2000
# 16/16 - 0s - loss: 0.0115 - root_mean_squared_error: 0.1070 - mean_absolute_error: 0.0608 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238 - val_mean_absolute_error: 0.0606 - 174ms/epoch - 11ms/step
# Epoch 1999/2000
# 16/16 - 0s - loss: 0.0113 - root_mean_squared_error: 0.1061 - mean_absolute_error: 0.0603 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1227 - val_mean_absolute_error: 0.0594 - 139ms/epoch - 9ms/step
# Epoch 2000/2000
#
# Epoch 2000: saving model to dae_training_ft_fridge/cp.ckpt
# 16/16 - 0s - loss: 0.0116 - root_mean_squared_error: 0.1075 - mean_absolute_error: 0.0608 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1220 - val_mean_absolute_error: 0.0593 - 237ms/epoch - 15ms/step

# %%
if not SKIP_TRAINING:
    print('Time spent', time_spent)
    plot_model_history(history)
# Out:
# Time spent 325.87297171699845
# dict_keys(['loss', 'root_mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error'])

# %%
# Predict from test split
y_test, y_pred = predict(model, feature=FEATURE, df_test=df_test, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH)
# Out:
# x_test.shape, y_test.shape
# (190700, 1) (190700, 1)
# 6/6 [==============================] - 0s 9ms/step
# y_test.shape, y_pred.shape
# (190720,) (5960, 32, 1)
# y_test.shape, y_pred.shape
# (190700,) (190700,)
# Normalized: y_test.mean, y_pred.mean
# 0.11840272151495979 0.10882797
# Denormalized: y_test.mean, y_pred.mean
# 38.491688451631035 35.461502

# %%
# plot_prediction_windows(FEATURE, y_test_denorm, y_pred_denorm)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=False, n_samples=n_samples)

# %%
n_samples = 80
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, active_factor=4, n_samples=n_samples)

# %%
n_samples = 200
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, n_samples=n_samples)

# %%
from lib import analysis
from lib.logging import losses_to_file, metrics_to_file

# %%
params = {}
params["algo"] = 'dae'
params["feature"] = FEATURE
params["seq_len"] = SEQ_LEN
params["seq_per_batch"] = SEQ_PER_BATCH
params["strides"] = N_STRIDES
params["epochs"] = EPOCHS
params["train_rows"] = df_train.shape[0]
params["val_rows"] = df_val.shape[0]
params["test_rows"] = df_test.shape[0]
params["norm_value"] = ref_norm
params["norm_type"] = NORM_TYPE
params["learning_rate"] = LEARNING_RATE
params["loss"] = 'adam'
params["clipvalue"] = CLIP_VALUE

# %%
print(params)
# Out:
# {'algo': 'dae', 'feature': 'ft_fridge', 'seq_len': 32, 'seq_per_batch': 1024, 'strides': 1, 'epochs': 2000, 'train_rows': 521300, 'val_rows': 316800, 'test_rows': 190700, 'norm_value': 325.09125, 'norm_type': 'mean', 'learning_rate': 0.01, 'loss': 'adam', 'clipvalue': 10.0}

# %%
results = analysis.classification_results(y_test, y_pred, on_threshold = 10)

metrics = {}
metrics["mae"] = analysis.mse_loss(y_test, y_pred)
metrics["mse"] = analysis.mae_loss(y_test, y_pred)
metrics["f1"] = analysis.f1(results)
metrics["accuracy"] = analysis.accuracy(results)
metrics["precision"] = analysis.precision(results)
metrics["recall"] = analysis.recall(results)

# %%
print(metrics)
# Out:
# {'mae': 1761.4390230771467, 'mse': 21.1715040073638, 'f1': 0.801888146458928, 'accuracy': 0.8045673833245937, 'precision': 0.6870400058296291, 'recall': 0.962840037274851}

# %%
if not SKIP_TRAINING:
    losses_to_file(1, params, history.history)

# %%
metrics_to_file(1, params, metrics)
