# %%
# Constants
MAX_NO_ROWS = 1000000
LOAD_MODEL=True
SKIP_TRAINING=True
FEATURE = 'ft_dishwasher'
SEQ_PER_BATCH = 1024
SEQ_LEN = 32
N_STRIDES = 1
NORM_TYPE = 'mean'
LEARNING_RATE = 1e-2
CLIP_VALUE = 10.
EPOCHS = 100
ALGO = 'cnn'
CHECKPOINT_PATH = f"{ALGO}_training_{FEATURE}/cp.ckpt"

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Dissertation
# Out:
# /content/drive/My Drive/Colab Notebooks/Dissertation

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.21.6)

# %%
from lib.chunk_reader import read_labels, get_merged_chunks, get_dates
from lib.plotting import plot_ft_days, plot_model_history, plot_prediction_windows
from lib.analysis import print_heads_tails

# %%
labels = read_labels(1)
for house in range(1,2):
    print('House {}: '.format(house), labels[house], '\n')
# Out:
# House 1:  ['mains_active', 'mains_apparent', 'mains_rms', 'aggregate_apparent', 'ft_boiler', 'ft_solar_thermal_pump', 'ft_washing_machine', 'ft_dishwasher', 'ft_tv', 'ft_kitchen_lights', 'ft_htpc', 'ft_kettle', 'ft_toaster', 'ft_fridge', 'ft_microwave', 'ft_amp_livingroom', 'ft_adsl_router', 'ft_livingroom_s_lamp', 'ft_lighting_circuit', 'ft_subwoofer_livingroom', 'ft_livingroom_lamp_tv', 'ft_kitchen_phone&stereo', 'ft_coffee_machine', 'ft_gas_oven', 'ft_data_logger_pc', 'ft_office_lamp2', 'aggregate_active', 'unix_time']

# %%
ref_chunk_df = get_merged_chunks(1, 1)
print('Original DF shape', ref_chunk_df.shape)
print('---')
ref_chunk_df = ref_chunk_df[0:MAX_NO_ROWS]
# Out:
# reading house 1; chunk 1
# reading file data/ukdale-parsed-chunks/house_1/chunk_1.dat; for house 1 and chunk 1
# read house 1; chunk 1; df.shape is (4500000, 29)
# Original DF shape (4500000, 29)
# ---

# %%
dates = {}
# for house in range(1,2):
dates[1] = get_dates(ref_chunk_df, 1)
# Out:
# House 1 data contain 71 days from 2013-04-11 to 2013-06-20.
# ['2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05-13', '2013-05-14', '2013-05-15', '2013-05-16', '2013-05-17', '2013-05-18', '2013-05-19', '2013-05-20', '2013-05-21', '2013-05-22', '2013-05-23', '2013-05-24', '2013-05-25', '2013-05-26', '2013-05-27', '2013-05-28', '2013-05-29', '2013-05-30', '2013-05-31', '2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04', '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08', '2013-06-09', '2013-06-10', '2013-06-11', '2013-06-12', '2013-06-13', '2013-06-14', '2013-06-15', '2013-06-16', '2013-06-17', '2013-06-18', '2013-06-19', '2013-06-20']

# %%
# Constants 2
rows_per_day = ref_chunk_df.loc[:dates[1][2]].shape[0]

# %%
from algos.processing import split_df_by_dates
from algos.cnn import create_model, train, predict
from algos.norm import get_ref_norm, denormalize, normalize

# %%
# Separate house 1 data into train, validation and test data
df_train, df_val, df_test  =  split_df_by_dates(ref_chunk_df, dates=dates, house=1)
# Out:
# df_train.shape:  (521300, 29)
# df_val.shape:  (316800, 29)
# df_test.shape:  (190700, 29)

# %%
ref_norm = get_ref_norm(df_train, NORM_TYPE)
# Out:
# ref_mean: 325.09124755859375; ref_max: 6002.919921875; ref_std: 434.2580871582031
# norm_type: mean; ref_norm 325.09124755859375

# %%
model = create_model(seq_len=SEQ_LEN, learning_rate=LEARNING_RATE, clipvalue=CLIP_VALUE)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 32, 30)            330
#
#  conv1d_1 (Conv1D)           (None, 32, 30)            7230
#
#  conv1d_2 (Conv1D)           (None, 32, 40)            7240
#
#  conv1d_3 (Conv1D)           (None, 32, 50)            10050
#
#  conv1d_4 (Conv1D)           (None, 32, 50)            12550
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 1024)              1639424
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 1,677,849
# Trainable params: 1,677,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !!!!!!!Counter!!!!!!! 
# Manually update for every new loaded training
# Run Counter = 0

# Load and or Train
if LOAD_MODEL:
  model.load_weights(CHECKPOINT_PATH)
if SKIP_TRAINING:
  pass
else:
  model, history, time_spent = train(model, feature=FEATURE, df_train=df_train, df_val=df_val, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH, epochs=EPOCHS, checkpoint_path=CHECKPOINT_PATH)
# Out:
# x_train.shape, y_train.shape, x_val.shape, x_val.shape
# (521300, 1) (521300, 1) (316800, 1) (316800, 1)
# self.data_len 521300
# seq_len 32
# n_sequences 521268
# x.shape, y.shape (521268, 32, 1) (521268,)
# seq_index 0
# seq_index 160000
# seq_index 320000
# seq_index 480000
# self.data_len 316800
# seq_len 32
# n_sequences 316768
# x.shape, y.shape (316768, 32, 1) (316768,)
# seq_index 0
# seq_index 160000
# Epoch 1/100
# 510/510 [==============================] - ETA: 0s - loss: 0.1954 - root_mean_squared_error: 0.4420 - mean_absolute_error: 0.0696
# Epoch 1: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 20s 17ms/step - loss: 0.1954 - root_mean_squared_error: 0.4420 - mean_absolute_error: 0.0696 - val_loss: 0.1277 - val_root_mean_squared_error: 0.3574 - val_mean_absolute_error: 0.0470
# Epoch 2/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.1800 - root_mean_squared_error: 0.4243 - mean_absolute_error: 0.0602
# Epoch 2: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.1801 - root_mean_squared_error: 0.4244 - mean_absolute_error: 0.0602 - val_loss: 0.1283 - val_root_mean_squared_error: 0.3582 - val_mean_absolute_error: 0.0444
# Epoch 3/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.1661 - root_mean_squared_error: 0.4076 - mean_absolute_error: 0.0559
# Epoch 3: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.1660 - root_mean_squared_error: 0.4075 - mean_absolute_error: 0.0558 - val_loss: 0.1220 - val_root_mean_squared_error: 0.3493 - val_mean_absolute_error: 0.0426
# Epoch 4/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.1433 - root_mean_squared_error: 0.3785 - mean_absolute_error: 0.0499
# Epoch 4: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.1431 - root_mean_squared_error: 0.3783 - mean_absolute_error: 0.0499 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3206 - val_mean_absolute_error: 0.0314
# Epoch 5/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.1344 - root_mean_squared_error: 0.3666 - mean_absolute_error: 0.0470
# Epoch 5: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.1344 - root_mean_squared_error: 0.3666 - mean_absolute_error: 0.0470 - val_loss: 0.0784 - val_root_mean_squared_error: 0.2799 - val_mean_absolute_error: 0.0314
# Epoch 6/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.1246 - root_mean_squared_error: 0.3530 - mean_absolute_error: 0.0448
# Epoch 6: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.1246 - root_mean_squared_error: 0.3530 - mean_absolute_error: 0.0448 - val_loss: 0.0921 - val_root_mean_squared_error: 0.3035 - val_mean_absolute_error: 0.0279
# Epoch 7/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.1229 - root_mean_squared_error: 0.3506 - mean_absolute_error: 0.0443
# Epoch 7: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.1228 - root_mean_squared_error: 0.3504 - mean_absolute_error: 0.0444 - val_loss: 0.0878 - val_root_mean_squared_error: 0.2963 - val_mean_absolute_error: 0.0368
# Epoch 8/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.1182 - root_mean_squared_error: 0.3438 - mean_absolute_error: 0.0431
# Epoch 8: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.1182 - root_mean_squared_error: 0.3438 - mean_absolute_error: 0.0431 - val_loss: 0.1286 - val_root_mean_squared_error: 0.3586 - val_mean_absolute_error: 0.0294
# Epoch 9/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.1174 - root_mean_squared_error: 0.3426 - mean_absolute_error: 0.0428
# Epoch 9: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.1173 - root_mean_squared_error: 0.3425 - mean_absolute_error: 0.0428 - val_loss: 0.0788 - val_root_mean_squared_error: 0.2807 - val_mean_absolute_error: 0.0316
# Epoch 10/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.1146 - root_mean_squared_error: 0.3385 - mean_absolute_error: 0.0417
# Epoch 10: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.1146 - root_mean_squared_error: 0.3385 - mean_absolute_error: 0.0417 - val_loss: 0.0746 - val_root_mean_squared_error: 0.2731 - val_mean_absolute_error: 0.0316
# Epoch 11/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.1163 - root_mean_squared_error: 0.3411 - mean_absolute_error: 0.0423
# Epoch 11: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.1163 - root_mean_squared_error: 0.3410 - mean_absolute_error: 0.0423 - val_loss: 0.0799 - val_root_mean_squared_error: 0.2827 - val_mean_absolute_error: 0.0267
# Epoch 12/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.1101 - root_mean_squared_error: 0.3319 - mean_absolute_error: 0.0404
# Epoch 12: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.1102 - root_mean_squared_error: 0.3319 - mean_absolute_error: 0.0404 - val_loss: 0.1310 - val_root_mean_squared_error: 0.3619 - val_mean_absolute_error: 0.0413
# Epoch 13/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.1114 - root_mean_squared_error: 0.3337 - mean_absolute_error: 0.0407
# Epoch 13: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.1113 - root_mean_squared_error: 0.3336 - mean_absolute_error: 0.0407 - val_loss: 0.0674 - val_root_mean_squared_error: 0.2597 - val_mean_absolute_error: 0.0264
# Epoch 14/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0957 - root_mean_squared_error: 0.3094 - mean_absolute_error: 0.0369
# Epoch 14: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0957 - root_mean_squared_error: 0.3093 - mean_absolute_error: 0.0368 - val_loss: 0.0658 - val_root_mean_squared_error: 0.2565 - val_mean_absolute_error: 0.0222
# Epoch 15/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0527 - root_mean_squared_error: 0.2295 - mean_absolute_error: 0.0252
# Epoch 15: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0527 - root_mean_squared_error: 0.2295 - mean_absolute_error: 0.0252 - val_loss: 0.0497 - val_root_mean_squared_error: 0.2228 - val_mean_absolute_error: 0.0175
# Epoch 16/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0468 - root_mean_squared_error: 0.2163 - mean_absolute_error: 0.0238
# Epoch 16: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.0466 - root_mean_squared_error: 0.2158 - mean_absolute_error: 0.0238 - val_loss: 0.0529 - val_root_mean_squared_error: 0.2299 - val_mean_absolute_error: 0.0201
# Epoch 17/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0466 - root_mean_squared_error: 0.2159 - mean_absolute_error: 0.0240
# Epoch 17: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0466 - root_mean_squared_error: 0.2159 - mean_absolute_error: 0.0240 - val_loss: 0.0673 - val_root_mean_squared_error: 0.2594 - val_mean_absolute_error: 0.0229
# Epoch 18/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0460 - root_mean_squared_error: 0.2144 - mean_absolute_error: 0.0237
# Epoch 18: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.0459 - root_mean_squared_error: 0.2142 - mean_absolute_error: 0.0237 - val_loss: 0.0603 - val_root_mean_squared_error: 0.2455 - val_mean_absolute_error: 0.0217
# Epoch 19/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0439 - root_mean_squared_error: 0.2096 - mean_absolute_error: 0.0230
# Epoch 19: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0438 - root_mean_squared_error: 0.2093 - mean_absolute_error: 0.0230 - val_loss: 0.0535 - val_root_mean_squared_error: 0.2313 - val_mean_absolute_error: 0.0211
# Epoch 20/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0429 - root_mean_squared_error: 0.2072 - mean_absolute_error: 0.0226
# Epoch 20: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072 - mean_absolute_error: 0.0226 - val_loss: 0.0557 - val_root_mean_squared_error: 0.2360 - val_mean_absolute_error: 0.0212
# Epoch 21/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0428 - root_mean_squared_error: 0.2068 - mean_absolute_error: 0.0227
# Epoch 21: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.0428 - root_mean_squared_error: 0.2068 - mean_absolute_error: 0.0227 - val_loss: 0.0556 - val_root_mean_squared_error: 0.2359 - val_mean_absolute_error: 0.0200
# Epoch 22/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0437 - root_mean_squared_error: 0.2090 - mean_absolute_error: 0.0230
# Epoch 22: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0437 - root_mean_squared_error: 0.2089 - mean_absolute_error: 0.0230 - val_loss: 0.0553 - val_root_mean_squared_error: 0.2351 - val_mean_absolute_error: 0.0215
# Epoch 23/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0411 - root_mean_squared_error: 0.2028 - mean_absolute_error: 0.0224
# Epoch 23: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0411 - root_mean_squared_error: 0.2028 - mean_absolute_error: 0.0224 - val_loss: 0.0473 - val_root_mean_squared_error: 0.2175 - val_mean_absolute_error: 0.0193
# Epoch 24/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0420 - root_mean_squared_error: 0.2050 - mean_absolute_error: 0.0229
# Epoch 24: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.0420 - root_mean_squared_error: 0.2050 - mean_absolute_error: 0.0229 - val_loss: 0.0644 - val_root_mean_squared_error: 0.2538 - val_mean_absolute_error: 0.0228
# Epoch 25/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0376 - root_mean_squared_error: 0.1940 - mean_absolute_error: 0.0215
# Epoch 25: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 19ms/step - loss: 0.0376 - root_mean_squared_error: 0.1940 - mean_absolute_error: 0.0215 - val_loss: 0.0621 - val_root_mean_squared_error: 0.2492 - val_mean_absolute_error: 0.0217
# Epoch 26/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0383 - root_mean_squared_error: 0.1957 - mean_absolute_error: 0.0217
# Epoch 26: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0383 - root_mean_squared_error: 0.1957 - mean_absolute_error: 0.0217 - val_loss: 0.0566 - val_root_mean_squared_error: 0.2380 - val_mean_absolute_error: 0.0216
# Epoch 27/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0379 - root_mean_squared_error: 0.1946 - mean_absolute_error: 0.0216
# Epoch 27: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.0379 - root_mean_squared_error: 0.1946 - mean_absolute_error: 0.0216 - val_loss: 0.0576 - val_root_mean_squared_error: 0.2400 - val_mean_absolute_error: 0.0198
# Epoch 28/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0354 - root_mean_squared_error: 0.1881 - mean_absolute_error: 0.0210
# Epoch 28: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0354 - root_mean_squared_error: 0.1881 - mean_absolute_error: 0.0210 - val_loss: 0.0632 - val_root_mean_squared_error: 0.2514 - val_mean_absolute_error: 0.0207
# Epoch 29/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0372 - root_mean_squared_error: 0.1929 - mean_absolute_error: 0.0215
# Epoch 29: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0373 - root_mean_squared_error: 0.1930 - mean_absolute_error: 0.0215 - val_loss: 0.0681 - val_root_mean_squared_error: 0.2609 - val_mean_absolute_error: 0.0285
# Epoch 30/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0357 - root_mean_squared_error: 0.1890 - mean_absolute_error: 0.0207
# Epoch 30: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 15ms/step - loss: 0.0357 - root_mean_squared_error: 0.1888 - mean_absolute_error: 0.0207 - val_loss: 0.0520 - val_root_mean_squared_error: 0.2280 - val_mean_absolute_error: 0.0205
# Epoch 31/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0399 - root_mean_squared_error: 0.1997 - mean_absolute_error: 0.0218
# Epoch 31: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0399 - root_mean_squared_error: 0.1997 - mean_absolute_error: 0.0218 - val_loss: 0.0548 - val_root_mean_squared_error: 0.2341 - val_mean_absolute_error: 0.0209
# Epoch 32/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0361 - root_mean_squared_error: 0.1901 - mean_absolute_error: 0.0209
# Epoch 32: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0361 - root_mean_squared_error: 0.1900 - mean_absolute_error: 0.0209 - val_loss: 0.0559 - val_root_mean_squared_error: 0.2364 - val_mean_absolute_error: 0.0181
# Epoch 33/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0347 - root_mean_squared_error: 0.1863 - mean_absolute_error: 0.0205
# Epoch 33: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0347 - root_mean_squared_error: 0.1863 - mean_absolute_error: 0.0205 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2600 - val_mean_absolute_error: 0.0228
# Epoch 34/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0331 - root_mean_squared_error: 0.1818 - mean_absolute_error: 0.0203
# Epoch 34: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0331 - root_mean_squared_error: 0.1818 - mean_absolute_error: 0.0203 - val_loss: 0.0560 - val_root_mean_squared_error: 0.2367 - val_mean_absolute_error: 0.0194
# Epoch 35/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0320 - root_mean_squared_error: 0.1789 - mean_absolute_error: 0.0199
# Epoch 35: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0322 - root_mean_squared_error: 0.1795 - mean_absolute_error: 0.0200 - val_loss: 0.0568 - val_root_mean_squared_error: 0.2383 - val_mean_absolute_error: 0.0204
# Epoch 36/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0328 - root_mean_squared_error: 0.1810 - mean_absolute_error: 0.0201
# Epoch 36: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 19ms/step - loss: 0.0328 - root_mean_squared_error: 0.1810 - mean_absolute_error: 0.0201 - val_loss: 0.0630 - val_root_mean_squared_error: 0.2510 - val_mean_absolute_error: 0.0205
# Epoch 37/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0339 - root_mean_squared_error: 0.1842 - mean_absolute_error: 0.0206
# Epoch 37: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0339 - root_mean_squared_error: 0.1841 - mean_absolute_error: 0.0206 - val_loss: 0.0602 - val_root_mean_squared_error: 0.2454 - val_mean_absolute_error: 0.0199
# Epoch 38/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0291 - root_mean_squared_error: 0.1707 - mean_absolute_error: 0.0192
# Epoch 38: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0292 - root_mean_squared_error: 0.1709 - mean_absolute_error: 0.0192 - val_loss: 0.0586 - val_root_mean_squared_error: 0.2422 - val_mean_absolute_error: 0.0193
# Epoch 39/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0305 - root_mean_squared_error: 0.1746 - mean_absolute_error: 0.0198
# Epoch 39: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0305 - root_mean_squared_error: 0.1746 - mean_absolute_error: 0.0198 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2303 - val_mean_absolute_error: 0.0189
# Epoch 40/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0293 - root_mean_squared_error: 0.1713 - mean_absolute_error: 0.0193
# Epoch 40: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0293 - root_mean_squared_error: 0.1713 - mean_absolute_error: 0.0193 - val_loss: 0.0605 - val_root_mean_squared_error: 0.2459 - val_mean_absolute_error: 0.0219
# Epoch 41/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0305 - root_mean_squared_error: 0.1746 - mean_absolute_error: 0.0196
# Epoch 41: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0305 - root_mean_squared_error: 0.1745 - mean_absolute_error: 0.0196 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2570 - val_mean_absolute_error: 0.0187
# Epoch 42/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0318 - root_mean_squared_error: 0.1783 - mean_absolute_error: 0.0197
# Epoch 42: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0319 - root_mean_squared_error: 0.1787 - mean_absolute_error: 0.0197 - val_loss: 0.0501 - val_root_mean_squared_error: 0.2239 - val_mean_absolute_error: 0.0185
# Epoch 43/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0281 - root_mean_squared_error: 0.1677 - mean_absolute_error: 0.0190
# Epoch 43: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0283 - root_mean_squared_error: 0.1682 - mean_absolute_error: 0.0190 - val_loss: 0.0558 - val_root_mean_squared_error: 0.2363 - val_mean_absolute_error: 0.0189
# Epoch 44/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0266 - root_mean_squared_error: 0.1631 - mean_absolute_error: 0.0184
# Epoch 44: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0266 - root_mean_squared_error: 0.1631 - mean_absolute_error: 0.0184 - val_loss: 0.0615 - val_root_mean_squared_error: 0.2479 - val_mean_absolute_error: 0.0239
# Epoch 45/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0294 - root_mean_squared_error: 0.1714 - mean_absolute_error: 0.0191
# Epoch 45: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0294 - root_mean_squared_error: 0.1716 - mean_absolute_error: 0.0191 - val_loss: 0.0682 - val_root_mean_squared_error: 0.2612 - val_mean_absolute_error: 0.0214
# Epoch 46/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0301 - root_mean_squared_error: 0.1736 - mean_absolute_error: 0.0194
# Epoch 46: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0301 - root_mean_squared_error: 0.1736 - mean_absolute_error: 0.0194 - val_loss: 0.0576 - val_root_mean_squared_error: 0.2399 - val_mean_absolute_error: 0.0191
# Epoch 47/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0270 - root_mean_squared_error: 0.1642 - mean_absolute_error: 0.0185
# Epoch 47: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0270 - root_mean_squared_error: 0.1642 - mean_absolute_error: 0.0185 - val_loss: 0.0560 - val_root_mean_squared_error: 0.2366 - val_mean_absolute_error: 0.0201
# Epoch 48/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0288 - root_mean_squared_error: 0.1696 - mean_absolute_error: 0.0188
# Epoch 48: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0289 - root_mean_squared_error: 0.1699 - mean_absolute_error: 0.0188 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2541 - val_mean_absolute_error: 0.0205
# Epoch 49/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0253 - root_mean_squared_error: 0.1591 - mean_absolute_error: 0.0180
# Epoch 49: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0253 - root_mean_squared_error: 0.1592 - mean_absolute_error: 0.0180 - val_loss: 0.0553 - val_root_mean_squared_error: 0.2352 - val_mean_absolute_error: 0.0185
# Epoch 50/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0273 - root_mean_squared_error: 0.1653 - mean_absolute_error: 0.0186
# Epoch 50: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0273 - root_mean_squared_error: 0.1653 - mean_absolute_error: 0.0186 - val_loss: 0.0610 - val_root_mean_squared_error: 0.2469 - val_mean_absolute_error: 0.0220
# Epoch 51/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0270 - root_mean_squared_error: 0.1644 - mean_absolute_error: 0.0185
# Epoch 51: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0271 - root_mean_squared_error: 0.1645 - mean_absolute_error: 0.0185 - val_loss: 0.0569 - val_root_mean_squared_error: 0.2385 - val_mean_absolute_error: 0.0198
# Epoch 52/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0295 - root_mean_squared_error: 0.1717 - mean_absolute_error: 0.0192
# Epoch 52: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 17ms/step - loss: 0.0294 - root_mean_squared_error: 0.1716 - mean_absolute_error: 0.0192 - val_loss: 0.0591 - val_root_mean_squared_error: 0.2431 - val_mean_absolute_error: 0.0191
# Epoch 53/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0244 - root_mean_squared_error: 0.1563 - mean_absolute_error: 0.0177
# Epoch 53: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - mean_absolute_error: 0.0177 - val_loss: 0.0606 - val_root_mean_squared_error: 0.2462 - val_mean_absolute_error: 0.0205
# Epoch 54/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0239 - root_mean_squared_error: 0.1545 - mean_absolute_error: 0.0178
# Epoch 54: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - mean_absolute_error: 0.0178 - val_loss: 0.0651 - val_root_mean_squared_error: 0.2552 - val_mean_absolute_error: 0.0187
# Epoch 55/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0237 - root_mean_squared_error: 0.1540 - mean_absolute_error: 0.0176
# Epoch 55: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - mean_absolute_error: 0.0176 - val_loss: 0.0610 - val_root_mean_squared_error: 0.2470 - val_mean_absolute_error: 0.0186
# Epoch 56/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0254 - root_mean_squared_error: 0.1594 - mean_absolute_error: 0.0182
# Epoch 56: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0254 - root_mean_squared_error: 0.1593 - mean_absolute_error: 0.0182 - val_loss: 0.0581 - val_root_mean_squared_error: 0.2411 - val_mean_absolute_error: 0.0185
# Epoch 57/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0240 - root_mean_squared_error: 0.1549 - mean_absolute_error: 0.0177
# Epoch 57: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0240 - root_mean_squared_error: 0.1550 - mean_absolute_error: 0.0177 - val_loss: 0.0576 - val_root_mean_squared_error: 0.2400 - val_mean_absolute_error: 0.0173
# Epoch 58/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0219 - root_mean_squared_error: 0.1479 - mean_absolute_error: 0.0173
# Epoch 58: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0218 - root_mean_squared_error: 0.1478 - mean_absolute_error: 0.0173 - val_loss: 0.0584 - val_root_mean_squared_error: 0.2416 - val_mean_absolute_error: 0.0181
# Epoch 59/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0252 - root_mean_squared_error: 0.1589 - mean_absolute_error: 0.0181
# Epoch 59: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0251 - root_mean_squared_error: 0.1585 - mean_absolute_error: 0.0181 - val_loss: 0.0521 - val_root_mean_squared_error: 0.2282 - val_mean_absolute_error: 0.0173
# Epoch 60/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0255 - root_mean_squared_error: 0.1598 - mean_absolute_error: 0.0181
# Epoch 60: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0258 - root_mean_squared_error: 0.1606 - mean_absolute_error: 0.0182 - val_loss: 0.0606 - val_root_mean_squared_error: 0.2461 - val_mean_absolute_error: 0.0213
# Epoch 61/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0252 - root_mean_squared_error: 0.1588 - mean_absolute_error: 0.0180
# Epoch 61: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - mean_absolute_error: 0.0180 - val_loss: 0.0617 - val_root_mean_squared_error: 0.2484 - val_mean_absolute_error: 0.0184
# Epoch 62/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0218 - root_mean_squared_error: 0.1475 - mean_absolute_error: 0.0171
# Epoch 62: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - mean_absolute_error: 0.0171 - val_loss: 0.0556 - val_root_mean_squared_error: 0.2358 - val_mean_absolute_error: 0.0197
# Epoch 63/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0228 - root_mean_squared_error: 0.1511 - mean_absolute_error: 0.0176
# Epoch 63: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 17ms/step - loss: 0.0228 - root_mean_squared_error: 0.1511 - mean_absolute_error: 0.0176 - val_loss: 0.0637 - val_root_mean_squared_error: 0.2524 - val_mean_absolute_error: 0.0188
# Epoch 64/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0222 - root_mean_squared_error: 0.1488 - mean_absolute_error: 0.0170
# Epoch 64: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0221 - root_mean_squared_error: 0.1487 - mean_absolute_error: 0.0170 - val_loss: 0.0613 - val_root_mean_squared_error: 0.2477 - val_mean_absolute_error: 0.0189
# Epoch 65/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0238 - root_mean_squared_error: 0.1542 - mean_absolute_error: 0.0173
# Epoch 65: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0238 - root_mean_squared_error: 0.1542 - mean_absolute_error: 0.0173 - val_loss: 0.0595 - val_root_mean_squared_error: 0.2439 - val_mean_absolute_error: 0.0199
# Epoch 66/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0224 - root_mean_squared_error: 0.1497 - mean_absolute_error: 0.0167
# Epoch 66: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0224 - root_mean_squared_error: 0.1496 - mean_absolute_error: 0.0167 - val_loss: 0.0602 - val_root_mean_squared_error: 0.2453 - val_mean_absolute_error: 0.0197
# Epoch 67/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0219 - root_mean_squared_error: 0.1479 - mean_absolute_error: 0.0169
# Epoch 67: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 19ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490 - mean_absolute_error: 0.0170 - val_loss: 0.0556 - val_root_mean_squared_error: 0.2359 - val_mean_absolute_error: 0.0187
# Epoch 68/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0240 - root_mean_squared_error: 0.1549 - mean_absolute_error: 0.0176
# Epoch 68: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0240 - root_mean_squared_error: 0.1549 - mean_absolute_error: 0.0176 - val_loss: 0.0575 - val_root_mean_squared_error: 0.2398 - val_mean_absolute_error: 0.0195
# Epoch 69/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0203 - root_mean_squared_error: 0.1423 - mean_absolute_error: 0.0165
# Epoch 69: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0204 - root_mean_squared_error: 0.1429 - mean_absolute_error: 0.0165 - val_loss: 0.0594 - val_root_mean_squared_error: 0.2437 - val_mean_absolute_error: 0.0191
# Epoch 70/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0206 - root_mean_squared_error: 0.1437 - mean_absolute_error: 0.0166
# Epoch 70: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0206 - root_mean_squared_error: 0.1436 - mean_absolute_error: 0.0166 - val_loss: 0.0612 - val_root_mean_squared_error: 0.2474 - val_mean_absolute_error: 0.0211
# Epoch 71/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1493 - mean_absolute_error: 0.0171
# Epoch 71: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0223 - root_mean_squared_error: 0.1492 - mean_absolute_error: 0.0171 - val_loss: 0.0649 - val_root_mean_squared_error: 0.2548 - val_mean_absolute_error: 0.0207
# Epoch 72/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0207 - root_mean_squared_error: 0.1440 - mean_absolute_error: 0.0168
# Epoch 72: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440 - mean_absolute_error: 0.0168 - val_loss: 0.0543 - val_root_mean_squared_error: 0.2330 - val_mean_absolute_error: 0.0166
# Epoch 73/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0232 - root_mean_squared_error: 0.1523 - mean_absolute_error: 0.0172
# Epoch 73: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - mean_absolute_error: 0.0172 - val_loss: 0.0543 - val_root_mean_squared_error: 0.2330 - val_mean_absolute_error: 0.0181
# Epoch 74/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0206 - root_mean_squared_error: 0.1437 - mean_absolute_error: 0.0164
# Epoch 74: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0206 - root_mean_squared_error: 0.1436 - mean_absolute_error: 0.0164 - val_loss: 0.0608 - val_root_mean_squared_error: 0.2465 - val_mean_absolute_error: 0.0224
# Epoch 75/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0191 - root_mean_squared_error: 0.1382 - mean_absolute_error: 0.0159
# Epoch 75: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0191 - root_mean_squared_error: 0.1382 - mean_absolute_error: 0.0159 - val_loss: 0.0600 - val_root_mean_squared_error: 0.2449 - val_mean_absolute_error: 0.0199
# Epoch 76/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0223 - root_mean_squared_error: 0.1492 - mean_absolute_error: 0.0169
# Epoch 76: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0223 - root_mean_squared_error: 0.1492 - mean_absolute_error: 0.0169 - val_loss: 0.0639 - val_root_mean_squared_error: 0.2527 - val_mean_absolute_error: 0.0188
# Epoch 77/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0221 - root_mean_squared_error: 0.1488 - mean_absolute_error: 0.0171
# Epoch 77: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - mean_absolute_error: 0.0171 - val_loss: 0.0663 - val_root_mean_squared_error: 0.2574 - val_mean_absolute_error: 0.0209
# Epoch 78/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0211 - root_mean_squared_error: 0.1452 - mean_absolute_error: 0.0166
# Epoch 78: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 17ms/step - loss: 0.0211 - root_mean_squared_error: 0.1454 - mean_absolute_error: 0.0166 - val_loss: 0.0612 - val_root_mean_squared_error: 0.2475 - val_mean_absolute_error: 0.0179
# Epoch 79/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0214 - root_mean_squared_error: 0.1463 - mean_absolute_error: 0.0168
# Epoch 79: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0214 - root_mean_squared_error: 0.1463 - mean_absolute_error: 0.0168 - val_loss: 0.0591 - val_root_mean_squared_error: 0.2431 - val_mean_absolute_error: 0.0183
# Epoch 80/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0211 - root_mean_squared_error: 0.1452 - mean_absolute_error: 0.0167
# Epoch 80: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 19ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - mean_absolute_error: 0.0167 - val_loss: 0.0606 - val_root_mean_squared_error: 0.2461 - val_mean_absolute_error: 0.0199
# Epoch 81/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0251 - root_mean_squared_error: 0.1586 - mean_absolute_error: 0.0178
# Epoch 81: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0253 - root_mean_squared_error: 0.1590 - mean_absolute_error: 0.0178 - val_loss: 0.0709 - val_root_mean_squared_error: 0.2662 - val_mean_absolute_error: 0.0213
# Epoch 82/100
# 506/510 [============================>.] - ETA: 0s - loss: 0.0229 - root_mean_squared_error: 0.1513 - mean_absolute_error: 0.0172
# Epoch 82: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0228 - root_mean_squared_error: 0.1510 - mean_absolute_error: 0.0172 - val_loss: 0.0603 - val_root_mean_squared_error: 0.2455 - val_mean_absolute_error: 0.0195
# Epoch 83/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1370 - mean_absolute_error: 0.0162
# Epoch 83: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 18ms/step - loss: 0.0188 - root_mean_squared_error: 0.1370 - mean_absolute_error: 0.0162 - val_loss: 0.0629 - val_root_mean_squared_error: 0.2508 - val_mean_absolute_error: 0.0207
# Epoch 84/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0215 - root_mean_squared_error: 0.1468 - mean_absolute_error: 0.0170
# Epoch 84: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467 - mean_absolute_error: 0.0169 - val_loss: 0.0644 - val_root_mean_squared_error: 0.2538 - val_mean_absolute_error: 0.0194
# Epoch 85/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0200 - root_mean_squared_error: 0.1415 - mean_absolute_error: 0.0166
# Epoch 85: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0200 - root_mean_squared_error: 0.1415 - mean_absolute_error: 0.0166 - val_loss: 0.0594 - val_root_mean_squared_error: 0.2437 - val_mean_absolute_error: 0.0195
# Epoch 86/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0187 - root_mean_squared_error: 0.1368 - mean_absolute_error: 0.0163
# Epoch 86: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0187 - root_mean_squared_error: 0.1368 - mean_absolute_error: 0.0163 - val_loss: 0.0612 - val_root_mean_squared_error: 0.2474 - val_mean_absolute_error: 0.0211
# Epoch 87/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0197 - root_mean_squared_error: 0.1404 - mean_absolute_error: 0.0165
# Epoch 87: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402 - mean_absolute_error: 0.0165 - val_loss: 0.0589 - val_root_mean_squared_error: 0.2427 - val_mean_absolute_error: 0.0198
# Epoch 88/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0177 - root_mean_squared_error: 0.1332 - mean_absolute_error: 0.0159
# Epoch 88: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0177 - root_mean_squared_error: 0.1331 - mean_absolute_error: 0.0159 - val_loss: 0.0617 - val_root_mean_squared_error: 0.2483 - val_mean_absolute_error: 0.0198
# Epoch 89/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0274 - root_mean_squared_error: 0.1656 - mean_absolute_error: 0.0183
# Epoch 89: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0274 - root_mean_squared_error: 0.1657 - mean_absolute_error: 0.0183 - val_loss: 0.0644 - val_root_mean_squared_error: 0.2538 - val_mean_absolute_error: 0.0206
# Epoch 90/100
# 509/510 [============================>.] - ETA: 0s - loss: 0.0182 - root_mean_squared_error: 0.1351 - mean_absolute_error: 0.0161
# Epoch 90: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0182 - root_mean_squared_error: 0.1351 - mean_absolute_error: 0.0161 - val_loss: 0.0597 - val_root_mean_squared_error: 0.2443 - val_mean_absolute_error: 0.0175
# Epoch 91/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0183 - root_mean_squared_error: 0.1351 - mean_absolute_error: 0.0158
# Epoch 91: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0182 - root_mean_squared_error: 0.1350 - mean_absolute_error: 0.0158 - val_loss: 0.0579 - val_root_mean_squared_error: 0.2406 - val_mean_absolute_error: 0.0195
# Epoch 92/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0168 - root_mean_squared_error: 0.1295 - mean_absolute_error: 0.0155
# Epoch 92: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 17ms/step - loss: 0.0168 - root_mean_squared_error: 0.1294 - mean_absolute_error: 0.0155 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2316 - val_mean_absolute_error: 0.0179
# Epoch 93/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0188 - root_mean_squared_error: 0.1372 - mean_absolute_error: 0.0162
# Epoch 93: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0188 - root_mean_squared_error: 0.1371 - mean_absolute_error: 0.0162 - val_loss: 0.0608 - val_root_mean_squared_error: 0.2465 - val_mean_absolute_error: 0.0220
# Epoch 94/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0202 - root_mean_squared_error: 0.1422 - mean_absolute_error: 0.0165
# Epoch 94: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0202 - root_mean_squared_error: 0.1421 - mean_absolute_error: 0.0165 - val_loss: 0.0631 - val_root_mean_squared_error: 0.2511 - val_mean_absolute_error: 0.0176
# Epoch 95/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0181 - root_mean_squared_error: 0.1344 - mean_absolute_error: 0.0160
# Epoch 95: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0182 - root_mean_squared_error: 0.1349 - mean_absolute_error: 0.0161 - val_loss: 0.0567 - val_root_mean_squared_error: 0.2381 - val_mean_absolute_error: 0.0177
# Epoch 96/100
# 510/510 [==============================] - ETA: 0s - loss: 0.0180 - root_mean_squared_error: 0.1342 - mean_absolute_error: 0.0160
# Epoch 96: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 9s 19ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - mean_absolute_error: 0.0160 - val_loss: 0.0593 - val_root_mean_squared_error: 0.2435 - val_mean_absolute_error: 0.0172
# Epoch 97/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0194 - root_mean_squared_error: 0.1394 - mean_absolute_error: 0.0163
# Epoch 97: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0195 - root_mean_squared_error: 0.1395 - mean_absolute_error: 0.0163 - val_loss: 0.0601 - val_root_mean_squared_error: 0.2452 - val_mean_absolute_error: 0.0209
# Epoch 98/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0197 - root_mean_squared_error: 0.1405 - mean_absolute_error: 0.0162
# Epoch 98: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 17ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404 - mean_absolute_error: 0.0162 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2494 - val_mean_absolute_error: 0.0195
# Epoch 99/100
# 507/510 [============================>.] - ETA: 0s - loss: 0.0210 - root_mean_squared_error: 0.1450 - mean_absolute_error: 0.0169
# Epoch 99: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 10s 19ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - mean_absolute_error: 0.0169 - val_loss: 0.0630 - val_root_mean_squared_error: 0.2510 - val_mean_absolute_error: 0.0185
# Epoch 100/100
# 508/510 [============================>.] - ETA: 0s - loss: 0.0186 - root_mean_squared_error: 0.1364 - mean_absolute_error: 0.0163
# Epoch 100: saving model to seq2seq_training_ft_dishwasher/cp.ckpt
# 510/510 [==============================] - 8s 16ms/step - loss: 0.0186 - root_mean_squared_error: 0.1365 - mean_absolute_error: 0.0163 - val_loss: 0.0596 - val_root_mean_squared_error: 0.2441 - val_mean_absolute_error: 0.0182

# %%
if not SKIP_TRAINING:
    print('Time spent', time_spent)
    plot_model_history(history)
# Out:
# Time spent 875.9748687680005
# dict_keys(['loss', 'root_mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error'])

# %%
# Predict from test split
y_test, y_pred = predict(model, feature=FEATURE, df_test=df_test, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH)
# Out:
# x_test.shape, y_test.shape
# (190700, 1) (190700, 1)
# self.data_len 190700
# seq_len 32
# n_sequences 190668
# x.shape, y.shape (190668, 32, 1) (190668,)
# seq_index 0
# seq_index 160000
# 187/187 [==============================] - 1s 5ms/step
# y_test.shape, y_pred.shape
# (190668,) (190668, 1)
# y_test.shape, y_pred.shape
# (190668,) (190668,)
# Normalized: y_test.mean, y_pred.mean
# 0.045529887 0.039504696
# Denormalized: y_test.mean, y_pred.mean
# 14.80137 12.85919

# %%
# plot_prediction_windows(FEATURE, y_test_denorm, y_pred_denorm)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=False, n_samples=n_samples)

# %%
n_samples = 80
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, active_factor=4, n_samples=n_samples)

# %%
n_samples = 200
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, n_samples=n_samples)

# %%
from lib import analysis
from lib.logging import losses_to_file, metrics_to_file

# %%
params = {}
params["algo"] = ALGO
params["feature"] = FEATURE
params["seq_len"] = SEQ_LEN
params["seq_per_batch"] = SEQ_PER_BATCH
params["strides"] = N_STRIDES
params["epochs"] = EPOCHS
params["train_rows"] = df_train.shape[0]
params["val_rows"] = df_val.shape[0]
params["test_rows"] = df_test.shape[0]
params["norm_value"] = ref_norm
params["norm_type"] = NORM_TYPE
params["learning_rate"] = LEARNING_RATE
params["loss"] = 'adam'
params["clipvalue"] = CLIP_VALUE

# %%
print(params)
# Out:
# {'algo': 'seq2seq', 'feature': 'ft_dishwasher', 'seq_len': 32, 'seq_per_batch': 1024, 'strides': 1, 'epochs': 100, 'train_rows': 521300, 'val_rows': 316800, 'test_rows': 190700, 'norm_value': 325.09125, 'norm_type': 'mean', 'learning_rate': 0.01, 'loss': 'adam', 'clipvalue': 10.0}

# %%
results = analysis.classification_results(y_test, y_pred, on_threshold = 100)

metrics = {}
metrics["mae"] = analysis.mse_loss(y_test, y_pred)
metrics["mse"] = analysis.mae_loss(y_test, y_pred)
metrics["f1"] = analysis.f1(results)
metrics["accuracy"] = analysis.accuracy(results)
metrics["precision"] = analysis.precision(results)
metrics["recall"] = analysis.recall(results)

# %%
print(metrics)
# Out:
# {'mae': 3462.6251695307915, 'mse': 5.324313632391919, 'f1': 0.4211635750421585, 'accuracy': 0.9855980028111692, 'precision': 0.9371482176360225, 'recall': 0.27161500815660683}

# %%
if not SKIP_TRAINING:
    losses_to_file(1, params, history.history)

# %%
metrics_to_file(1, params, metrics)
