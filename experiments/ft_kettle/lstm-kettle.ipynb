# %%
# Constants
MAX_NO_ROWS = 1000000
LOAD_MODEL=False
SKIP_TRAINING=False
FEATURE = 'ft_kettle'
SEQ_PER_BATCH = 1024
SEQ_LEN = 32
N_STRIDES = 1
NORM_TYPE = 'max'
LEARNING_RATE = 1e-3
CLIP_VALUE = 10.
EPOCHS = 40
CHECKPOINT_PATH = f"lstm_training_{FEATURE}/cp.ckpt"

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Dissertation
# Out:
# /content/drive/My Drive/Colab Notebooks/Dissertation

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.22.4)

# %%
from lib.chunk_reader import read_labels, get_merged_chunks, get_dates
from lib.plotting import plot_ft_days, plot_model_history, plot_prediction_windows
from lib.analysis import print_heads_tails

# %%
labels = read_labels(1)
for house in range(1,2):
    print('House {}: '.format(house), labels[house], '\n')
# Out:
# House 1:  ['mains_active', 'mains_apparent', 'mains_rms', 'aggregate_apparent', 'ft_boiler', 'ft_solar_thermal_pump', 'ft_washing_machine', 'ft_dishwasher', 'ft_tv', 'ft_kitchen_lights', 'ft_htpc', 'ft_kettle', 'ft_toaster', 'ft_fridge', 'ft_microwave', 'ft_amp_livingroom', 'ft_adsl_router', 'ft_livingroom_s_lamp', 'ft_lighting_circuit', 'ft_subwoofer_livingroom', 'ft_livingroom_lamp_tv', 'ft_kitchen_phone&stereo', 'ft_coffee_machine', 'ft_gas_oven', 'ft_data_logger_pc', 'ft_office_lamp2', 'aggregate_active', 'unix_time']

# %%
ref_chunk_df = get_merged_chunks(1, 1)
print('Original DF shape', ref_chunk_df.shape)
print('---')
ref_chunk_df = ref_chunk_df[0:MAX_NO_ROWS]
# Out:
# reading house 1; chunk 1
# reading file data/ukdale-parsed-chunks/house_1/chunk_1.dat; for house 1 and chunk 1
# read house 1; chunk 1; df.shape is (4500000, 29)
# Original DF shape (4500000, 29)
# ---

# %%
dates = {}
# for house in range(1,2):
dates[1] = get_dates(ref_chunk_df, 1)
# Out:
# House 1 data contain 71 days from 2013-04-11 to 2013-06-20.
# ['2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05-13', '2013-05-14', '2013-05-15', '2013-05-16', '2013-05-17', '2013-05-18', '2013-05-19', '2013-05-20', '2013-05-21', '2013-05-22', '2013-05-23', '2013-05-24', '2013-05-25', '2013-05-26', '2013-05-27', '2013-05-28', '2013-05-29', '2013-05-30', '2013-05-31', '2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04', '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08', '2013-06-09', '2013-06-10', '2013-06-11', '2013-06-12', '2013-06-13', '2013-06-14', '2013-06-15', '2013-06-16', '2013-06-17', '2013-06-18', '2013-06-19', '2013-06-20']

# %%
# Constants 2
rows_per_day = ref_chunk_df.loc[:dates[1][2]].shape[0]

# %%
from algos.processing import split_df_by_dates
from algos.lstm import create_model, train, predict
from algos.norm import get_ref_norm

# %%
# Separate house 1 data into train, validation and test data
df_train, df_val, df_test  =  split_df_by_dates(ref_chunk_df, dates=dates, house=1)
# Out:
# df_train.shape:  (521300, 29)
# df_val.shape:  (316800, 29)
# df_test.shape:  (190700, 29)

# %%
ref_norm = get_ref_norm(df_train, NORM_TYPE)
# Out:
# ref_mean: 325.09124755859375; ref_max: 6002.919921875; ref_std: 434.2580871582031
# norm_type: max; ref_norm 6002.919921875

# %%
model = create_model(seq_len=SEQ_LEN, learning_rate=LEARNING_RATE, clipvalue=CLIP_VALUE)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 32, 16)            80
#
#  bidirectional (Bidirectiona  (None, 32, 256)          148480
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 512)              1050624
#  nal)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,264,977
# Trainable params: 1,264,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !!!!!!!Counter!!!!!!! 
# Manually update for every new loaded training
# Run Counter = 0

# Load and or Train
if LOAD_MODEL:
  model.load_weights(CHECKPOINT_PATH)
if SKIP_TRAINING:
  pass
else:
  model, history, time_spent = train(model, feature=FEATURE, df_train=df_train, df_val=df_val, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH, epochs=EPOCHS, checkpoint_path=CHECKPOINT_PATH)
# Out:
# x_train.shape, y_train.shape, x_val.shape, x_val.shape
# (521300, 1) (521300, 1) (316800, 1) (316800, 1)
# self.data_len 521300
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 510
# x.shape, y.shape (522240, 32, 1) (522240,)
# batch_index 0
# batch_index 200
# batch_index 400
# self.data_len 316800
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 310
# x.shape, y.shape (317440, 32, 1) (317440,)
# batch_index 0
# batch_index 200
# Epoch 1/40
#   6/510 [..............................] - ETA: 50s - loss: 0.0033 - root_mean_squared_error: 0.0577 - mean_absolute_error: 0.0347
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0138s vs `on_train_batch_end` time: 0.0692s). Check your callbacks.
# 510/510 [==============================] - ETA: 0s - loss: 7.2666e-04 - root_mean_squared_error: 0.0270 - mean_absolute_error: 0.0077
# Epoch 1: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 75s 109ms/step - loss: 7.2666e-04 - root_mean_squared_error: 0.0270 - mean_absolute_error: 0.0077 - val_loss: 4.0322e-04 - val_root_mean_squared_error: 0.0201 - val_mean_absolute_error: 0.0047
# Epoch 2/40
# 510/510 [==============================] - ETA: 0s - loss: 4.5930e-04 - root_mean_squared_error: 0.0214 - mean_absolute_error: 0.0048
# Epoch 2: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 54s 106ms/step - loss: 4.5930e-04 - root_mean_squared_error: 0.0214 - mean_absolute_error: 0.0048 - val_loss: 2.8899e-04 - val_root_mean_squared_error: 0.0170 - val_mean_absolute_error: 0.0028
# Epoch 3/40
# 510/510 [==============================] - ETA: 0s - loss: 3.4105e-04 - root_mean_squared_error: 0.0185 - mean_absolute_error: 0.0036
# Epoch 3: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 55s 109ms/step - loss: 3.4105e-04 - root_mean_squared_error: 0.0185 - mean_absolute_error: 0.0036 - val_loss: 2.3283e-04 - val_root_mean_squared_error: 0.0153 - val_mean_absolute_error: 0.0019
# Epoch 4/40
# 510/510 [==============================] - ETA: 0s - loss: 3.0102e-04 - root_mean_squared_error: 0.0173 - mean_absolute_error: 0.0030
# Epoch 4: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 56s 110ms/step - loss: 3.0102e-04 - root_mean_squared_error: 0.0173 - mean_absolute_error: 0.0030 - val_loss: 2.2232e-04 - val_root_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0027
# Epoch 5/40
# 510/510 [==============================] - ETA: 0s - loss: 2.7378e-04 - root_mean_squared_error: 0.0165 - mean_absolute_error: 0.0028
# Epoch 5: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 56s 111ms/step - loss: 2.7378e-04 - root_mean_squared_error: 0.0165 - mean_absolute_error: 0.0028 - val_loss: 2.0828e-04 - val_root_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0020
# Epoch 6/40
# 510/510 [==============================] - ETA: 0s - loss: 2.6701e-04 - root_mean_squared_error: 0.0163 - mean_absolute_error: 0.0027
# Epoch 6: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 2.6701e-04 - root_mean_squared_error: 0.0163 - mean_absolute_error: 0.0027 - val_loss: 1.9783e-04 - val_root_mean_squared_error: 0.0141 - val_mean_absolute_error: 0.0019
# Epoch 7/40
# 510/510 [==============================] - ETA: 0s - loss: 2.5806e-04 - root_mean_squared_error: 0.0161 - mean_absolute_error: 0.0024
# Epoch 7: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 2.5806e-04 - root_mean_squared_error: 0.0161 - mean_absolute_error: 0.0024 - val_loss: 3.2816e-04 - val_root_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.0021
# Epoch 8/40
# 510/510 [==============================] - ETA: 0s - loss: 2.4648e-04 - root_mean_squared_error: 0.0157 - mean_absolute_error: 0.0024
# Epoch 8: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 67s 132ms/step - loss: 2.4648e-04 - root_mean_squared_error: 0.0157 - mean_absolute_error: 0.0024 - val_loss: 1.8752e-04 - val_root_mean_squared_error: 0.0137 - val_mean_absolute_error: 0.0018
# Epoch 9/40
# 510/510 [==============================] - ETA: 0s - loss: 2.4395e-04 - root_mean_squared_error: 0.0156 - mean_absolute_error: 0.0025
# Epoch 9: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 2.4395e-04 - root_mean_squared_error: 0.0156 - mean_absolute_error: 0.0025 - val_loss: 2.0976e-04 - val_root_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0024
# Epoch 10/40
# 510/510 [==============================] - ETA: 0s - loss: 2.3863e-04 - root_mean_squared_error: 0.0154 - mean_absolute_error: 0.0021
# Epoch 10: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 2.3863e-04 - root_mean_squared_error: 0.0154 - mean_absolute_error: 0.0021 - val_loss: 1.9392e-04 - val_root_mean_squared_error: 0.0139 - val_mean_absolute_error: 0.0039
# Epoch 11/40
# 510/510 [==============================] - ETA: 0s - loss: 2.3538e-04 - root_mean_squared_error: 0.0153 - mean_absolute_error: 0.0024
# Epoch 11: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 2.3538e-04 - root_mean_squared_error: 0.0153 - mean_absolute_error: 0.0024 - val_loss: 2.0996e-04 - val_root_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0027
# Epoch 12/40
# 510/510 [==============================] - ETA: 0s - loss: 2.2864e-04 - root_mean_squared_error: 0.0151 - mean_absolute_error: 0.0021
# Epoch 12: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 67s 132ms/step - loss: 2.2864e-04 - root_mean_squared_error: 0.0151 - mean_absolute_error: 0.0021 - val_loss: 2.0669e-04 - val_root_mean_squared_error: 0.0144 - val_mean_absolute_error: 0.0019
# Epoch 13/40
# 510/510 [==============================] - ETA: 0s - loss: 2.1554e-04 - root_mean_squared_error: 0.0147 - mean_absolute_error: 0.0021
# Epoch 13: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 2.1554e-04 - root_mean_squared_error: 0.0147 - mean_absolute_error: 0.0021 - val_loss: 2.8623e-04 - val_root_mean_squared_error: 0.0169 - val_mean_absolute_error: 0.0025
# Epoch 14/40
# 510/510 [==============================] - ETA: 0s - loss: 2.2409e-04 - root_mean_squared_error: 0.0150 - mean_absolute_error: 0.0023
# Epoch 14: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 2.2409e-04 - root_mean_squared_error: 0.0150 - mean_absolute_error: 0.0023 - val_loss: 1.6710e-04 - val_root_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0027
# Epoch 15/40
# 510/510 [==============================] - ETA: 0s - loss: 2.0436e-04 - root_mean_squared_error: 0.0143 - mean_absolute_error: 0.0020
# Epoch 15: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 2.0436e-04 - root_mean_squared_error: 0.0143 - mean_absolute_error: 0.0020 - val_loss: 1.8483e-04 - val_root_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0015
# Epoch 16/40
# 510/510 [==============================] - ETA: 0s - loss: 2.1380e-04 - root_mean_squared_error: 0.0146 - mean_absolute_error: 0.0020
# Epoch 16: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 2.1380e-04 - root_mean_squared_error: 0.0146 - mean_absolute_error: 0.0020 - val_loss: 2.0404e-04 - val_root_mean_squared_error: 0.0143 - val_mean_absolute_error: 0.0029
# Epoch 17/40
# 510/510 [==============================] - ETA: 0s - loss: 1.8876e-04 - root_mean_squared_error: 0.0137 - mean_absolute_error: 0.0018
# Epoch 17: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.8876e-04 - root_mean_squared_error: 0.0137 - mean_absolute_error: 0.0018 - val_loss: 1.7663e-04 - val_root_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0011
# Epoch 18/40
# 510/510 [==============================] - ETA: 0s - loss: 1.9867e-04 - root_mean_squared_error: 0.0141 - mean_absolute_error: 0.0021
# Epoch 18: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.9867e-04 - root_mean_squared_error: 0.0141 - mean_absolute_error: 0.0021 - val_loss: 1.6484e-04 - val_root_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0013
# Epoch 19/40
# 510/510 [==============================] - ETA: 0s - loss: 1.7981e-04 - root_mean_squared_error: 0.0134 - mean_absolute_error: 0.0017
# Epoch 19: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 67s 132ms/step - loss: 1.7981e-04 - root_mean_squared_error: 0.0134 - mean_absolute_error: 0.0017 - val_loss: 1.7731e-04 - val_root_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0022
# Epoch 20/40
# 510/510 [==============================] - ETA: 0s - loss: 1.8708e-04 - root_mean_squared_error: 0.0137 - mean_absolute_error: 0.0018
# Epoch 20: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 1.8708e-04 - root_mean_squared_error: 0.0137 - mean_absolute_error: 0.0018 - val_loss: 2.2278e-04 - val_root_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0020
# Epoch 21/40
# 510/510 [==============================] - ETA: 0s - loss: 1.8114e-04 - root_mean_squared_error: 0.0135 - mean_absolute_error: 0.0017
# Epoch 21: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.8114e-04 - root_mean_squared_error: 0.0135 - mean_absolute_error: 0.0017 - val_loss: 1.8523e-04 - val_root_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0019
# Epoch 22/40
# 510/510 [==============================] - ETA: 0s - loss: 1.7243e-04 - root_mean_squared_error: 0.0131 - mean_absolute_error: 0.0017
# Epoch 22: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.7243e-04 - root_mean_squared_error: 0.0131 - mean_absolute_error: 0.0017 - val_loss: 2.2629e-04 - val_root_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0013
# Epoch 23/40
# 510/510 [==============================] - ETA: 0s - loss: 1.8027e-04 - root_mean_squared_error: 0.0134 - mean_absolute_error: 0.0017
# Epoch 23: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.8027e-04 - root_mean_squared_error: 0.0134 - mean_absolute_error: 0.0017 - val_loss: 1.6179e-04 - val_root_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0013
# Epoch 24/40
# 510/510 [==============================] - ETA: 0s - loss: 1.9385e-04 - root_mean_squared_error: 0.0139 - mean_absolute_error: 0.0017
# Epoch 24: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 67s 132ms/step - loss: 1.9385e-04 - root_mean_squared_error: 0.0139 - mean_absolute_error: 0.0017 - val_loss: 2.0346e-04 - val_root_mean_squared_error: 0.0143 - val_mean_absolute_error: 0.0018
# Epoch 25/40
# 510/510 [==============================] - ETA: 0s - loss: 1.7148e-04 - root_mean_squared_error: 0.0131 - mean_absolute_error: 0.0016
# Epoch 25: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 1.7148e-04 - root_mean_squared_error: 0.0131 - mean_absolute_error: 0.0016 - val_loss: 2.1695e-04 - val_root_mean_squared_error: 0.0147 - val_mean_absolute_error: 0.0013
# Epoch 26/40
# 510/510 [==============================] - ETA: 0s - loss: 1.7019e-04 - root_mean_squared_error: 0.0130 - mean_absolute_error: 0.0016
# Epoch 26: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.7019e-04 - root_mean_squared_error: 0.0130 - mean_absolute_error: 0.0016 - val_loss: 1.6017e-04 - val_root_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0015
# Epoch 27/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6643e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0017
# Epoch 27: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.6643e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0017 - val_loss: 1.7644e-04 - val_root_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0010
# Epoch 28/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6457e-04 - root_mean_squared_error: 0.0128 - mean_absolute_error: 0.0015
# Epoch 28: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 67s 132ms/step - loss: 1.6457e-04 - root_mean_squared_error: 0.0128 - mean_absolute_error: 0.0015 - val_loss: 1.6767e-04 - val_root_mean_squared_error: 0.0129 - val_mean_absolute_error: 0.0023
# Epoch 29/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6329e-04 - root_mean_squared_error: 0.0128 - mean_absolute_error: 0.0016
# Epoch 29: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 1.6329e-04 - root_mean_squared_error: 0.0128 - mean_absolute_error: 0.0016 - val_loss: 1.7585e-04 - val_root_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0016
# Epoch 30/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6536e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0016
# Epoch 30: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.6536e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0016 - val_loss: 1.7341e-04 - val_root_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0022
# Epoch 31/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6140e-04 - root_mean_squared_error: 0.0127 - mean_absolute_error: 0.0015
# Epoch 31: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 67s 132ms/step - loss: 1.6140e-04 - root_mean_squared_error: 0.0127 - mean_absolute_error: 0.0015 - val_loss: 1.7210e-04 - val_root_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0011
# Epoch 32/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6626e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0016
# Epoch 32: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 1.6626e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0016 - val_loss: 1.8520e-04 - val_root_mean_squared_error: 0.0136 - val_mean_absolute_error: 0.0012
# Epoch 33/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6357e-04 - root_mean_squared_error: 0.0128 - mean_absolute_error: 0.0015
# Epoch 33: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.6357e-04 - root_mean_squared_error: 0.0128 - mean_absolute_error: 0.0015 - val_loss: 1.7625e-04 - val_root_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0012
# Epoch 34/40
# 510/510 [==============================] - ETA: 0s - loss: 1.5538e-04 - root_mean_squared_error: 0.0125 - mean_absolute_error: 0.0014
# Epoch 34: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 67s 132ms/step - loss: 1.5538e-04 - root_mean_squared_error: 0.0125 - mean_absolute_error: 0.0014 - val_loss: 1.6457e-04 - val_root_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0014
# Epoch 35/40
# 510/510 [==============================] - ETA: 0s - loss: 1.6589e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0015
# Epoch 35: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 111ms/step - loss: 1.6589e-04 - root_mean_squared_error: 0.0129 - mean_absolute_error: 0.0015 - val_loss: 1.6371e-04 - val_root_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0012
# Epoch 36/40
# 510/510 [==============================] - ETA: 0s - loss: 1.5519e-04 - root_mean_squared_error: 0.0125 - mean_absolute_error: 0.0014
# Epoch 36: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.5519e-04 - root_mean_squared_error: 0.0125 - mean_absolute_error: 0.0014 - val_loss: 2.1329e-04 - val_root_mean_squared_error: 0.0146 - val_mean_absolute_error: 0.0013
# Epoch 37/40
# 510/510 [==============================] - ETA: 0s - loss: 1.5350e-04 - root_mean_squared_error: 0.0124 - mean_absolute_error: 0.0015
# Epoch 37: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.5350e-04 - root_mean_squared_error: 0.0124 - mean_absolute_error: 0.0015 - val_loss: 1.6323e-04 - val_root_mean_squared_error: 0.0128 - val_mean_absolute_error: 9.2524e-04
# Epoch 38/40
# 510/510 [==============================] - ETA: 0s - loss: 1.5260e-04 - root_mean_squared_error: 0.0124 - mean_absolute_error: 0.0014
# Epoch 38: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.5260e-04 - root_mean_squared_error: 0.0124 - mean_absolute_error: 0.0014 - val_loss: 2.0974e-04 - val_root_mean_squared_error: 0.0145 - val_mean_absolute_error: 0.0017
# Epoch 39/40
# 510/510 [==============================] - ETA: 0s - loss: 1.5117e-04 - root_mean_squared_error: 0.0123 - mean_absolute_error: 0.0014
# Epoch 39: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 112ms/step - loss: 1.5117e-04 - root_mean_squared_error: 0.0123 - mean_absolute_error: 0.0014 - val_loss: 1.8253e-04 - val_root_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0017
# Epoch 40/40
# 510/510 [==============================] - ETA: 0s - loss: 1.4469e-04 - root_mean_squared_error: 0.0120 - mean_absolute_error: 0.0013
# Epoch 40: saving model to lstm_training_ft_kettle/cp.ckpt
# 510/510 [==============================] - 57s 113ms/step - loss: 1.4469e-04 - root_mean_squared_error: 0.0120 - mean_absolute_error: 0.0013 - val_loss: 1.7857e-04 - val_root_mean_squared_error: 0.0134 - val_mean_absolute_error: 0.0014

# %%
if not SKIP_TRAINING:
    print('Time spent', time_spent)
    plot_model_history(history)
# Out:
# Time spent 2356.875537053999
# dict_keys(['loss', 'root_mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error'])

# %%
# Predict from test split
y_test, y_pred = predict(model, feature=FEATURE, df_test=df_test, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH)
# Out:
# x_test.shape, y_test.shape
# (190700, 1) (190700, 1)
# self.data_len 190700
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 187
# x.shape, y.shape (191488, 32, 1) (191488,)
# batch_index 0
# 187/187 [==============================] - 8s 33ms/step
# y_test.shape, y_pred.shape
# (191488,) (191488, 1)
# y_test.shape, y_pred.shape
# (191488,) (191488,)
# Normalized: y_test.mean, y_pred.mean
# 0.002148089 0.0018291869
# Denormalized: y_test.mean, y_pred.mean
# 12.894805 13.3461075

# %%
# plot_prediction_windows(FEATURE, y_test_denorm, y_pred_denorm)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=False, n_samples=n_samples)

# %%
n_samples = 80
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, active_factor=4, n_samples=n_samples)

# %%
n_samples = 200
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, n_samples=n_samples)

# %%
from lib import analysis
from lib.logging import losses_to_file, metrics_to_file

# %%
params = {}
params["algo"] = 'lstm'
params["feature"] = FEATURE
params["seq_len"] = SEQ_LEN
params["seq_per_batch"] = SEQ_PER_BATCH
params["strides"] = N_STRIDES
params["epochs"] = EPOCHS
params["train_rows"] = df_train.shape[0]
params["val_rows"] = df_val.shape[0]
params["test_rows"] = df_test.shape[0]
params["norm_value"] = ref_norm
params["norm_type"] = NORM_TYPE
params["learning_rate"] = LEARNING_RATE
params["loss"] = 'adam'
params["clipvalue"] = CLIP_VALUE

# %%
print(params)
# Out:
# {'algo': 'lstm', 'feature': 'ft_kettle', 'seq_len': 32, 'seq_per_batch': 1024, 'strides': 1, 'epochs': 40, 'train_rows': 521300, 'val_rows': 316800, 'test_rows': 190700, 'norm_value': 6002.92, 'norm_type': 'max', 'learning_rate': 0.001, 'loss': 'adam', 'clipvalue': 10.0}

# %%
results = analysis.classification_results(y_test, y_pred, on_threshold = 100)

metrics = {}
metrics["mae"] = analysis.mse_loss(y_test, y_pred)
metrics["mse"] = analysis.mae_loss(y_test, y_pred)
metrics["f1"] = analysis.f1(results)
metrics["accuracy"] = analysis.accuracy(results)
metrics["precision"] = analysis.precision(results)
metrics["recall"] = analysis.recall(results)

# %%
print(metrics)
# Out:
# {'mae': 4315.481979376532, 'mse': 4.740629258080333, 'f1': 0.740949316170555, 'accuracy': 0.996636864973262, 'precision': 0.6119601328903654, 'recall': 0.9388379204892966}

# %%
if not SKIP_TRAINING:
    losses_to_file(1, params, history.history)

# %%
metrics_to_file(1, params, metrics)
