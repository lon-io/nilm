# %%
# Constants
MAX_NO_ROWS = 1000000
LOAD_MODEL=False
SKIP_TRAINING=False
FEATURE = 'ft_fridge'
SEQ_PER_BATCH = 1024
SEQ_LEN = 32
N_STRIDES = 1
NORM_TYPE = 'max'
LEARNING_RATE = 1e-2
CLIP_VALUE = 10.
EPOCHS = 100
CHECKPOINT_PATH = f"gru_training_{FEATURE}/cp.ckpt"

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Dissertation
# Out:
# /content/drive/My Drive/Colab Notebooks/Dissertation

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.21.6)

# %%
from lib.chunk_reader import read_labels, get_merged_chunks, get_dates
from lib.plotting import plot_ft_days, plot_model_history, plot_prediction_windows
from lib.analysis import print_heads_tails

# %%
labels = read_labels(1)
for house in range(1,2):
    print('House {}: '.format(house), labels[house], '\n')
# Out:
# House 1:  ['mains_active', 'mains_apparent', 'mains_rms', 'aggregate_apparent', 'ft_boiler', 'ft_solar_thermal_pump', 'ft_washing_machine', 'ft_dishwasher', 'ft_tv', 'ft_kitchen_lights', 'ft_htpc', 'ft_kettle', 'ft_toaster', 'ft_fridge', 'ft_microwave', 'ft_amp_livingroom', 'ft_adsl_router', 'ft_livingroom_s_lamp', 'ft_lighting_circuit', 'ft_subwoofer_livingroom', 'ft_livingroom_lamp_tv', 'ft_kitchen_phone&stereo', 'ft_coffee_machine', 'ft_gas_oven', 'ft_data_logger_pc', 'ft_office_lamp2', 'aggregate_active', 'unix_time']

# %%
ref_chunk_df = get_merged_chunks(1, 1)
print('Original DF shape', ref_chunk_df.shape)
print('---')
ref_chunk_df = ref_chunk_df[0:MAX_NO_ROWS]
# Out:
# reading house 1; chunk 1
# reading file data/ukdale-parsed-chunks/house_1/chunk_1.dat; for house 1 and chunk 1
# read house 1; chunk 1; df.shape is (4500000, 29)
# Original DF shape (4500000, 29)
# ---

# %%
dates = {}
# for house in range(1,2):
dates[1] = get_dates(ref_chunk_df, 1)
# Out:
# House 1 data contain 71 days from 2013-04-11 to 2013-06-20.
# ['2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05-13', '2013-05-14', '2013-05-15', '2013-05-16', '2013-05-17', '2013-05-18', '2013-05-19', '2013-05-20', '2013-05-21', '2013-05-22', '2013-05-23', '2013-05-24', '2013-05-25', '2013-05-26', '2013-05-27', '2013-05-28', '2013-05-29', '2013-05-30', '2013-05-31', '2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04', '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08', '2013-06-09', '2013-06-10', '2013-06-11', '2013-06-12', '2013-06-13', '2013-06-14', '2013-06-15', '2013-06-16', '2013-06-17', '2013-06-18', '2013-06-19', '2013-06-20']

# %%
# Constants 2
rows_per_day = ref_chunk_df.loc[:dates[1][2]].shape[0]

# %%
plot_ft_days(ref_chunk_df, dates, 1, FEATURE, 2)
# Out:
# (31700,)
# (15850, 2)

# %%
from algos.processing import split_df_by_dates
from algos.lstm import train, predict
from algos.gru import create_model
from algos.norm import get_ref_norm

# %%
# Separate house 1 data into train, validation and test data
df_train, df_val, df_test  =  split_df_by_dates(ref_chunk_df, dates=dates, house=1)
# Out:
# df_train.shape:  (521300, 29)
# df_val.shape:  (316800, 29)
# df_test.shape:  (190700, 29)

# %%
ref_norm = get_ref_norm(df_train, NORM_TYPE)
# Out:
# ref_mean: 325.09124755859375; ref_max: 6002.919921875; ref_std: 434.2580871582031
# norm_type: max; ref_norm 6002.919921875

# %%
model = create_model(seq_len=SEQ_LEN, learning_rate=LEARNING_RATE, clipvalue=CLIP_VALUE)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 32, 16)            80
#
#  conv1d_1 (Conv1D)           (None, 32, 8)             520
#
#  bidirectional (Bidirectiona  (None, 32, 128)          28416
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 256)              198144
#  nal)
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 243,673
# Trainable params: 243,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !!!!!!!Counter!!!!!!! 
# Manually update for every new loaded training
# Run Counter = 0

# Load and or Train
if LOAD_MODEL:
  model.load_weights(CHECKPOINT_PATH)
if SKIP_TRAINING:
  pass
else:
  model, history, time_spent = train(model, feature=FEATURE, df_train=df_train, df_val=df_val, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH, epochs=EPOCHS, checkpoint_path=CHECKPOINT_PATH)
# Out:
# x_train.shape, y_train.shape, x_val.shape, x_val.shape
# (521300, 1) (521300, 1) (316800, 1) (316800, 1)
# self.data_len 521300
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 510
# x.shape, y.shape (522240, 32, 1) (522240,)
# batch_index 0
# batch_index 200
# batch_index 400
# self.data_len 316800
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 310
# x.shape, y.shape (317440, 32, 1) (317440,)
# batch_index 0
# batch_index 200
# Epoch 1/100
#   5/510 [..............................] - ETA: 27s - loss: 0.0012 - root_mean_squared_error: 0.0347 - mean_absolute_error: 0.0223
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0174s vs `on_train_batch_end` time: 0.0289s). Check your callbacks.
# 509/510 [============================>.] - ETA: 0s - loss: 9.2129e-05 - root_mean_squared_error: 0.0096 - mean_absolute_error: 0.0076
# Epoch 1: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 38s 40ms/step - loss: 9.2075e-05 - root_mean_squared_error: 0.0096 - mean_absolute_error: 0.0076 - val_loss: 7.1036e-05 - val_root_mean_squared_error: 0.0084 - val_mean_absolute_error: 0.0069
# Epoch 2/100
# 509/510 [============================>.] - ETA: 0s - loss: 7.2656e-05 - root_mean_squared_error: 0.0085 - mean_absolute_error: 0.0072
# Epoch 2: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 19s 37ms/step - loss: 7.2630e-05 - root_mean_squared_error: 0.0085 - mean_absolute_error: 0.0072 - val_loss: 7.0918e-05 - val_root_mean_squared_error: 0.0084 - val_mean_absolute_error: 0.0067
# Epoch 3/100
# 509/510 [============================>.] - ETA: 0s - loss: 6.9508e-05 - root_mean_squared_error: 0.0083 - mean_absolute_error: 0.0068
# Epoch 3: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 19s 38ms/step - loss: 6.9499e-05 - root_mean_squared_error: 0.0083 - mean_absolute_error: 0.0068 - val_loss: 6.4302e-05 - val_root_mean_squared_error: 0.0080 - val_mean_absolute_error: 0.0062
# Epoch 4/100
# 509/510 [============================>.] - ETA: 0s - loss: 6.5405e-05 - root_mean_squared_error: 0.0081 - mean_absolute_error: 0.0063
# Epoch 4: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 41ms/step - loss: 6.5376e-05 - root_mean_squared_error: 0.0081 - mean_absolute_error: 0.0063 - val_loss: 5.6443e-05 - val_root_mean_squared_error: 0.0075 - val_mean_absolute_error: 0.0053
# Epoch 5/100
# 510/510 [==============================] - ETA: 0s - loss: 6.1884e-05 - root_mean_squared_error: 0.0079 - mean_absolute_error: 0.0060
# Epoch 5: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 42ms/step - loss: 6.1884e-05 - root_mean_squared_error: 0.0079 - mean_absolute_error: 0.0060 - val_loss: 5.6007e-05 - val_root_mean_squared_error: 0.0075 - val_mean_absolute_error: 0.0054
# Epoch 6/100
# 510/510 [==============================] - ETA: 0s - loss: 6.1062e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059
# Epoch 6: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 39ms/step - loss: 6.1062e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059 - val_loss: 5.8010e-05 - val_root_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0056
# Epoch 7/100
# 509/510 [============================>.] - ETA: 0s - loss: 6.0691e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059
# Epoch 7: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 39ms/step - loss: 6.0670e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059 - val_loss: 5.8028e-05 - val_root_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0055
# Epoch 8/100
# 509/510 [============================>.] - ETA: 0s - loss: 6.0109e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059
# Epoch 8: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 39ms/step - loss: 6.0094e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059 - val_loss: 5.4233e-05 - val_root_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0052
# Epoch 9/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.9920e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0059
# Epoch 9: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 42ms/step - loss: 5.9942e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0059 - val_loss: 5.4581e-05 - val_root_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0052
# Epoch 10/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.9681e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058
# Epoch 10: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.9671e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058 - val_loss: 5.6862e-05 - val_root_mean_squared_error: 0.0075 - val_mean_absolute_error: 0.0056
# Epoch 11/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.9429e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058
# Epoch 11: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.9560e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058 - val_loss: 5.3316e-05 - val_root_mean_squared_error: 0.0073 - val_mean_absolute_error: 0.0051
# Epoch 12/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.9354e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058
# Epoch 12: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 39ms/step - loss: 5.9334e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058 - val_loss: 5.4187e-05 - val_root_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0053
# Epoch 13/100
# 509/510 [============================>.] - ETA: 0s - loss: 7.5317e-05 - root_mean_squared_error: 0.0087 - mean_absolute_error: 0.0062
# Epoch 13: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 39ms/step - loss: 7.5314e-05 - root_mean_squared_error: 0.0087 - mean_absolute_error: 0.0062 - val_loss: 7.7722e-05 - val_root_mean_squared_error: 0.0088 - val_mean_absolute_error: 0.0077
# Epoch 14/100
# 509/510 [============================>.] - ETA: 0s - loss: 7.1222e-05 - root_mean_squared_error: 0.0084 - mean_absolute_error: 0.0071
# Epoch 14: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 7.1178e-05 - root_mean_squared_error: 0.0084 - mean_absolute_error: 0.0071 - val_loss: 5.9633e-05 - val_root_mean_squared_error: 0.0077 - val_mean_absolute_error: 0.0058
# Epoch 15/100
# 509/510 [============================>.] - ETA: 0s - loss: 6.1990e-05 - root_mean_squared_error: 0.0079 - mean_absolute_error: 0.0059
# Epoch 15: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 6.1957e-05 - root_mean_squared_error: 0.0079 - mean_absolute_error: 0.0059 - val_loss: 5.6934e-05 - val_root_mean_squared_error: 0.0075 - val_mean_absolute_error: 0.0051
# Epoch 16/100
# 510/510 [==============================] - ETA: 0s - loss: 6.0320e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0057
# Epoch 16: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 6.0320e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0057 - val_loss: 5.8128e-05 - val_root_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0055
# Epoch 17/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.9014e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0057
# Epoch 17: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 5.8988e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0057 - val_loss: 5.3285e-05 - val_root_mean_squared_error: 0.0073 - val_mean_absolute_error: 0.0051
# Epoch 18/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.8404e-05 - root_mean_squared_error: 0.0076 - mean_absolute_error: 0.0057
# Epoch 18: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.8397e-05 - root_mean_squared_error: 0.0076 - mean_absolute_error: 0.0057 - val_loss: 5.2141e-05 - val_root_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0050
# Epoch 19/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.6281e-05 - root_mean_squared_error: 0.0075 - mean_absolute_error: 0.0054
# Epoch 19: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 5.6261e-05 - root_mean_squared_error: 0.0075 - mean_absolute_error: 0.0054 - val_loss: 5.1146e-05 - val_root_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0044
# Epoch 20/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.3403e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0049
# Epoch 20: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.3390e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0049 - val_loss: 5.3746e-05 - val_root_mean_squared_error: 0.0073 - val_mean_absolute_error: 0.0044
# Epoch 21/100
# 510/510 [==============================] - ETA: 0s - loss: 5.2492e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0048
# Epoch 21: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 5.2492e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0048 - val_loss: 4.8064e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0042
# Epoch 22/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.2105e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047
# Epoch 22: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.2083e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047 - val_loss: 4.9155e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0040
# Epoch 23/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.1533e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047
# Epoch 23: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.1503e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047 - val_loss: 4.7226e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0039
# Epoch 24/100
# 509/510 [============================>.] - ETA: 0s - loss: 5.0747e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0046
# Epoch 24: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.0728e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0046 - val_loss: 5.2511e-05 - val_root_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0041
# Epoch 25/100
# 510/510 [==============================] - ETA: 0s - loss: 5.0156e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0045
# Epoch 25: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 5.0156e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0045 - val_loss: 4.6533e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0040
# Epoch 26/100
# 510/510 [==============================] - ETA: 0s - loss: 4.9476e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044
# Epoch 26: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.9476e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044 - val_loss: 4.9935e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0040
# Epoch 27/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.9055e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044
# Epoch 27: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.9045e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044 - val_loss: 5.0732e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0041
# Epoch 28/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8875e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043
# Epoch 28: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 4.8851e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043 - val_loss: 5.0745e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0042
# Epoch 29/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8526e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043
# Epoch 29: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.8520e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043 - val_loss: 4.9632e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0042
# Epoch 30/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8250e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0043
# Epoch 30: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.8232e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0043 - val_loss: 4.5989e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0039
# Epoch 31/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8185e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042
# Epoch 31: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.8155e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042 - val_loss: 4.9478e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0043
# Epoch 32/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8041e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042
# Epoch 32: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.8018e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042 - val_loss: 5.0682e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0038
# Epoch 33/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.7892e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042
# Epoch 33: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.7872e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042 - val_loss: 4.8651e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0039
# Epoch 34/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.7672e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042
# Epoch 34: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.7654e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042 - val_loss: 4.9490e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0039
# Epoch 35/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8781e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043
# Epoch 35: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.8760e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043 - val_loss: 4.7893e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0039
# Epoch 36/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8947e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043
# Epoch 36: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.8932e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0043 - val_loss: 5.1765e-05 - val_root_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0046
# Epoch 37/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.8130e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0043
# Epoch 37: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.8122e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0043 - val_loss: 4.6265e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0038
# Epoch 38/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.7675e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042
# Epoch 38: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 4.7659e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0042 - val_loss: 4.6606e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0037
# Epoch 39/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.7289e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0041
# Epoch 39: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 4.7277e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0041 - val_loss: 4.8023e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0040
# Epoch 40/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.7013e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0041
# Epoch 40: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.6996e-05 - root_mean_squared_error: 0.0069 - mean_absolute_error: 0.0041 - val_loss: 4.7442e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0036
# Epoch 41/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.6728e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0041
# Epoch 41: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.6712e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0041 - val_loss: 4.6610e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0038
# Epoch 42/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.6411e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0041
# Epoch 42: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.6455e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0041 - val_loss: 4.9701e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0039
# Epoch 43/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.6173e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0041
# Epoch 43: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.6214e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0041 - val_loss: 4.7996e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0037
# Epoch 44/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.6105e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0040
# Epoch 44: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.6080e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0040 - val_loss: 5.0515e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0040
# Epoch 45/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.5903e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0040
# Epoch 45: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.5883e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0040 - val_loss: 4.6368e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0037
# Epoch 46/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.5580e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0040
# Epoch 46: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.5574e-05 - root_mean_squared_error: 0.0068 - mean_absolute_error: 0.0040 - val_loss: 4.8137e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0037
# Epoch 47/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.5364e-05 - root_mean_squared_error: 0.0067 - mean_absolute_error: 0.0040
# Epoch 47: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.5349e-05 - root_mean_squared_error: 0.0067 - mean_absolute_error: 0.0040 - val_loss: 4.5228e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0035
# Epoch 48/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.5247e-05 - root_mean_squared_error: 0.0067 - mean_absolute_error: 0.0039
# Epoch 48: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.5220e-05 - root_mean_squared_error: 0.0067 - mean_absolute_error: 0.0039 - val_loss: 4.3983e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0035
# Epoch 49/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.4254e-05 - root_mean_squared_error: 0.0067 - mean_absolute_error: 0.0039
# Epoch 49: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.4235e-05 - root_mean_squared_error: 0.0067 - mean_absolute_error: 0.0039 - val_loss: 4.3741e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0034
# Epoch 50/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.3292e-05 - root_mean_squared_error: 0.0066 - mean_absolute_error: 0.0038
# Epoch 50: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 4.3286e-05 - root_mean_squared_error: 0.0066 - mean_absolute_error: 0.0038 - val_loss: 4.4276e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0037
# Epoch 51/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.2877e-05 - root_mean_squared_error: 0.0065 - mean_absolute_error: 0.0038
# Epoch 51: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 4.2863e-05 - root_mean_squared_error: 0.0065 - mean_absolute_error: 0.0038 - val_loss: 4.8688e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0037
# Epoch 52/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.2188e-05 - root_mean_squared_error: 0.0065 - mean_absolute_error: 0.0037
# Epoch 52: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.2176e-05 - root_mean_squared_error: 0.0065 - mean_absolute_error: 0.0037 - val_loss: 4.4172e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0035
# Epoch 53/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.1592e-05 - root_mean_squared_error: 0.0064 - mean_absolute_error: 0.0037
# Epoch 53: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.1562e-05 - root_mean_squared_error: 0.0064 - mean_absolute_error: 0.0037 - val_loss: 4.2813e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0035
# Epoch 54/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.1035e-05 - root_mean_squared_error: 0.0064 - mean_absolute_error: 0.0036
# Epoch 54: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 4.1148e-05 - root_mean_squared_error: 0.0064 - mean_absolute_error: 0.0036 - val_loss: 4.2012e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0032
# Epoch 55/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.0585e-05 - root_mean_squared_error: 0.0064 - mean_absolute_error: 0.0036
# Epoch 55: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 4.0562e-05 - root_mean_squared_error: 0.0064 - mean_absolute_error: 0.0036 - val_loss: 4.3077e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0034
# Epoch 56/100
# 509/510 [============================>.] - ETA: 0s - loss: 4.0157e-05 - root_mean_squared_error: 0.0063 - mean_absolute_error: 0.0035
# Epoch 56: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 4.0138e-05 - root_mean_squared_error: 0.0063 - mean_absolute_error: 0.0035 - val_loss: 4.5596e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0036
# Epoch 57/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.9567e-05 - root_mean_squared_error: 0.0063 - mean_absolute_error: 0.0035
# Epoch 57: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.9568e-05 - root_mean_squared_error: 0.0063 - mean_absolute_error: 0.0035 - val_loss: 4.4575e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0035
# Epoch 58/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.9257e-05 - root_mean_squared_error: 0.0063 - mean_absolute_error: 0.0034
# Epoch 58: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.9241e-05 - root_mean_squared_error: 0.0063 - mean_absolute_error: 0.0034 - val_loss: 4.1599e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0032
# Epoch 59/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.8674e-05 - root_mean_squared_error: 0.0062 - mean_absolute_error: 0.0034
# Epoch 59: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.8665e-05 - root_mean_squared_error: 0.0062 - mean_absolute_error: 0.0034 - val_loss: 3.8813e-05 - val_root_mean_squared_error: 0.0062 - val_mean_absolute_error: 0.0032
# Epoch 60/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.8203e-05 - root_mean_squared_error: 0.0062 - mean_absolute_error: 0.0034
# Epoch 60: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.8197e-05 - root_mean_squared_error: 0.0062 - mean_absolute_error: 0.0034 - val_loss: 4.2054e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0032
# Epoch 61/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.8080e-05 - root_mean_squared_error: 0.0062 - mean_absolute_error: 0.0033
# Epoch 61: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.8120e-05 - root_mean_squared_error: 0.0062 - mean_absolute_error: 0.0033 - val_loss: 4.3635e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0034
# Epoch 62/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.7616e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033
# Epoch 62: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.7699e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033 - val_loss: 4.3608e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 63/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.7353e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033
# Epoch 63: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.7344e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033 - val_loss: 4.3248e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0035
# Epoch 64/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.6904e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0032
# Epoch 64: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.6901e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0032 - val_loss: 4.2098e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0032
# Epoch 65/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.6879e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0032
# Epoch 65: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.6866e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0032 - val_loss: 4.0355e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0033
# Epoch 66/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.6528e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032
# Epoch 66: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.6552e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032 - val_loss: 4.5849e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0037
# Epoch 67/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.6005e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031
# Epoch 67: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.6138e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031 - val_loss: 4.0333e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0032
# Epoch 68/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.5991e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031
# Epoch 68: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.5985e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031 - val_loss: 4.1637e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0033
# Epoch 69/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.5767e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031
# Epoch 69: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.5749e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031 - val_loss: 4.1600e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0032
# Epoch 70/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.5466e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031
# Epoch 70: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.5451e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0031 - val_loss: 3.9542e-05 - val_root_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0029
# Epoch 71/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.5223e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031
# Epoch 71: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.5210e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031 - val_loss: 4.2395e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0033
# Epoch 72/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.5076e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031
# Epoch 72: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.5060e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031 - val_loss: 4.0820e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 73/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.4785e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0030
# Epoch 73: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.4773e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0030 - val_loss: 4.3011e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 74/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.4582e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0030
# Epoch 74: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 3.4568e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0030 - val_loss: 3.7765e-05 - val_root_mean_squared_error: 0.0061 - val_mean_absolute_error: 0.0028
# Epoch 75/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.4220e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030
# Epoch 75: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.4202e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030 - val_loss: 3.7833e-05 - val_root_mean_squared_error: 0.0062 - val_mean_absolute_error: 0.0028
# Epoch 76/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.4064e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030
# Epoch 76: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 3.4051e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030 - val_loss: 4.3157e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 77/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.3843e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030
# Epoch 77: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.3825e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030 - val_loss: 4.3196e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 78/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.3628e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0029
# Epoch 78: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.3607e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0029 - val_loss: 4.1572e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 79/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.3199e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0029
# Epoch 79: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.3178e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0029 - val_loss: 3.8131e-05 - val_root_mean_squared_error: 0.0062 - val_mean_absolute_error: 0.0030
# Epoch 80/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.3101e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0029
# Epoch 80: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.3081e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0029 - val_loss: 4.0577e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 81/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.2935e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0029
# Epoch 81: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 3.2919e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0029 - val_loss: 4.2835e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0032
# Epoch 82/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.2838e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0029
# Epoch 82: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.2818e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0029 - val_loss: 4.0069e-05 - val_root_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0031
# Epoch 83/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.2401e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0029
# Epoch 83: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.2388e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0029 - val_loss: 4.1628e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0032
# Epoch 84/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.2320e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0028
# Epoch 84: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 20s 40ms/step - loss: 3.2299e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0028 - val_loss: 4.3018e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 85/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.2033e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0028
# Epoch 85: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 3.2007e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0028 - val_loss: 4.2523e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0030
# Epoch 86/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.1683e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0028
# Epoch 86: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 3.1666e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0028 - val_loss: 4.1366e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 87/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.1436e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0028
# Epoch 87: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 44ms/step - loss: 3.1418e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0028 - val_loss: 4.1162e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 88/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.1246e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0027
# Epoch 88: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.1223e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0027 - val_loss: 4.0001e-05 - val_root_mean_squared_error: 0.0063 - val_mean_absolute_error: 0.0029
# Epoch 89/100
# 510/510 [==============================] - ETA: 0s - loss: 3.1082e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0027
# Epoch 89: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.1082e-05 - root_mean_squared_error: 0.0056 - mean_absolute_error: 0.0027 - val_loss: 4.2912e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0034
# Epoch 90/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.0544e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0027
# Epoch 90: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 44ms/step - loss: 3.0524e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0027 - val_loss: 4.1038e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 91/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.0512e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0027
# Epoch 91: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 3.0496e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0027 - val_loss: 4.1018e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 92/100
# 509/510 [============================>.] - ETA: 0s - loss: 3.0262e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0027
# Epoch 92: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 3.0243e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0027 - val_loss: 4.0435e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0029
# Epoch 93/100
# 509/510 [============================>.] - ETA: 0s - loss: 2.9815e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0026
# Epoch 93: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 2.9800e-05 - root_mean_squared_error: 0.0055 - mean_absolute_error: 0.0026 - val_loss: 4.2316e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0030
# Epoch 94/100
# 509/510 [============================>.] - ETA: 0s - loss: 2.9664e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026
# Epoch 94: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 44ms/step - loss: 2.9647e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026 - val_loss: 4.3176e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 95/100
# 510/510 [==============================] - ETA: 0s - loss: 2.9394e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026
# Epoch 95: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 44ms/step - loss: 2.9394e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026 - val_loss: 4.1093e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0032
# Epoch 96/100
# 509/510 [============================>.] - ETA: 0s - loss: 2.9038e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026
# Epoch 96: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 44ms/step - loss: 2.9014e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026 - val_loss: 4.1466e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0029
# Epoch 97/100
# 509/510 [============================>.] - ETA: 0s - loss: 2.8845e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026
# Epoch 97: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 22s 43ms/step - loss: 2.8825e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026 - val_loss: 4.1060e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0028
# Epoch 98/100
# 509/510 [============================>.] - ETA: 0s - loss: 2.8738e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026
# Epoch 98: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 2.8722e-05 - root_mean_squared_error: 0.0054 - mean_absolute_error: 0.0026 - val_loss: 4.3891e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0031
# Epoch 99/100
# 509/510 [============================>.] - ETA: 0s - loss: 2.8396e-05 - root_mean_squared_error: 0.0053 - mean_absolute_error: 0.0025
# Epoch 99: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 2.8380e-05 - root_mean_squared_error: 0.0053 - mean_absolute_error: 0.0025 - val_loss: 4.0847e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0032
# Epoch 100/100
# 509/510 [============================>.] - ETA: 0s - loss: 2.7948e-05 - root_mean_squared_error: 0.0053 - mean_absolute_error: 0.0025
# Epoch 100: saving model to gru_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 21s 40ms/step - loss: 2.7929e-05 - root_mean_squared_error: 0.0053 - mean_absolute_error: 0.0025 - val_loss: 4.7203e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0033

# %%
if not SKIP_TRAINING:
    print('Time spent', time_spent)
    plot_model_history(history)
# Out:
# Time spent 2121.7471064740016
# dict_keys(['loss', 'root_mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error'])

# %%
# Predict from test split
y_test, y_pred = predict(model, feature=FEATURE, df_test=df_test, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH)
# Out:
# x_test.shape, y_test.shape
# (190700, 1) (190700, 1)
# self.data_len 190700
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 187
# x.shape, y.shape (191488, 32, 1) (191488,)
# batch_index 0
# 187/187 [==============================] - 3s 11ms/step
# y_test.shape, y_pred.shape
# (191488,) (191488, 1)
# y_test.shape, y_pred.shape
# (191488,) (191488,)
# Normalized: y_test.mean, y_pred.mean
# 0.006400404 0.005588537
# Denormalized: y_test.mean, y_pred.mean
# 38.421112 34.52783

# %%
# plot_prediction_windows(FEATURE, y_test_denorm, y_pred_denorm)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=False, n_samples=n_samples)

# %%
n_samples = 80
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, active_factor=4, n_samples=n_samples)

# %%
n_samples = 200
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, n_samples=n_samples)

# %%
from lib import analysis
from lib.logging import losses_to_file, metrics_to_file

# %%
params = {}
params["algo"] = 'gru'
params["feature"] = FEATURE
params["seq_len"] = SEQ_LEN
params["seq_per_batch"] = SEQ_PER_BATCH
params["strides"] = N_STRIDES
params["epochs"] = EPOCHS
params["train_rows"] = df_train.shape[0]
params["val_rows"] = df_val.shape[0]
params["test_rows"] = df_test.shape[0]
params["norm_value"] = ref_norm
params["norm_type"] = NORM_TYPE
params["learning_rate"] = LEARNING_RATE
params["loss"] = 'adam'
params["clipvalue"] = CLIP_VALUE

# %%
print(params)
# Out:
# {'algo': 'gru', 'feature': 'ft_fridge', 'seq_len': 32, 'seq_per_batch': 1024, 'strides': 1, 'epochs': 100, 'train_rows': 521300, 'val_rows': 316800, 'test_rows': 190700, 'norm_value': 6002.92, 'norm_type': 'max', 'learning_rate': 0.01, 'loss': 'adam', 'clipvalue': 10.0}

# %%
results = analysis.classification_results(y_test, y_pred, on_threshold = 10)

metrics = {}
metrics["mae"] = analysis.mse_loss(y_test, y_pred)
metrics["mse"] = analysis.mae_loss(y_test, y_pred)
metrics["f1"] = analysis.f1(results)
metrics["accuracy"] = analysis.accuracy(results)
metrics["precision"] = analysis.precision(results)
metrics["recall"] = analysis.recall(results)

# %%
print(metrics)
# Out:
# {'mae': 1703.131049398001, 'mse': 18.799209212218244, 'f1': 0.8347849312523226, 'accuracy': 0.8514058322192514, 'precision': 0.7672480040985357, 'recall': 0.9153593439616972}

# %%
if not SKIP_TRAINING:
    losses_to_file(1, params, history.history)

# %%
metrics_to_file(1, params, metrics)
