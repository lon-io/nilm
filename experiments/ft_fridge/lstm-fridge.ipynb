# %%
# Constants
MAX_NO_ROWS = 1000000
LOAD_MODEL=False
SKIP_TRAINING=False
FEATURE = 'ft_fridge'
SEQ_PER_BATCH = 1024
SEQ_LEN = 32
N_STRIDES = 1
NORM_TYPE = 'max'
LEARNING_RATE = 1e-2
CLIP_VALUE = 10.
EPOCHS = 100
CHECKPOINT_PATH = f"lstm_training_{FEATURE}/cp.ckpt"

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
from tensorflow import keras

# %matplotlib inline
print(tf.version.VERSION)
# Out:
# 2.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Dissertation
# Out:
# /content/drive/My Drive/Colab Notebooks/Dissertation

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (6.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.8/dist-packages (from h5py) (1.21.6)

# %%
from lib.chunk_reader import read_labels, get_merged_chunks, get_dates
from lib.plotting import plot_ft_days, plot_model_history, plot_prediction_windows
from lib.analysis import print_heads_tails

# %%
labels = read_labels(1)
for house in range(1,2):
    print('House {}: '.format(house), labels[house], '\n')
# Out:
# House 1:  ['mains_active', 'mains_apparent', 'mains_rms', 'aggregate_apparent', 'ft_boiler', 'ft_solar_thermal_pump', 'ft_washing_machine', 'ft_dishwasher', 'ft_tv', 'ft_kitchen_lights', 'ft_htpc', 'ft_kettle', 'ft_toaster', 'ft_fridge', 'ft_microwave', 'ft_amp_livingroom', 'ft_adsl_router', 'ft_livingroom_s_lamp', 'ft_lighting_circuit', 'ft_subwoofer_livingroom', 'ft_livingroom_lamp_tv', 'ft_kitchen_phone&stereo', 'ft_coffee_machine', 'ft_gas_oven', 'ft_data_logger_pc', 'ft_office_lamp2', 'aggregate_active', 'unix_time']

# %%
ref_chunk_df = get_merged_chunks(1, 1)
print('Original DF shape', ref_chunk_df.shape)
print('---')
ref_chunk_df = ref_chunk_df[0:MAX_NO_ROWS]
# Out:
# reading house 1; chunk 1
# reading file data/ukdale-parsed-chunks/house_1/chunk_1.dat; for house 1 and chunk 1
# read house 1; chunk 1; df.shape is (4500000, 29)
# Original DF shape (4500000, 29)
# ---

# %%
dates = {}
# for house in range(1,2):
dates[1] = get_dates(ref_chunk_df, 1)
# Out:
# House 1 data contain 71 days from 2013-04-11 to 2013-06-20.
# ['2013-04-11', '2013-04-12', '2013-04-13', '2013-04-14', '2013-04-15', '2013-04-16', '2013-04-17', '2013-04-18', '2013-04-19', '2013-04-20', '2013-04-21', '2013-04-22', '2013-04-23', '2013-04-24', '2013-04-25', '2013-04-26', '2013-04-27', '2013-04-28', '2013-04-29', '2013-04-30', '2013-05-01', '2013-05-02', '2013-05-03', '2013-05-04', '2013-05-05', '2013-05-06', '2013-05-07', '2013-05-08', '2013-05-09', '2013-05-10', '2013-05-11', '2013-05-12', '2013-05-13', '2013-05-14', '2013-05-15', '2013-05-16', '2013-05-17', '2013-05-18', '2013-05-19', '2013-05-20', '2013-05-21', '2013-05-22', '2013-05-23', '2013-05-24', '2013-05-25', '2013-05-26', '2013-05-27', '2013-05-28', '2013-05-29', '2013-05-30', '2013-05-31', '2013-06-01', '2013-06-02', '2013-06-03', '2013-06-04', '2013-06-05', '2013-06-06', '2013-06-07', '2013-06-08', '2013-06-09', '2013-06-10', '2013-06-11', '2013-06-12', '2013-06-13', '2013-06-14', '2013-06-15', '2013-06-16', '2013-06-17', '2013-06-18', '2013-06-19', '2013-06-20']

# %%
# Constants 2
rows_per_day = ref_chunk_df.loc[:dates[1][2]].shape[0]

# %%
# plot_ft_days(ref_chunk_df, dates, 1, FEATURE, 2)

# %%
from algos.processing import split_df_by_dates
from algos.lstm import create_model, train, predict
from algos.norm import get_ref_norm

# %%
# Separate house 1 data into train, validation and test data
df_train, df_val, df_test  =  split_df_by_dates(ref_chunk_df, dates=dates, house=1)
# Out:
# df_train.shape:  (521300, 29)
# df_val.shape:  (316800, 29)
# df_test.shape:  (190700, 29)

# %%
ref_norm = get_ref_norm(df_train, NORM_TYPE)
# Out:
# ref_mean: 325.09124755859375; ref_max: 6002.919921875; ref_std: 434.2580871582031
# norm_type: max; ref_norm 6002.919921875

# %%
model = create_model(seq_len=SEQ_LEN, learning_rate=LEARNING_RATE, clipvalue=CLIP_VALUE)
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 32, 16)            80
#
#  bidirectional (Bidirectiona  (None, 32, 256)          148480
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 512)              1050624
#  nal)
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,264,977
# Trainable params: 1,264,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !!!!!!!Counter!!!!!!! 
# Manually update for every new loaded training
# Run Counter = 0

# Load and or Train
if LOAD_MODEL:
  model.load_weights(CHECKPOINT_PATH)
if SKIP_TRAINING:
  pass
else:
  model, history, time_spent = train(model, feature=FEATURE, df_train=df_train, df_val=df_val, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH, epochs=EPOCHS, checkpoint_path=CHECKPOINT_PATH)
# Out:
# x_train.shape, y_train.shape, x_val.shape, x_val.shape
# (521300, 1) (521300, 1) (316800, 1) (316800, 1)
# self.data_len 521300
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 510
# x.shape, y.shape (522240, 32, 1) (522240,)
# batch_index 0
# batch_index 200
# batch_index 400
# self.data_len 316800
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 310
# x.shape, y.shape (317440, 32, 1) (317440,)
# batch_index 0
# batch_index 200
# Epoch 1/100
#   6/510 [..............................] - ETA: 50s - loss: 0.0017 - root_mean_squared_error: 0.0417 - mean_absolute_error: 0.0273
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0199s vs `on_train_batch_end` time: 0.0653s). Check your callbacks.
# 510/510 [==============================] - ETA: 0s - loss: 9.7890e-05 - root_mean_squared_error: 0.0099 - mean_absolute_error: 0.0075
# Epoch 1: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 72s 112ms/step - loss: 9.7890e-05 - root_mean_squared_error: 0.0099 - mean_absolute_error: 0.0075 - val_loss: 6.7819e-05 - val_root_mean_squared_error: 0.0082 - val_mean_absolute_error: 0.0060
# Epoch 2/100
# 510/510 [==============================] - ETA: 0s - loss: 6.7558e-05 - root_mean_squared_error: 0.0082 - mean_absolute_error: 0.0066
# Epoch 2: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 68s 133ms/step - loss: 6.7558e-05 - root_mean_squared_error: 0.0082 - mean_absolute_error: 0.0066 - val_loss: 6.0947e-05 - val_root_mean_squared_error: 0.0078 - val_mean_absolute_error: 0.0060
# Epoch 3/100
# 510/510 [==============================] - ETA: 0s - loss: 6.3111e-05 - root_mean_squared_error: 0.0079 - mean_absolute_error: 0.0061
# Epoch 3: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 116ms/step - loss: 6.3111e-05 - root_mean_squared_error: 0.0079 - mean_absolute_error: 0.0061 - val_loss: 5.7568e-05 - val_root_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0054
# Epoch 4/100
# 510/510 [==============================] - ETA: 0s - loss: 6.1427e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0060
# Epoch 4: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 135ms/step - loss: 6.1427e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0060 - val_loss: 5.7022e-05 - val_root_mean_squared_error: 0.0076 - val_mean_absolute_error: 0.0054
# Epoch 5/100
# 510/510 [==============================] - ETA: 0s - loss: 6.1294e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0060
# Epoch 5: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 116ms/step - loss: 6.1294e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0060 - val_loss: 6.0732e-05 - val_root_mean_squared_error: 0.0078 - val_mean_absolute_error: 0.0056
# Epoch 6/100
# 510/510 [==============================] - ETA: 0s - loss: 6.1192e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0060
# Epoch 6: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 115ms/step - loss: 6.1192e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0060 - val_loss: 5.8526e-05 - val_root_mean_squared_error: 0.0077 - val_mean_absolute_error: 0.0055
# Epoch 7/100
# 510/510 [==============================] - ETA: 0s - loss: 6.0758e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059
# Epoch 7: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 115ms/step - loss: 6.0758e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059 - val_loss: 6.2169e-05 - val_root_mean_squared_error: 0.0079 - val_mean_absolute_error: 0.0060
# Epoch 8/100
# 510/510 [==============================] - ETA: 0s - loss: 6.0460e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059
# Epoch 8: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 115ms/step - loss: 6.0460e-05 - root_mean_squared_error: 0.0078 - mean_absolute_error: 0.0059 - val_loss: 5.4804e-05 - val_root_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0053
# Epoch 9/100
# 510/510 [==============================] - ETA: 0s - loss: 5.9465e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058
# Epoch 9: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 116ms/step - loss: 5.9465e-05 - root_mean_squared_error: 0.0077 - mean_absolute_error: 0.0058 - val_loss: 5.4570e-05 - val_root_mean_squared_error: 0.0074 - val_mean_absolute_error: 0.0048
# Epoch 10/100
# 510/510 [==============================] - ETA: 0s - loss: 5.6576e-05 - root_mean_squared_error: 0.0075 - mean_absolute_error: 0.0054
# Epoch 10: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 116ms/step - loss: 5.6576e-05 - root_mean_squared_error: 0.0075 - mean_absolute_error: 0.0054 - val_loss: 5.2471e-05 - val_root_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0047
# Epoch 11/100
# 510/510 [==============================] - ETA: 0s - loss: 5.5059e-05 - root_mean_squared_error: 0.0074 - mean_absolute_error: 0.0052
# Epoch 11: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 136ms/step - loss: 5.5059e-05 - root_mean_squared_error: 0.0074 - mean_absolute_error: 0.0052 - val_loss: 5.0626e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0045
# Epoch 12/100
# 510/510 [==============================] - ETA: 0s - loss: 5.4385e-05 - root_mean_squared_error: 0.0074 - mean_absolute_error: 0.0051
# Epoch 12: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 136ms/step - loss: 5.4385e-05 - root_mean_squared_error: 0.0074 - mean_absolute_error: 0.0051 - val_loss: 4.9835e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0042
# Epoch 13/100
# 510/510 [==============================] - ETA: 0s - loss: 5.3933e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0050
# Epoch 13: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 136ms/step - loss: 5.3933e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0050 - val_loss: 5.1142e-05 - val_root_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0044
# Epoch 14/100
# 510/510 [==============================] - ETA: 0s - loss: 5.3640e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0050
# Epoch 14: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 117ms/step - loss: 5.3640e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0050 - val_loss: 5.1479e-05 - val_root_mean_squared_error: 0.0072 - val_mean_absolute_error: 0.0044
# Epoch 15/100
# 510/510 [==============================] - ETA: 0s - loss: 5.3533e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0050
# Epoch 15: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 116ms/step - loss: 5.3533e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0050 - val_loss: 5.0251e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0043
# Epoch 16/100
# 510/510 [==============================] - ETA: 0s - loss: 5.2902e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0049
# Epoch 16: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 136ms/step - loss: 5.2902e-05 - root_mean_squared_error: 0.0073 - mean_absolute_error: 0.0049 - val_loss: 5.0353e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0043
# Epoch 17/100
# 510/510 [==============================] - ETA: 0s - loss: 5.2544e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0048
# Epoch 17: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 5.2544e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0048 - val_loss: 4.8281e-05 - val_root_mean_squared_error: 0.0069 - val_mean_absolute_error: 0.0044
# Epoch 18/100
# 510/510 [==============================] - ETA: 0s - loss: 5.2301e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0048
# Epoch 18: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 136ms/step - loss: 5.2301e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0048 - val_loss: 5.0423e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0043
# Epoch 19/100
# 510/510 [==============================] - ETA: 0s - loss: 5.1772e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047
# Epoch 19: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 136ms/step - loss: 5.1772e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047 - val_loss: 5.1109e-05 - val_root_mean_squared_error: 0.0071 - val_mean_absolute_error: 0.0044
# Epoch 20/100
# 510/510 [==============================] - ETA: 0s - loss: 5.1487e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047
# Epoch 20: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 136ms/step - loss: 5.1487e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047 - val_loss: 4.8626e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0041
# Epoch 21/100
# 510/510 [==============================] - ETA: 0s - loss: 5.1217e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047
# Epoch 21: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 136ms/step - loss: 5.1217e-05 - root_mean_squared_error: 0.0072 - mean_absolute_error: 0.0047 - val_loss: 4.8961e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0040
# Epoch 22/100
# 510/510 [==============================] - ETA: 0s - loss: 5.0531e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0046
# Epoch 22: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 136ms/step - loss: 5.0531e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0046 - val_loss: 4.8317e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0041
# Epoch 23/100
# 510/510 [==============================] - ETA: 0s - loss: 4.9937e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0045
# Epoch 23: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 59s 116ms/step - loss: 4.9937e-05 - root_mean_squared_error: 0.0071 - mean_absolute_error: 0.0045 - val_loss: 4.8390e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0039
# Epoch 24/100
# 510/510 [==============================] - ETA: 0s - loss: 4.9265e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044
# Epoch 24: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 135ms/step - loss: 4.9265e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044 - val_loss: 4.9254e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.0040
# Epoch 25/100
# 510/510 [==============================] - ETA: 0s - loss: 4.8985e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044
# Epoch 25: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 4.8985e-05 - root_mean_squared_error: 0.0070 - mean_absolute_error: 0.0044 - val_loss: 4.8639e-05 - val_root_mean_squared_error: 0.0070 - val_mean_absolute_error: 0.
-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033
# Epoch 68: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 118ms/step - loss: 3.7025e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033 - val_loss: 4.5137e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0034
# Epoch 69/100
# 510/510 [==============================] - ETA: 0s - loss: 3.7045e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0034
# Epoch 69: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 136ms/step - loss: 3.7045e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0034 - val_loss: 4.3740e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 70/100
# 510/510 [==============================] - ETA: 0s - loss: 3.6964e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033
# Epoch 70: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.6964e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033 - val_loss: 4.1369e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0032
# Epoch 71/100
# 510/510 [==============================] - ETA: 0s - loss: 3.6691e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033
# Epoch 71: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.6691e-05 - root_mean_squared_error: 0.0061 - mean_absolute_error: 0.0033 - val_loss: 4.4160e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0034
# Epoch 72/100
# 510/510 [==============================] - ETA: 0s - loss: 3.6523e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033
# Epoch 72: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.6523e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033 - val_loss: 4.3331e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 73/100
# 510/510 [==============================] - ETA: 0s - loss: 3.6336e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033
# Epoch 73: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.6336e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033 - val_loss: 4.1525e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0033
# Epoch 74/100
# 510/510 [==============================] - ETA: 0s - loss: 3.6220e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033
# Epoch 74: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.6220e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033 - val_loss: 4.5508e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0034
# Epoch 75/100
# 510/510 [==============================] - ETA: 0s - loss: 3.6158e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033
# Epoch 75: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.6158e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033 - val_loss: 4.2128e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0032
# Epoch 76/100
# 510/510 [==============================] - ETA: 0s - loss: 3.5955e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033
# Epoch 76: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.5955e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0033 - val_loss: 4.2341e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0034
# Epoch 77/100
# 510/510 [==============================] - ETA: 0s - loss: 3.5627e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032
# Epoch 77: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.5627e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032 - val_loss: 4.2958e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 78/100
# 510/510 [==============================] - ETA: 0s - loss: 3.5479e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032
# Epoch 78: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 118ms/step - loss: 3.5479e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032 - val_loss: 4.3601e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 79/100
# 510/510 [==============================] - ETA: 0s - loss: 3.5487e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032
# Epoch 79: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 69s 136ms/step - loss: 3.5487e-05 - root_mean_squared_error: 0.0060 - mean_absolute_error: 0.0032 - val_loss: 4.3618e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 80/100
# 510/510 [==============================] - ETA: 0s - loss: 3.5235e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032
# Epoch 80: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 118ms/step - loss: 3.5235e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032 - val_loss: 4.4576e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0034
# Epoch 81/100
# 510/510 [==============================] - ETA: 0s - loss: 3.5165e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032
# Epoch 81: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 117ms/step - loss: 3.5165e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032 - val_loss: 4.3565e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 82/100
# 510/510 [==============================] - ETA: 0s - loss: 3.5067e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032
# Epoch 82: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.5067e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032 - val_loss: 4.4600e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0034
# Epoch 83/100
# 510/510 [==============================] - ETA: 0s - loss: 3.4887e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032
# Epoch 83: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 138ms/step - loss: 3.4887e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032 - val_loss: 4.2426e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0031
# Epoch 84/100
# 510/510 [==============================] - ETA: 0s - loss: 3.4987e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032
# Epoch 84: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.4987e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032 - val_loss: 4.1215e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 85/100
# 510/510 [==============================] - ETA: 0s - loss: 3.4660e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031
# Epoch 85: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.4660e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031 - val_loss: 4.6268e-05 - val_root_mean_squared_error: 0.0068 - val_mean_absolute_error: 0.0034
# Epoch 86/100
# 510/510 [==============================] - ETA: 0s - loss: 3.4545e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032
# Epoch 86: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.4545e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0032 - val_loss: 4.2279e-05 - val_root_mean_squared_error: 0.0065 - val_mean_absolute_error: 0.0032
# Epoch 87/100
# 510/510 [==============================] - ETA: 0s - loss: 3.4414e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031
# Epoch 87: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 138ms/step - loss: 3.4414e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031 - val_loss: 4.2984e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 88/100
# 510/510 [==============================] - ETA: 0s - loss: 3.4318e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031
# Epoch 88: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 138ms/step - loss: 3.4318e-05 - root_mean_squared_error: 0.0059 - mean_absolute_error: 0.0031 - val_loss: 4.1457e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0033
# Epoch 89/100
# 510/510 [==============================] - ETA: 0s - loss: 3.4140e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 89: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 138ms/step - loss: 3.4140e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.4189e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0034
# Epoch 90/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3797e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 90: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 118ms/step - loss: 3.3797e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.3992e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 91/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3933e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 91: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 117ms/step - loss: 3.3933e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.5002e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0035
# Epoch 92/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3743e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 92: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.3743e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.3728e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0032
# Epoch 93/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3980e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 93: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 118ms/step - loss: 3.3980e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.3128e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0035
# Epoch 94/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3758e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 94: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.3758e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.4280e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0034
# Epoch 95/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3416e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 95: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 138ms/step - loss: 3.3416e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.1148e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 96/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3547e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 96: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 118ms/step - loss: 3.3547e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.4225e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0032
# Epoch 97/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3095e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030
# Epoch 97: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 137ms/step - loss: 3.3095e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0030 - val_loss: 4.1555e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0030
# Epoch 98/100
# 510/510 [==============================] - ETA: 0s - loss: 3.2706e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0030
# Epoch 98: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 138ms/step - loss: 3.2706e-05 - root_mean_squared_error: 0.0057 - mean_absolute_error: 0.0030 - val_loss: 4.3333e-05 - val_root_mean_squared_error: 0.0066 - val_mean_absolute_error: 0.0033
# Epoch 99/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3601e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 99: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 70s 138ms/step - loss: 3.3601e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.0888e-05 - val_root_mean_squared_error: 0.0064 - val_mean_absolute_error: 0.0031
# Epoch 100/100
# 510/510 [==============================] - ETA: 0s - loss: 3.3211e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031
# Epoch 100: saving model to lstm_training_ft_fridge/cp.ckpt
# 510/510 [==============================] - 60s 118ms/step - loss: 3.3211e-05 - root_mean_squared_error: 0.0058 - mean_absolute_error: 0.0031 - val_loss: 4.4436e-05 - val_root_mean_squared_error: 0.0067 - val_mean_absolute_error: 0.0034

# %%
if not SKIP_TRAINING:
    print('Time spent', time_spent)
    plot_model_history(history)
# Out:
# Time spent 6558.549943711999
# dict_keys(['loss', 'root_mean_squared_error', 'mean_absolute_error', 'val_loss', 'val_root_mean_squared_error', 'val_mean_absolute_error'])

# %%
# Predict from test split
y_test, y_pred = predict(model, feature=FEATURE, df_test=df_test, ref_norm=ref_norm, seq_len=SEQ_LEN, seq_per_batch=SEQ_PER_BATCH)
# Out:
# x_test.shape, y_test.shape
# (190700, 1) (190700, 1)
# self.data_len 190700
# stride 1
# seq_per_batch 1024
# seq_len 32
# n_batches 187
# x.shape, y.shape (191488, 32, 1) (191488,)
# batch_index 0
# 187/187 [==============================] - 8s 33ms/step
# y_test.shape, y_pred.shape
# (191488,) (191488, 1)
# y_test.shape, y_pred.shape
# (191488,) (191488,)
# Normalized: y_test.mean, y_pred.mean
# 0.006400404 0.0063415025
# Denormalized: y_test.mean, y_pred.mean
# 38.421112 38.095203

# %%
# plot_prediction_windows(FEATURE, y_test_denorm, y_pred_denorm)

# %%
n_samples = int(rows_per_day * 0.2)
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=False, n_samples=n_samples)

# %%
n_samples = 80
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, active_factor=4, n_samples=n_samples)

# %%
n_samples = 200
plot_prediction_windows(FEATURE, y_test, y_pred, use_active=True, n_samples=n_samples)

# %%
from lib import analysis
from lib.logging import losses_to_file, metrics_to_file

# %%
params = {}
params["algo"] = 'lstm'
params["feature"] = FEATURE
params["seq_len"] = SEQ_LEN
params["seq_per_batch"] = SEQ_PER_BATCH
params["strides"] = N_STRIDES
params["epochs"] = EPOCHS
params["train_rows"] = df_train.shape[0]
params["val_rows"] = df_val.shape[0]
params["test_rows"] = df_test.shape[0]
params["norm_value"] = ref_norm
params["norm_type"] = NORM_TYPE
params["learning_rate"] = LEARNING_RATE
params["loss"] = 'adam'
params["clipvalue"] = CLIP_VALUE

# %%
print(params)
# Out:
# {'algo': 'lstm', 'feature': 'ft_fridge', 'seq_len': 32, 'seq_per_batch': 1024, 'strides': 1, 'epochs': 100, 'train_rows': 521300, 'val_rows': 316800, 'test_rows': 190700, 'norm_value': 6002.92, 'norm_type': 'max', 'learning_rate': 0.01, 'loss': 'adam', 'clipvalue': 10.0}

# %%
results = analysis.classification_results(y_test, y_pred, on_threshold = 10)

metrics = {}
metrics["mae"] = analysis.mse_loss(y_test, y_pred)
metrics["mse"] = analysis.mae_loss(y_test, y_pred)
metrics["f1"] = analysis.f1(results)
metrics["accuracy"] = analysis.accuracy(results)
metrics["precision"] = analysis.precision(results)
metrics["recall"] = analysis.recall(results)

# %%
print(metrics)
# Out:
# {'mae': 1684.8433654488174, 'mse': 20.768034228264053, 'f1': 0.8134517226712037, 'accuracy': 0.8167718081550802, 'precision': 0.6982966370905904, 'recall': 0.9740869963836398}

# %%
if not SKIP_TRAINING:
    losses_to_file(1, params, history.history)

# %%
metrics_to_file(1, params, metrics)
